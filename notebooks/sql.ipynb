# %% [markdown]
# ### import csv and check shape

# %%
import pandas as pd
import os

# %%
billing = pd.read_csv("data/billing.csv")
visits = pd.read_csv("data/visits.csv")
patient = pd.read_csv("data/patients.csv")

print("patient shape :",patient.shape)
print("billing shape :",billing.shape)
print("visits shape :",visits.shape)
# Out:
# patient shape : (5000, 7)
# billing shape : (25000, 7)
# visits shape : (25000, 8)

# %%
billing_data= billing.to_dict(orient="records")
billing_data
# Out:
# [{'bill_id': 1,
#   'visit_id': 1,
#   'billed_amount': 23550.0,
#   'approved_amount': 21429.62,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-11-03'},
#  {'bill_id': 2,
#   'visit_id': 2,
#   'billed_amount': 88539.01,
#   'approved_amount': 19725.49,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-16'},
#  {'bill_id': 3,
#   'visit_id': 3,
#   'billed_amount': 25949.3,
#   'approved_amount': 1580.95,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-20'},
#  {'bill_id': 4,
#   'visit_id': 4,
#   'billed_amount': 8349.57,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-08-16'},
#  {'bill_id': 5,
#   'visit_id': 5,
#   'billed_amount': 88539.01,
#   'approved_amount': 86803.45,
#   'claim_status': 'Paid',
#   'payment_days': 30.0,
#   'billing_date': '2025-08-23'},
#  {'bill_id': 6,
#   'visit_id': 6,
#   'billed_amount': 15260.62,
#   'approved_amount': 15170.82,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-10-12'},
#  {'bill_id': 7,
#   'visit_id': 7,
#   'billed_amount': 7359.98,
#   'approved_amount': 6682.34,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2026-01-07'},
#  {'bill_id': 8,
#   'visit_id': 8,
#   'billed_amount': 9612.77,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-19'},
#  {'bill_id': 9,
#   'visit_id': 9,
#   'billed_amount': 37201.86,
#   'approved_amount': 35682.85,
#   'claim_status': 'Paid',
#   'payment_days': 54.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 10,
#   'visit_id': 10,
#   'billed_amount': 77351.57,
#   'approved_amount': 4276.21,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 11,
#   'visit_id': 11,
#   'billed_amount': 75636.36,
#   'approved_amount': 20515.56,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-11-18'},
#  {'bill_id': 12,
#   'visit_id': 12,
#   'billed_amount': 27143.29,
#   'approved_amount': 26404.71,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2025-07-08'},
#  {'bill_id': 13,
#   'visit_id': 13,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-11'},
#  {'bill_id': 14,
#   'visit_id': 14,
#   'billed_amount': 88539.01,
#   'approved_amount': 82492.35,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-04-22'},
#  {'bill_id': 15,
#   'visit_id': 15,
#   'billed_amount': 15270.1,
#   'approved_amount': 13684.78,
#   'claim_status': 'Paid',
#   'payment_days': 43.0,
#   'billing_date': '2025-10-03'},
#  {'bill_id': 16,
#   'visit_id': 16,
#   'billed_amount': 52792.35,
#   'approved_amount': 52220.55,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2025-05-18'},
#  {'bill_id': 17,
#   'visit_id': 17,
#   'billed_amount': 16983.11,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-07-13'},
#  {'bill_id': 18,
#   'visit_id': 18,
#   'billed_amount': 56745.53,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-09-16'},
#  {'bill_id': 19,
#   'visit_id': 19,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-13'},
#  {'bill_id': 20,
#   'visit_id': 20,
#   'billed_amount': 35961.09,
#   'approved_amount': 4197.42,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-09'},
#  {'bill_id': 21,
#   'visit_id': 21,
#   'billed_amount': 88539.01,
#   'approved_amount': 4852.22,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-03-29'},
#  {'bill_id': 22,
#   'visit_id': 22,
#   'billed_amount': 22128.13,
#   'approved_amount': 20304.98,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-07-29'},
#  {'bill_id': 23,
#   'visit_id': 23,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-24'},
#  {'bill_id': 24,
#   'visit_id': 24,
#   'billed_amount': 88539.01,
#   'approved_amount': 3845.92,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-31'},
#  {'bill_id': 25,
#   'visit_id': 25,
#   'billed_amount': 26042.55,
#   'approved_amount': 22346.83,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-10-23'},
#  {'bill_id': 26,
#   'visit_id': 26,
#   'billed_amount': 36895.37,
#   'approved_amount': 36266.54,
#   'claim_status': 'Paid',
#   'payment_days': 33.0,
#   'billing_date': '2025-03-17'},
#  {'bill_id': 27,
#   'visit_id': 27,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-08-08'},
#  {'bill_id': 28,
#   'visit_id': 28,
#   'billed_amount': 35535.64,
#   'approved_amount': 32660.21,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2025-07-05'},
#  {'bill_id': 29,
#   'visit_id': 29,
#   'billed_amount': 8684.68,
#   'approved_amount': 7537.64,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-01'},
#  {'bill_id': 30,
#   'visit_id': 30,
#   'billed_amount': 13732.33,
#   'approved_amount': 12507.77,
#   'claim_status': 'Paid',
#   'payment_days': 25.0,
#   'billing_date': '2025-07-03'},
#  {'bill_id': 31,
#   'visit_id': 31,
#   'billed_amount': 84216.42,
#   'approved_amount': 37359.34,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 32,
#   'visit_id': 32,
#   'billed_amount': 68049.65,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-04-04'},
#  {'bill_id': 33,
#   'visit_id': 33,
#   'billed_amount': 13428.57,
#   'approved_amount': 13122.58,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-04-23'},
#  {'bill_id': 34,
#   'visit_id': 34,
#   'billed_amount': 39442.34,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-12'},
#  {'bill_id': 35,
#   'visit_id': 35,
#   'billed_amount': 13854.4,
#   'approved_amount': 13477.47,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-06-02'},
#  {'bill_id': 36,
#   'visit_id': 36,
#   'billed_amount': 9673.38,
#   'approved_amount': 8591.38,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 37,
#   'visit_id': 37,
#   'billed_amount': 11234.87,
#   'approved_amount': 9892.48,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-09-03'},
#  {'bill_id': 38,
#   'visit_id': 38,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 41.0,
#   'billing_date': '2025-10-18'},
#  {'bill_id': 39,
#   'visit_id': 39,
#   'billed_amount': 88539.01,
#   'approved_amount': 77695.0,
#   'claim_status': 'Paid',
#   'payment_days': 34.0,
#   'billing_date': '2025-08-15'},
#  {'bill_id': 40,
#   'visit_id': 40,
#   'billed_amount': 20939.44,
#   'approved_amount': 5096.46,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-05'},
#  {'bill_id': 41,
#   'visit_id': 41,
#   'billed_amount': 88539.01,
#   'approved_amount': 86398.27,
#   'claim_status': 'Paid',
#   'payment_days': 42.0,
#   'billing_date': '2025-09-16'},
#  {'bill_id': 42,
#   'visit_id': 42,
#   'billed_amount': 64560.47,
#   'approved_amount': 64200.54,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-04-21'},
#  {'bill_id': 43,
#   'visit_id': 43,
#   'billed_amount': 43137.01,
#   'approved_amount': 39102.4,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2025-11-26'},
#  {'bill_id': 44,
#   'visit_id': 44,
#   'billed_amount': 88539.01,
#   'approved_amount': 81942.35,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 45,
#   'visit_id': 45,
#   'billed_amount': 88539.01,
#   'approved_amount': 82220.37,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-05'},
#  {'bill_id': 46,
#   'visit_id': 46,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-19'},
#  {'bill_id': 47,
#   'visit_id': 47,
#   'billed_amount': 19653.25,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 46.0,
#   'billing_date': '2025-12-05'},
#  {'bill_id': 48,
#   'visit_id': 48,
#   'billed_amount': 88539.01,
#   'approved_amount': 12255.31,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 49,
#   'visit_id': 49,
#   'billed_amount': 43710.5,
#   'approved_amount': 40189.95,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-09-16'},
#  {'bill_id': 50,
#   'visit_id': 50,
#   'billed_amount': 16615.07,
#   'approved_amount': 16474.11,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-11-15'},
#  {'bill_id': 51,
#   'visit_id': 51,
#   'billed_amount': 4491.6,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-25'},
#  {'bill_id': 52,
#   'visit_id': 52,
#   'billed_amount': 39407.74,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-08-25'},
#  {'bill_id': 53,
#   'visit_id': 53,
#   'billed_amount': 29059.39,
#   'approved_amount': 24914.19,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2026-01-02'},
#  {'bill_id': 54,
#   'visit_id': 54,
#   'billed_amount': 16769.43,
#   'approved_amount': 4251.49,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-04-25'},
#  {'bill_id': 55,
#   'visit_id': 55,
#   'billed_amount': 15352.55,
#   'approved_amount': 13650.58,
#   'claim_status': 'Paid',
#   'payment_days': 43.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 56,
#   'visit_id': 56,
#   'billed_amount': 58191.91,
#   'approved_amount': 55124.07,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2025-11-30'},
#  {'bill_id': 57,
#   'visit_id': 57,
#   'billed_amount': 15144.38,
#   'approved_amount': 14966.95,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 58,
#   'visit_id': 58,
#   'billed_amount': 6447.02,
#   'approved_amount': 5680.51,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-07-01'},
#  {'bill_id': 59,
#   'visit_id': 59,
#   'billed_amount': 28166.31,
#   'approved_amount': 26809.72,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-11-08'},
#  {'bill_id': 60,
#   'visit_id': 60,
#   'billed_amount': 4791.75,
#   'approved_amount': 4766.2,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-04-16'},
#  {'bill_id': 61,
#   'visit_id': 61,
#   'billed_amount': 38304.24,
#   'approved_amount': 33428.53,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 62,
#   'visit_id': 62,
#   'billed_amount': 11212.33,
#   'approved_amount': 11001.05,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-10-23'},
#  {'bill_id': 63,
#   'visit_id': 63,
#   'billed_amount': 61707.55,
#   'approved_amount': 56836.95,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-10-14'},
#  {'bill_id': 64,
#   'visit_id': 64,
#   'billed_amount': 4403.76,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-11-03'},
#  {'bill_id': 65,
#   'visit_id': 65,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-05'},
#  {'bill_id': 66,
#   'visit_id': 66,
#   'billed_amount': 43641.75,
#   'approved_amount': 1464.39,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-27'},
#  {'bill_id': 67,
#   'visit_id': 67,
#   'billed_amount': 16959.12,
#   'approved_amount': 16322.5,
#   'claim_status': 'Paid',
#   'payment_days': 29.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 68,
#   'visit_id': 68,
#   'billed_amount': 10170.19,
#   'approved_amount': 9038.76,
#   'claim_status': 'Paid',
#   'payment_days': 31.0,
#   'billing_date': '2025-09-14'},
#  {'bill_id': 69,
#   'visit_id': 69,
#   'billed_amount': 3814.08,
#   'approved_amount': 3712.85,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-26'},
#  {'bill_id': 70,
#   'visit_id': 70,
#   'billed_amount': 16835.18,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-10'},
#  {'bill_id': 71,
#   'visit_id': 71,
#   'billed_amount': 10445.22,
#   'approved_amount': 10197.07,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-12-01'},
#  {'bill_id': 72,
#   'visit_id': 72,
#   'billed_amount': 19472.2,
#   'approved_amount': 19168.21,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-10-14'},
#  {'bill_id': 73,
#   'visit_id': 73,
#   'billed_amount': 54044.91,
#   'approved_amount': 49182.24,
#   'claim_status': 'Paid',
#   'payment_days': 54.0,
#   'billing_date': '2025-11-01'},
#  {'bill_id': 74,
#   'visit_id': 74,
#   'billed_amount': 9893.38,
#   'approved_amount': 8926.67,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 75,
#   'visit_id': 75,
#   'billed_amount': 14128.44,
#   'approved_amount': 626.47,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-31'},
#  {'bill_id': 76,
#   'visit_id': 76,
#   'billed_amount': 12037.92,
#   'approved_amount': 11348.25,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-07-31'},
#  {'bill_id': 77,
#   'visit_id': 77,
#   'billed_amount': 88539.01,
#   'approved_amount': 39819.39,
#   'claim_status': 'Pending',
#   'payment_days': 49.0,
#   'billing_date': '2025-12-20'},
#  {'bill_id': 78,
#   'visit_id': 78,
#   'billed_amount': 500.0,
#   'approved_amount': 475.01,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-06-15'},
#  {'bill_id': 79,
#   'visit_id': 79,
#   'billed_amount': 13063.27,
#   'approved_amount': 434.45,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-06'},
#  {'bill_id': 80,
#   'visit_id': 80,
#   'billed_amount': 20769.99,
#   'approved_amount': 17878.76,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2025-08-16'},
#  {'bill_id': 81,
#   'visit_id': 81,
#   'billed_amount': 5479.72,
#   'approved_amount': 89.14,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-06-30'},
#  {'bill_id': 82,
#   'visit_id': 82,
#   'billed_amount': 5757.61,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 83,
#   'visit_id': 83,
#   'billed_amount': 67337.51,
#   'approved_amount': 58390.05,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-07-12'},
#  {'bill_id': 84,
#   'visit_id': 84,
#   'billed_amount': 14461.37,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 85,
#   'visit_id': 85,
#   'billed_amount': 43217.65,
#   'approved_amount': 37815.17,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-07-01'},
#  {'bill_id': 86,
#   'visit_id': 86,
#   'billed_amount': 9830.13,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-17'},
#  {'bill_id': 87,
#   'visit_id': 87,
#   'billed_amount': 15400.51,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-01'},
#  {'bill_id': 88,
#   'visit_id': 88,
#   'billed_amount': 35466.63,
#   'approved_amount': 3783.34,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-18'},
#  {'bill_id': 89,
#   'visit_id': 89,
#   'billed_amount': 21261.9,
#   'approved_amount': 18366.53,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2025-12-15'},
#  {'bill_id': 90,
#   'visit_id': 90,
#   'billed_amount': 42446.51,
#   'approved_amount': 36685.95,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-11-24'},
#  {'bill_id': 91,
#   'visit_id': 91,
#   'billed_amount': 35434.73,
#   'approved_amount': 35351.15,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-12-31'},
#  {'bill_id': 92,
#   'visit_id': 92,
#   'billed_amount': 31885.97,
#   'approved_amount': 28177.99,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 93,
#   'visit_id': 93,
#   'billed_amount': 8827.05,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 94,
#   'visit_id': 94,
#   'billed_amount': 4084.47,
#   'approved_amount': 3911.1,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 95,
#   'visit_id': 95,
#   'billed_amount': 14240.18,
#   'approved_amount': 13148.95,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-09-04'},
#  {'bill_id': 96,
#   'visit_id': 96,
#   'billed_amount': 30000.11,
#   'approved_amount': 27621.55,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 97,
#   'visit_id': 97,
#   'billed_amount': 88539.01,
#   'approved_amount': 75334.89,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2025-09-27'},
#  {'bill_id': 98,
#   'visit_id': 98,
#   'billed_amount': 40143.82,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-12'},
#  {'bill_id': 99,
#   'visit_id': 99,
#   'billed_amount': 37359.58,
#   'approved_amount': 33508.58,
#   'claim_status': 'Paid',
#   'payment_days': 29.0,
#   'billing_date': '2025-11-18'},
#  {'bill_id': 100,
#   'visit_id': 100,
#   'billed_amount': 46234.53,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 36.0,
#   'billing_date': '2025-10-19'},
#  {'bill_id': 101,
#   'visit_id': 101,
#   'billed_amount': 88539.01,
#   'approved_amount': 87495.97,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-07-18'},
#  {'bill_id': 102,
#   'visit_id': 102,
#   'billed_amount': 6908.05,
#   'approved_amount': 6121.56,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 103,
#   'visit_id': 103,
#   'billed_amount': 13691.76,
#   'approved_amount': 359.23,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-10-14'},
#  {'bill_id': 104,
#   'visit_id': 104,
#   'billed_amount': 26404.54,
#   'approved_amount': 26121.9,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2026-01-18'},
#  {'bill_id': 105,
#   'visit_id': 105,
#   'billed_amount': 10744.76,
#   'approved_amount': 9967.18,
#   'claim_status': 'Paid',
#   'payment_days': 42.0,
#   'billing_date': '2025-07-22'},
#  {'bill_id': 106,
#   'visit_id': 106,
#   'billed_amount': 10318.61,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-20'},
#  {'bill_id': 107,
#   'visit_id': 107,
#   'billed_amount': 6526.8,
#   'approved_amount': 5990.88,
#   'claim_status': 'Paid',
#   'payment_days': 25.0,
#   'billing_date': '2025-10-12'},
#  {'bill_id': 108,
#   'visit_id': 108,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-27'},
#  {'bill_id': 109,
#   'visit_id': 109,
#   'billed_amount': 42445.99,
#   'approved_amount': 40173.54,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-30'},
#  {'bill_id': 110,
#   'visit_id': 110,
#   'billed_amount': 4109.6,
#   'approved_amount': 3561.57,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2025-09-24'},
#  {'bill_id': 111,
#   'visit_id': 111,
#   'billed_amount': 1461.78,
#   'approved_amount': 1444.76,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2026-01-11'},
#  {'bill_id': 112,
#   'visit_id': 112,
#   'billed_amount': 19810.18,
#   'approved_amount': 17249.76,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-08-12'},
#  {'bill_id': 113,
#   'visit_id': 113,
#   'billed_amount': 11112.39,
#   'approved_amount': 11070.35,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 114,
#   'visit_id': 114,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 46.0,
#   'billing_date': '2025-03-02'},
#  {'bill_id': 115,
#   'visit_id': 115,
#   'billed_amount': 12342.29,
#   'approved_amount': 11661.86,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-08-29'},
#  {'bill_id': 116,
#   'visit_id': 116,
#   'billed_amount': 28316.95,
#   'approved_amount': 26673.85,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 117,
#   'visit_id': 117,
#   'billed_amount': 58631.52,
#   'approved_amount': 55132.33,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-03-10'},
#  {'bill_id': 118,
#   'visit_id': 118,
#   'billed_amount': 88539.01,
#   'approved_amount': 79861.96,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2025-08-17'},
#  {'bill_id': 119,
#   'visit_id': 119,
#   'billed_amount': 51668.77,
#   'approved_amount': 44178.91,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 120,
#   'visit_id': 120,
#   'billed_amount': 15134.08,
#   'approved_amount': 14483.26,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 121,
#   'visit_id': 121,
#   'billed_amount': 65594.27,
#   'approved_amount': 60395.21,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 122,
#   'visit_id': 122,
#   'billed_amount': 21618.46,
#   'approved_amount': 2777.61,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-23'},
#  {'bill_id': 123,
#   'visit_id': 123,
#   'billed_amount': 11738.64,
#   'approved_amount': 10794.61,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-12-22'},
#  {'bill_id': 124,
#   'visit_id': 124,
#   'billed_amount': 8549.76,
#   'approved_amount': 7508.94,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 125,
#   'visit_id': 125,
#   'billed_amount': 88539.01,
#   'approved_amount': 17367.31,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-19'},
#  {'bill_id': 126,
#   'visit_id': 126,
#   'billed_amount': 4817.28,
#   'approved_amount': 4130.81,
#   'claim_status': 'Paid',
#   'payment_days': 31.0,
#   'billing_date': '2026-01-15'},
#  {'bill_id': 127,
#   'visit_id': 127,
#   'billed_amount': 11776.4,
#   'approved_amount': 11493.37,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2026-01-12'},
#  {'bill_id': 128,
#   'visit_id': 128,
#   'billed_amount': 88539.01,
#   'approved_amount': 37060.56,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-26'},
#  {'bill_id': 129,
#   'visit_id': 129,
#   'billed_amount': 88539.01,
#   'approved_amount': 10170.24,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 130,
#   'visit_id': 130,
#   'billed_amount': 61186.86,
#   'approved_amount': 53269.76,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 131,
#   'visit_id': 131,
#   'billed_amount': 52345.1,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 132,
#   'visit_id': 132,
#   'billed_amount': 80128.97,
#   'approved_amount': 78051.28,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 133,
#   'visit_id': 133,
#   'billed_amount': 88539.01,
#   'approved_amount': 4784.74,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-05-11'},
#  {'bill_id': 134,
#   'visit_id': 134,
#   'billed_amount': 11697.88,
#   'approved_amount': 11071.14,
#   'claim_status': 'Paid',
#   'payment_days': 32.0,
#   'billing_date': '2025-05-29'},
#  {'bill_id': 135,
#   'visit_id': 135,
#   'billed_amount': 88368.14,
#   'approved_amount': 42730.23,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-16'},
#  {'bill_id': 136,
#   'visit_id': 136,
#   'billed_amount': 6630.77,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 137,
#   'visit_id': 137,
#   'billed_amount': 10215.95,
#   'approved_amount': 823.97,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-04-21'},
#  {'bill_id': 138,
#   'visit_id': 138,
#   'billed_amount': 14484.42,
#   'approved_amount': 13501.36,
#   'claim_status': 'Paid',
#   'payment_days': 43.0,
#   'billing_date': '2025-06-27'},
#  {'bill_id': 139,
#   'visit_id': 139,
#   'billed_amount': 21079.66,
#   'approved_amount': 19909.38,
#   'claim_status': 'Paid',
#   'payment_days': 37.0,
#   'billing_date': '2025-09-28'},
#  {'bill_id': 140,
#   'visit_id': 140,
#   'billed_amount': 11299.85,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-29'},
#  {'bill_id': 141,
#   'visit_id': 141,
#   'billed_amount': 88539.01,
#   'approved_amount': 5757.83,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-05-06'},
#  {'bill_id': 142,
#   'visit_id': 142,
#   'billed_amount': 13655.84,
#   'approved_amount': 1054.57,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-05-26'},
#  {'bill_id': 143,
#   'visit_id': 143,
#   'billed_amount': 13423.39,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-12'},
#  {'bill_id': 144,
#   'visit_id': 144,
#   'billed_amount': 22463.23,
#   'approved_amount': 20494.28,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-12-31'},
#  {'bill_id': 145,
#   'visit_id': 145,
#   'billed_amount': 22892.02,
#   'approved_amount': 19798.32,
#   'claim_status': 'Paid',
#   'payment_days': 55.0,
#   'billing_date': '2025-07-27'},
#  {'bill_id': 146,
#   'visit_id': 146,
#   'billed_amount': 41782.54,
#   'approved_amount': 16018.45,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 147,
#   'visit_id': 147,
#   'billed_amount': 11191.81,
#   'approved_amount': 9886.52,
#   'claim_status': 'Paid',
#   'payment_days': 55.0,
#   'billing_date': '2025-11-16'},
#  {'bill_id': 148,
#   'visit_id': 148,
#   'billed_amount': 12794.55,
#   'approved_amount': 11138.3,
#   'claim_status': 'Paid',
#   'payment_days': 29.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 149,
#   'visit_id': 149,
#   'billed_amount': 4304.25,
#   'approved_amount': 4118.6,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-12-20'},
#  {'bill_id': 150,
#   'visit_id': 150,
#   'billed_amount': 88539.01,
#   'approved_amount': 82667.2,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-10-01'},
#  {'bill_id': 151,
#   'visit_id': 151,
#   'billed_amount': 46070.91,
#   'approved_amount': 45311.13,
#   'claim_status': 'Paid',
#   'payment_days': 32.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 152,
#   'visit_id': 152,
#   'billed_amount': 81084.46,
#   'approved_amount': 6222.66,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-07'},
#  {'bill_id': 153,
#   'visit_id': 153,
#   'billed_amount': 14957.14,
#   'approved_amount': 13887.8,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 154,
#   'visit_id': 154,
#   'billed_amount': 88539.01,
#   'approved_amount': 85021.21,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2026-01-10'},
#  {'bill_id': 155,
#   'visit_id': 155,
#   'billed_amount': 2937.28,
#   'approved_amount': 51.39,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-29'},
#  {'bill_id': 156,
#   'visit_id': 156,
#   'billed_amount': 12679.88,
#   'approved_amount': 10786.53,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 157,
#   'visit_id': 157,
#   'billed_amount': 15840.99,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 49.0,
#   'billing_date': '2025-12-15'},
#  {'bill_id': 158,
#   'visit_id': 158,
#   'billed_amount': 6496.49,
#   'approved_amount': 5932.26,
#   'claim_status': 'Paid',
#   'payment_days': 34.0,
#   'billing_date': '2025-11-13'},
#  {'bill_id': 159,
#   'visit_id': 159,
#   'billed_amount': 8766.04,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-12'},
#  {'bill_id': 160,
#   'visit_id': 160,
#   'billed_amount': 17765.62,
#   'approved_amount': 16795.6,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-11-10'},
#  {'bill_id': 161,
#   'visit_id': 161,
#   'billed_amount': 19398.91,
#   'approved_amount': 18857.25,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 162,
#   'visit_id': 162,
#   'billed_amount': 9851.95,
#   'approved_amount': 9136.75,
#   'claim_status': 'Paid',
#   'payment_days': 40.0,
#   'billing_date': '2025-11-25'},
#  {'bill_id': 163,
#   'visit_id': 163,
#   'billed_amount': 6405.33,
#   'approved_amount': 6169.88,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-12-17'},
#  {'bill_id': 164,
#   'visit_id': 164,
#   'billed_amount': 21786.96,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-15'},
#  {'bill_id': 165,
#   'visit_id': 165,
#   'billed_amount': 65997.2,
#   'approved_amount': 30739.04,
#   'claim_status': 'Pending',
#   'payment_days': 36.0,
#   'billing_date': '2025-08-15'},
#  {'bill_id': 166,
#   'visit_id': 166,
#   'billed_amount': 88539.01,
#   'approved_amount': 79542.47,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-05-30'},
#  {'bill_id': 167,
#   'visit_id': 167,
#   'billed_amount': 20888.47,
#   'approved_amount': 17963.61,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-12-21'},
#  {'bill_id': 168,
#   'visit_id': 168,
#   'billed_amount': 33737.44,
#   'approved_amount': 31308.84,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-28'},
#  {'bill_id': 169,
#   'visit_id': 169,
#   'billed_amount': 17361.69,
#   'approved_amount': 17272.02,
#   'claim_status': 'Paid',
#   'payment_days': 46.0,
#   'billing_date': '2025-08-30'},
#  {'bill_id': 170,
#   'visit_id': 170,
#   'billed_amount': 36930.26,
#   'approved_amount': 35611.88,
#   'claim_status': 'Paid',
#   'payment_days': 38.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 171,
#   'visit_id': 171,
#   'billed_amount': 56299.65,
#   'approved_amount': 54187.14,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 172,
#   'visit_id': 172,
#   'billed_amount': 16032.41,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-27'},
#  {'bill_id': 173,
#   'visit_id': 173,
#   'billed_amount': 11626.85,
#   'approved_amount': 10322.64,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-12-09'},
#  {'bill_id': 174,
#   'visit_id': 174,
#   'billed_amount': 53067.32,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-07-27'},
#  {'bill_id': 175,
#   'visit_id': 175,
#   'billed_amount': 66718.54,
#   'approved_amount': 59451.6,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-08-30'},
#  {'bill_id': 176,
#   'visit_id': 176,
#   'billed_amount': 18829.33,
#   'approved_amount': 16093.1,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-11-24'},
#  {'bill_id': 177,
#   'visit_id': 177,
#   'billed_amount': 44075.31,
#   'approved_amount': 21016.02,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-10'},
#  {'bill_id': 178,
#   'visit_id': 178,
#   'billed_amount': 6870.26,
#   'approved_amount': 5853.71,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 179,
#   'visit_id': 179,
#   'billed_amount': 5884.1,
#   'approved_amount': 5607.31,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 180,
#   'visit_id': 180,
#   'billed_amount': 47205.2,
#   'approved_amount': 4974.37,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-07'},
#  {'bill_id': 181,
#   'visit_id': 181,
#   'billed_amount': 6613.62,
#   'approved_amount': 6328.23,
#   'claim_status': 'Paid',
#   'payment_days': 37.0,
#   'billing_date': '2025-12-26'},
#  {'bill_id': 182,
#   'visit_id': 182,
#   'billed_amount': 500.0,
#   'approved_amount': 440.64,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-12-21'},
#  {'bill_id': 183,
#   'visit_id': 183,
#   'billed_amount': 45369.61,
#   'approved_amount': 43657.0,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 184,
#   'visit_id': 184,
#   'billed_amount': 16454.4,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-19'},
#  {'bill_id': 185,
#   'visit_id': 185,
#   'billed_amount': 21135.38,
#   'approved_amount': 6448.82,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-22'},
#  {'bill_id': 186,
#   'visit_id': 186,
#   'billed_amount': 8601.97,
#   'approved_amount': 331.61,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-24'},
#  {'bill_id': 187,
#   'visit_id': 187,
#   'billed_amount': 33286.24,
#   'approved_amount': 2404.2,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-04-22'},
#  {'bill_id': 188,
#   'visit_id': 188,
#   'billed_amount': 24013.27,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-05'},
#  {'bill_id': 189,
#   'visit_id': 189,
#   'billed_amount': 88539.01,
#   'approved_amount': 78922.61,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-11-02'},
#  {'bill_id': 190,
#   'visit_id': 190,
#   'billed_amount': 33836.26,
#   'approved_amount': 30572.81,
#   'claim_status': 'Paid',
#   'payment_days': 46.0,
#   'billing_date': '2025-12-12'},
#  {'bill_id': 191,
#   'visit_id': 191,
#   'billed_amount': 49553.58,
#   'approved_amount': 46473.34,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2025-09-21'},
#  {'bill_id': 192,
#   'visit_id': 192,
#   'billed_amount': 88539.01,
#   'approved_amount': 78521.1,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-12-17'},
#  {'bill_id': 193,
#   'visit_id': 193,
#   'billed_amount': 10521.98,
#   'approved_amount': 9682.53,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-11-24'},
#  {'bill_id': 194,
#   'visit_id': 194,
#   'billed_amount': 24730.44,
#   'approved_amount': 24536.9,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-09-02'},
#  {'bill_id': 195,
#   'visit_id': 195,
#   'billed_amount': 9293.3,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-03'},
#  {'bill_id': 196,
#   'visit_id': 196,
#   'billed_amount': 15817.94,
#   'approved_amount': 14087.19,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2025-03-30'},
#  {'bill_id': 197,
#   'visit_id': 197,
#   'billed_amount': 19618.14,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 198,
#   'visit_id': 198,
#   'billed_amount': 44440.43,
#   'approved_amount': 40282.47,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2026-01-19'},
#  {'bill_id': 199,
#   'visit_id': 199,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'bill_id': 200,
#   'visit_id': 200,
#   'billed_amount': 45891.64,
#   'approved_amount': 44660.81,
#   'claim_status': 'Paid',
#   'payment_days': 43.0,
#   'billing_date': '2025-12-27'},
#  {'bill_id': 201,
#   'visit_id': 201,
#   'billed_amount': 15433.32,
#   'approved_amount': 14872.26,
#   'claim_status': 'Paid',
#   'payment_days': 40.0,
#   'billing_date': '2025-08-20'},
#  {'bill_id': 202,
#   'visit_id': 202,
#   'billed_amount': 56864.67,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-24'},
#  {'bill_id': 203,
#   'visit_id': 203,
#   'billed_amount': 44517.3,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-05'},
#  {'bill_id': 204,
#   'visit_id': 204,
#   'billed_amount': 88539.01,
#   'approved_amount': 10854.89,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-05'},
#  {'bill_id': 205,
#   'visit_id': 205,
#   'billed_amount': 88539.01,
#   'approved_amount': 6713.98,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-09'},
#  {'bill_id': 206,
#   'visit_id': 206,
#   'billed_amount': 789.66,
#   'approved_amount': 709.06,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-09-30'},
#  {'bill_id': 207,
#   'visit_id': 207,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-30'},
#  {'bill_id': 208,
#   'visit_id': 208,
#   'billed_amount': 13254.09,
#   'approved_amount': 12349.58,
#   'claim_status': 'Paid',
#   'payment_days': 32.0,
#   'billing_date': '2025-12-22'},
#  {'bill_id': 209,
#   'visit_id': 209,
#   'billed_amount': 29948.52,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 53.0,
#   'billing_date': '2025-12-30'},
#  {'bill_id': 210,
#   'visit_id': 210,
#   'billed_amount': 29781.86,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 27.0,
#   'billing_date': '2025-06-15'},
#  {'bill_id': 211,
#   'visit_id': 211,
#   'billed_amount': 7519.63,
#   'approved_amount': 3473.75,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-24'},
#  {'bill_id': 212,
#   'visit_id': 212,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-17'},
#  {'bill_id': 213,
#   'visit_id': 213,
#   'billed_amount': 48148.09,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-26'},
#  {'bill_id': 214,
#   'visit_id': 214,
#   'billed_amount': 61347.15,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-13'},
#  {'bill_id': 215,
#   'visit_id': 215,
#   'billed_amount': 27497.04,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-06'},
#  {'bill_id': 216,
#   'visit_id': 216,
#   'billed_amount': 88539.01,
#   'approved_amount': 3537.11,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-28'},
#  {'bill_id': 217,
#   'visit_id': 217,
#   'billed_amount': 45006.46,
#   'approved_amount': 43510.9,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-12-27'},
#  {'bill_id': 218,
#   'visit_id': 218,
#   'billed_amount': 65553.8,
#   'approved_amount': 65416.06,
#   'claim_status': 'Paid',
#   'payment_days': 23.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 219,
#   'visit_id': 219,
#   'billed_amount': 46371.26,
#   'approved_amount': 46150.66,
#   'claim_status': 'Paid',
#   'payment_days': 51.0,
#   'billing_date': '2025-10-31'},
#  {'bill_id': 220,
#   'visit_id': 220,
#   'billed_amount': 13173.54,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 221,
#   'visit_id': 221,
#   'billed_amount': 38371.01,
#   'approved_amount': 35048.77,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 222,
#   'visit_id': 222,
#   'billed_amount': 29418.0,
#   'approved_amount': 26152.1,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 223,
#   'visit_id': 223,
#   'billed_amount': 68460.7,
#   'approved_amount': 63704.73,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2025-08-17'},
#  {'bill_id': 224,
#   'visit_id': 224,
#   'billed_amount': 15899.52,
#   'approved_amount': 5422.29,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-04'},
#  {'bill_id': 225,
#   'visit_id': 225,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-13'},
#  {'bill_id': 226,
#   'visit_id': 226,
#   'billed_amount': 11379.18,
#   'approved_amount': 739.34,
#   'claim_status': 'Pending',
#   'payment_days': 42.0,
#   'billing_date': '2025-10-06'},
#  {'bill_id': 227,
#   'visit_id': 227,
#   'billed_amount': 88539.01,
#   'approved_amount': 32016.08,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-01'},
#  {'bill_id': 228,
#   'visit_id': 228,
#   'billed_amount': 8572.37,
#   'approved_amount': 661.55,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-08'},
#  {'bill_id': 229,
#   'visit_id': 229,
#   'billed_amount': 28239.6,
#   'approved_amount': 27367.76,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 230,
#   'visit_id': 230,
#   'billed_amount': 50319.24,
#   'approved_amount': 4935.04,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-13'},
#  {'bill_id': 231,
#   'visit_id': 231,
#   'billed_amount': 37167.47,
#   'approved_amount': 32305.17,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 232,
#   'visit_id': 232,
#   'billed_amount': 10144.64,
#   'approved_amount': 9542.1,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-11-08'},
#  {'bill_id': 233,
#   'visit_id': 233,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-06-29'},
#  {'bill_id': 234,
#   'visit_id': 234,
#   'billed_amount': 57473.14,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-09'},
#  {'bill_id': 235,
#   'visit_id': 235,
#   'billed_amount': 44994.88,
#   'approved_amount': 38556.83,
#   'claim_status': 'Paid',
#   'payment_days': 25.0,
#   'billing_date': '2025-06-24'},
#  {'bill_id': 236,
#   'visit_id': 236,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 237,
#   'visit_id': 237,
#   'billed_amount': 44856.13,
#   'approved_amount': 4389.68,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-06-21'},
#  {'bill_id': 238,
#   'visit_id': 238,
#   'billed_amount': 88539.01,
#   'approved_amount': 4231.61,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 239,
#   'visit_id': 239,
#   'billed_amount': 59328.31,
#   'approved_amount': 15732.0,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-08-11'},
#  {'bill_id': 240,
#   'visit_id': 240,
#   'billed_amount': 88539.01,
#   'approved_amount': 4663.46,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 241,
#   'visit_id': 241,
#   'billed_amount': 19715.39,
#   'approved_amount': 7743.29,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-30'},
#  {'bill_id': 242,
#   'visit_id': 242,
#   'billed_amount': 16564.6,
#   'approved_amount': 16542.38,
#   'claim_status': 'Paid',
#   'payment_days': 55.0,
#   'billing_date': '2025-07-07'},
#  {'bill_id': 243,
#   'visit_id': 243,
#   'billed_amount': 36067.14,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 244,
#   'visit_id': 244,
#   'billed_amount': 9926.72,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-28'},
#  {'bill_id': 245,
#   'visit_id': 245,
#   'billed_amount': 74411.79,
#   'approved_amount': 66768.77,
#   'claim_status': 'Paid',
#   'payment_days': 33.0,
#   'billing_date': '2025-12-28'},
#  {'bill_id': 246,
#   'visit_id': 246,
#   'billed_amount': 45286.02,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-05-13'},
#  {'bill_id': 247,
#   'visit_id': 247,
#   'billed_amount': 752.65,
#   'approved_amount': 694.9,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2025-11-14'},
#  {'bill_id': 248,
#   'visit_id': 248,
#   'billed_amount': 43487.7,
#   'approved_amount': 39055.94,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-07-07'},
#  {'bill_id': 249,
#   'visit_id': 249,
#   'billed_amount': 8487.6,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-08-16'},
#  {'bill_id': 250,
#   'visit_id': 250,
#   'billed_amount': 60279.77,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 251,
#   'visit_id': 251,
#   'billed_amount': 88539.01,
#   'approved_amount': 12485.19,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-23'},
#  {'bill_id': 252,
#   'visit_id': 252,
#   'billed_amount': 88539.01,
#   'approved_amount': 75883.43,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2025-12-13'},
#  {'bill_id': 253,
#   'visit_id': 253,
#   'billed_amount': 88539.01,
#   'approved_amount': 32502.5,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-30'},
#  {'bill_id': 254,
#   'visit_id': 254,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 255,
#   'visit_id': 255,
#   'billed_amount': 88539.01,
#   'approved_amount': 85115.33,
#   'claim_status': 'Paid',
#   'payment_days': 33.0,
#   'billing_date': '2025-07-23'},
#  {'bill_id': 256,
#   'visit_id': 256,
#   'billed_amount': 11005.94,
#   'approved_amount': 10509.93,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-09-04'},
#  {'bill_id': 257,
#   'visit_id': 257,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-12'},
#  {'bill_id': 258,
#   'visit_id': 258,
#   'billed_amount': 16087.33,
#   'approved_amount': 1735.87,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 259,
#   'visit_id': 259,
#   'billed_amount': 27862.22,
#   'approved_amount': 25075.36,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2026-01-02'},
#  {'bill_id': 260,
#   'visit_id': 260,
#   'billed_amount': 88539.01,
#   'approved_amount': 29094.46,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-05'},
#  {'bill_id': 261,
#   'visit_id': 261,
#   'billed_amount': 54581.24,
#   'approved_amount': 9765.24,
#   'claim_status': 'Pending',
#   'payment_days': 31.0,
#   'billing_date': '2025-10-09'},
#  {'bill_id': 262,
#   'visit_id': 262,
#   'billed_amount': 35267.0,
#   'approved_amount': 30013.63,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-05-08'},
#  {'bill_id': 263,
#   'visit_id': 263,
#   'billed_amount': 28279.7,
#   'approved_amount': 24462.04,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-11-04'},
#  {'bill_id': 264,
#   'visit_id': 264,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 53.0,
#   'billing_date': '2025-12-18'},
#  {'bill_id': 265,
#   'visit_id': 265,
#   'billed_amount': 31690.16,
#   'approved_amount': 29797.2,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-08-26'},
#  {'bill_id': 266,
#   'visit_id': 266,
#   'billed_amount': 23144.6,
#   'approved_amount': 22978.11,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 267,
#   'visit_id': 267,
#   'billed_amount': 14718.25,
#   'approved_amount': 12585.97,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2026-01-01'},
#  {'bill_id': 268,
#   'visit_id': 268,
#   'billed_amount': 17067.87,
#   'approved_amount': 16273.29,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-10-07'},
#  {'bill_id': 269,
#   'visit_id': 269,
#   'billed_amount': 31715.07,
#   'approved_amount': 27563.22,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-09-21'},
# ...
#   'billing_date': '2025-08-11'},
#  {'bill_id': 912,
#   'visit_id': 912,
#   'billed_amount': 54889.74,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-10'},
#  {'bill_id': 913,
#   'visit_id': 913,
#   'billed_amount': 37357.57,
#   'approved_amount': 32674.83,
#   'claim_status': 'Paid',
#   'payment_days': 54.0,
#   'billing_date': '2025-10-11'},
#  {'bill_id': 914,
#   'visit_id': 914,
#   'billed_amount': 677.15,
#   'approved_amount': 249.62,
#   'claim_status': 'Pending',
#   'payment_days': 38.0,
#   'billing_date': '2025-12-22'},
#  {'bill_id': 915,
#   'visit_id': 915,
#   'billed_amount': 17096.23,
#   'approved_amount': 15579.97,
#   'claim_status': 'Paid',
#   'payment_days': 48.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 916,
#   'visit_id': 916,
#   'billed_amount': 80538.33,
#   'approved_amount': 2215.94,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-10-23'},
#  {'bill_id': 917,
#   'visit_id': 917,
#   'billed_amount': 2741.6,
#   'approved_amount': 238.26,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-30'},
#  {'bill_id': 918,
#   'visit_id': 918,
#   'billed_amount': 3843.93,
#   'approved_amount': 3517.35,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2025-09-06'},
#  {'bill_id': 919,
#   'visit_id': 919,
#   'billed_amount': 36984.84,
#   'approved_amount': 33143.92,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-12-05'},
#  {'bill_id': 920,
#   'visit_id': 920,
#   'billed_amount': 88539.01,
#   'approved_amount': 80132.1,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 921,
#   'visit_id': 921,
#   'billed_amount': 88539.01,
#   'approved_amount': 4434.53,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-09-17'},
#  {'bill_id': 922,
#   'visit_id': 922,
#   'billed_amount': 40627.87,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-27'},
#  {'bill_id': 923,
#   'visit_id': 923,
#   'billed_amount': 56136.95,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 55.0,
#   'billing_date': '2025-08-27'},
#  {'bill_id': 924,
#   'visit_id': 924,
#   'billed_amount': 42407.0,
#   'approved_amount': 42247.37,
#   'claim_status': 'Paid',
#   'payment_days': 42.0,
#   'billing_date': '2025-09-24'},
#  {'bill_id': 925,
#   'visit_id': 925,
#   'billed_amount': 23325.39,
#   'approved_amount': 22652.44,
#   'claim_status': 'Paid',
#   'payment_days': 34.0,
#   'billing_date': '2026-01-13'},
#  {'bill_id': 926,
#   'visit_id': 926,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-10'},
#  {'bill_id': 927,
#   'visit_id': 927,
#   'billed_amount': 6132.87,
#   'approved_amount': 5705.31,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-10-25'},
#  {'bill_id': 928,
#   'visit_id': 928,
#   'billed_amount': 7250.12,
#   'approved_amount': 6291.75,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-08-02'},
#  {'bill_id': 929,
#   'visit_id': 929,
#   'billed_amount': 39014.02,
#   'approved_amount': 36898.81,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 930,
#   'visit_id': 930,
#   'billed_amount': 66371.61,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 931,
#   'visit_id': 931,
#   'billed_amount': 66788.73,
#   'approved_amount': 64923.12,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 932,
#   'visit_id': 932,
#   'billed_amount': 16710.74,
#   'approved_amount': 16698.24,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 933,
#   'visit_id': 933,
#   'billed_amount': 7608.39,
#   'approved_amount': 6655.43,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-11-23'},
#  {'bill_id': 934,
#   'visit_id': 934,
#   'billed_amount': 21993.98,
#   'approved_amount': 19308.74,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2025-12-06'},
#  {'bill_id': 935,
#   'visit_id': 935,
#   'billed_amount': 5526.13,
#   'approved_amount': 5217.92,
#   'claim_status': 'Paid',
#   'payment_days': 29.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 936,
#   'visit_id': 936,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-09-30'},
#  {'bill_id': 937,
#   'visit_id': 937,
#   'billed_amount': 28123.18,
#   'approved_amount': 24993.1,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-04-24'},
#  {'bill_id': 938,
#   'visit_id': 938,
#   'billed_amount': 11999.83,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-04'},
#  {'bill_id': 939,
#   'visit_id': 939,
#   'billed_amount': 26261.63,
#   'approved_amount': 10558.83,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-20'},
#  {'bill_id': 940,
#   'visit_id': 940,
#   'billed_amount': 23002.71,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 941,
#   'visit_id': 941,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 942,
#   'visit_id': 942,
#   'billed_amount': 47749.09,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-07-25'},
#  {'bill_id': 943,
#   'visit_id': 943,
#   'billed_amount': 13727.6,
#   'approved_amount': 1962.27,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-07-08'},
#  {'bill_id': 944,
#   'visit_id': 944,
#   'billed_amount': 25142.2,
#   'approved_amount': 2932.28,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 945,
#   'visit_id': 945,
#   'billed_amount': 10615.15,
#   'approved_amount': 10448.12,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-07-17'},
#  {'bill_id': 946,
#   'visit_id': 946,
#   'billed_amount': 17102.45,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-10-19'},
#  {'bill_id': 947,
#   'visit_id': 947,
#   'billed_amount': 83431.97,
#   'approved_amount': 81668.39,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-04-24'},
#  {'bill_id': 948,
#   'visit_id': 948,
#   'billed_amount': 21907.33,
#   'approved_amount': 21539.61,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-05-12'},
#  {'bill_id': 949,
#   'visit_id': 949,
#   'billed_amount': 8473.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 48.0,
#   'billing_date': '2025-12-31'},
#  {'bill_id': 950,
#   'visit_id': 950,
#   'billed_amount': 88539.01,
#   'approved_amount': 19283.62,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-04'},
#  {'bill_id': 951,
#   'visit_id': 951,
#   'billed_amount': 9116.26,
#   'approved_amount': 8295.69,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-05-09'},
#  {'bill_id': 952,
#   'visit_id': 952,
#   'billed_amount': 31752.57,
#   'approved_amount': 27864.13,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2025-11-04'},
#  {'bill_id': 953,
#   'visit_id': 953,
#   'billed_amount': 35612.19,
#   'approved_amount': 6567.72,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-23'},
#  {'bill_id': 954,
#   'visit_id': 954,
#   'billed_amount': 33325.14,
#   'approved_amount': 29732.24,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2025-05-22'},
#  {'bill_id': 955,
#   'visit_id': 955,
#   'billed_amount': 6185.73,
#   'approved_amount': 5599.68,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-06-03'},
#  {'bill_id': 956,
#   'visit_id': 956,
#   'billed_amount': 17062.98,
#   'approved_amount': 14864.38,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-10-13'},
#  {'bill_id': 957,
#   'visit_id': 957,
#   'billed_amount': 14165.92,
#   'approved_amount': 13022.18,
#   'claim_status': 'Paid',
#   'payment_days': 31.0,
#   'billing_date': '2025-10-26'},
#  {'bill_id': 958,
#   'visit_id': 958,
#   'billed_amount': 10116.63,
#   'approved_amount': 8632.34,
#   'claim_status': 'Paid',
#   'payment_days': 46.0,
#   'billing_date': '2026-01-13'},
#  {'bill_id': 959,
#   'visit_id': 959,
#   'billed_amount': 8027.72,
#   'approved_amount': 3807.09,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-11-28'},
#  {'bill_id': 960,
#   'visit_id': 960,
#   'billed_amount': 28320.02,
#   'approved_amount': 13724.82,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 961,
#   'visit_id': 961,
#   'billed_amount': 52062.78,
#   'approved_amount': 24379.44,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-30'},
#  {'bill_id': 962,
#   'visit_id': 962,
#   'billed_amount': 7220.77,
#   'approved_amount': 6523.72,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2025-08-18'},
#  {'bill_id': 963,
#   'visit_id': 963,
#   'billed_amount': 80438.02,
#   'approved_amount': 69813.62,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-11-04'},
#  {'bill_id': 964,
#   'visit_id': 964,
#   'billed_amount': 14977.44,
#   'approved_amount': 12752.69,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-10'},
#  {'bill_id': 965,
#   'visit_id': 965,
#   'billed_amount': 88539.01,
#   'approved_amount': 82226.07,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-12-20'},
#  {'bill_id': 966,
#   'visit_id': 966,
#   'billed_amount': 17672.27,
#   'approved_amount': 15138.39,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-10-24'},
#  {'bill_id': 967,
#   'visit_id': 967,
#   'billed_amount': 13698.87,
#   'approved_amount': 4329.39,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 968,
#   'visit_id': 968,
#   'billed_amount': 36937.65,
#   'approved_amount': 31735.36,
#   'claim_status': 'Paid',
#   'payment_days': 38.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 969,
#   'visit_id': 969,
#   'billed_amount': 40035.94,
#   'approved_amount': 19555.16,
#   'claim_status': 'Pending',
#   'payment_days': 33.0,
#   'billing_date': '2025-12-17'},
#  {'bill_id': 970,
#   'visit_id': 970,
#   'billed_amount': 52258.57,
#   'approved_amount': 44439.64,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2025-05-28'},
#  {'bill_id': 971,
#   'visit_id': 971,
#   'billed_amount': 11388.47,
#   'approved_amount': 234.99,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-04-28'},
#  {'bill_id': 972,
#   'visit_id': 972,
#   'billed_amount': 15952.63,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 973,
#   'visit_id': 973,
#   'billed_amount': 63186.14,
#   'approved_amount': 61984.82,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-08'},
#  {'bill_id': 974,
#   'visit_id': 974,
#   'billed_amount': 6674.27,
#   'approved_amount': 6388.85,
#   'claim_status': 'Paid',
#   'payment_days': 46.0,
#   'billing_date': '2025-11-27'},
#  {'bill_id': 975,
#   'visit_id': 975,
#   'billed_amount': 88539.01,
#   'approved_amount': 10811.31,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-12'},
#  {'bill_id': 976,
#   'visit_id': 976,
#   'billed_amount': 14999.63,
#   'approved_amount': 14815.21,
#   'claim_status': 'Paid',
#   'payment_days': 32.0,
#   'billing_date': '2025-10-04'},
#  {'bill_id': 977,
#   'visit_id': 977,
#   'billed_amount': 978.47,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 978,
#   'visit_id': 978,
#   'billed_amount': 45835.56,
#   'approved_amount': 44994.31,
#   'claim_status': 'Paid',
#   'payment_days': 55.0,
#   'billing_date': '2026-01-20'},
#  {'bill_id': 979,
#   'visit_id': 979,
#   'billed_amount': 15965.26,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-12-27'},
#  {'bill_id': 980,
#   'visit_id': 980,
#   'billed_amount': 11104.53,
#   'approved_amount': 9600.14,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-10-18'},
#  {'bill_id': 981,
#   'visit_id': 981,
#   'billed_amount': 43812.11,
#   'approved_amount': 38679.54,
#   'claim_status': 'Paid',
#   'payment_days': 43.0,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 982,
#   'visit_id': 982,
#   'billed_amount': 88539.01,
#   'approved_amount': 80733.36,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2025-11-10'},
#  {'bill_id': 983,
#   'visit_id': 983,
#   'billed_amount': 18850.51,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 27.0,
#   'billing_date': '2026-01-13'},
#  {'bill_id': 984,
#   'visit_id': 984,
#   'billed_amount': 27769.06,
#   'approved_amount': 27629.14,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-09-26'},
#  {'bill_id': 985,
#   'visit_id': 985,
#   'billed_amount': 21231.96,
#   'approved_amount': 20668.64,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-10-06'},
#  {'bill_id': 986,
#   'visit_id': 986,
#   'billed_amount': 56401.94,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-09-25'},
#  {'bill_id': 987,
#   'visit_id': 987,
#   'billed_amount': 31882.06,
#   'approved_amount': 31495.39,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-04-05'},
#  {'bill_id': 988,
#   'visit_id': 988,
#   'billed_amount': 41827.23,
#   'approved_amount': 40995.71,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2025-04-22'},
#  {'bill_id': 989,
#   'visit_id': 989,
#   'billed_amount': 48531.78,
#   'approved_amount': 47672.15,
#   'claim_status': 'Paid',
#   'payment_days': 23.0,
#   'billing_date': '2025-07-22'},
#  {'bill_id': 990,
#   'visit_id': 990,
#   'billed_amount': 24026.67,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-06-21'},
#  {'bill_id': 991,
#   'visit_id': 991,
#   'billed_amount': 88539.01,
#   'approved_amount': 82183.99,
#   'claim_status': 'Paid',
#   'payment_days': 39.0,
#   'billing_date': '2025-06-12'},
#  {'bill_id': 992,
#   'visit_id': 992,
#   'billed_amount': 64192.43,
#   'approved_amount': 63910.4,
#   'claim_status': 'Paid',
#   'payment_days': 36.0,
#   'billing_date': '2025-12-18'},
#  {'bill_id': 993,
#   'visit_id': 993,
#   'billed_amount': 61255.48,
#   'approved_amount': 60832.49,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-04-11'},
#  {'bill_id': 994,
#   'visit_id': 994,
#   'billed_amount': 44807.85,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-01'},
#  {'bill_id': 995,
#   'visit_id': 995,
#   'billed_amount': 9089.34,
#   'approved_amount': 8602.04,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2025-10-26'},
#  {'bill_id': 996,
#   'visit_id': 996,
#   'billed_amount': 44243.95,
#   'approved_amount': 38775.6,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 997,
#   'visit_id': 997,
#   'billed_amount': 88539.01,
#   'approved_amount': 86136.67,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2025-06-25'},
#  {'bill_id': 998,
#   'visit_id': 998,
#   'billed_amount': 14749.8,
#   'approved_amount': 13831.03,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2025-07-12'},
#  {'bill_id': 999,
#   'visit_id': 999,
#   'billed_amount': 11837.89,
#   'approved_amount': 10369.28,
#   'claim_status': 'Paid',
#   'payment_days': 23.0,
#   'billing_date': '2025-08-09'},
#  {'bill_id': 1000,
#   'visit_id': 1000,
#   'billed_amount': 9897.97,
#   'approved_amount': 9315.17,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-11-29'},
#  ...]

# %%
len(billing_data)
# Out:
# 25000

# %%
visits_data= visits.to_dict(orient="records")
visits_data
# Out:
# [{'visit_id': 1,
#   'patient_id': 1,
#   'visit_date': '10/16/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.15,
#   'risk_score': 'Low',
#   'doctor_id': 186},
#  {'visit_id': 2,
#   'patient_id': 1,
#   'visit_date': '12/9/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 39.98,
#   'risk_score': 'High',
#   'doctor_id': 149},
#  {'visit_id': 3,
#   'patient_id': 1,
#   'visit_date': '10/29/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.97,
#   'risk_score': 'Medium',
#   'doctor_id': 122},
#  {'visit_id': 4,
#   'patient_id': 1,
#   'visit_date': '7/31/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.32,
#   'risk_score': 'Medium',
#   'doctor_id': 193},
#  {'visit_id': 5,
#   'patient_id': 1,
#   'visit_date': '8/2/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 41.43,
#   'risk_score': 'High',
#   'doctor_id': 141},
#  {'visit_id': 6,
#   'patient_id': 1,
#   'visit_date': '9/19/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.72,
#   'risk_score': 'Medium',
#   'doctor_id': 109},
#  {'visit_id': 7,
#   'patient_id': 2,
#   'visit_date': '1/2/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 4.46,
#   'risk_score': 'Medium',
#   'doctor_id': 131},
#  {'visit_id': 8,
#   'patient_id': 2,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.63,
#   'risk_score': 'Low',
#   'doctor_id': 105},
#  {'visit_id': 9,
#   'patient_id': 2,
#   'visit_date': '1/10/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.05,
#   'risk_score': 'Low',
#   'doctor_id': 142},
#  {'visit_id': 10,
#   'patient_id': 2,
#   'visit_date': '1/19/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 41.34,
#   'risk_score': 'Low',
#   'doctor_id': 195},
#  {'visit_id': 11,
#   'patient_id': 3,
#   'visit_date': '11/6/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 35.86,
#   'risk_score': 'High',
#   'doctor_id': 111},
#  {'visit_id': 12,
#   'patient_id': 3,
#   'visit_date': '6/21/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.16,
#   'risk_score': 'Medium',
#   'doctor_id': 180},
#  {'visit_id': 13,
#   'patient_id': 3,
#   'visit_date': '12/13/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 76.46,
#   'risk_score': 'High',
#   'doctor_id': 153},
#  {'visit_id': 14,
#   'patient_id': 3,
#   'visit_date': '4/8/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 73.59,
#   'risk_score': 'High',
#   'doctor_id': 197},
#  {'visit_id': 15,
#   'patient_id': 4,
#   'visit_date': '9/11/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.8,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 16,
#   'patient_id': 4,
#   'visit_date': '4/25/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 34.39,
#   'risk_score': 'High',
#   'doctor_id': 178},
#  {'visit_id': 17,
#   'patient_id': 4,
#   'visit_date': '6/17/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.16,
#   'risk_score': 'Medium',
#   'doctor_id': 122},
#  {'visit_id': 18,
#   'patient_id': 4,
#   'visit_date': '8/24/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 37.91,
#   'risk_score': 'Medium',
#   'doctor_id': 153},
#  {'visit_id': 19,
#   'patient_id': 4,
#   'visit_date': '11/12/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 65.1,
#   'risk_score': 'High',
#   'doctor_id': 175},
#  {'visit_id': 20,
#   'patient_id': 4,
#   'visit_date': '12/12/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.95,
#   'risk_score': 'Medium',
#   'doctor_id': 184},
#  {'visit_id': 21,
#   'patient_id': 4,
#   'visit_date': '3/24/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 52.76,
#   'risk_score': 'High',
#   'doctor_id': 139},
#  {'visit_id': 22,
#   'patient_id': 5,
#   'visit_date': '7/5/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.88,
#   'risk_score': 'Medium',
#   'doctor_id': 186},
#  {'visit_id': 23,
#   'patient_id': 5,
#   'visit_date': '8/26/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 66.89,
#   'risk_score': 'High',
#   'doctor_id': 147},
#  {'visit_id': 24,
#   'patient_id': 5,
#   'visit_date': '8/26/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 72.31,
#   'risk_score': 'High',
#   'doctor_id': 128},
#  {'visit_id': 25,
#   'patient_id': 6,
#   'visit_date': '10/10/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.88,
#   'risk_score': 'Medium',
#   'doctor_id': 187},
#  {'visit_id': 26,
#   'patient_id': 6,
#   'visit_date': '2/20/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.2,
#   'risk_score': 'Low',
#   'doctor_id': 110},
#  {'visit_id': 27,
#   'patient_id': 6,
#   'visit_date': '7/16/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 64.51,
#   'risk_score': 'High',
#   'doctor_id': 198},
#  {'visit_id': 28,
#   'patient_id': 6,
#   'visit_date': '7/2/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.23,
#   'risk_score': 'Medium',
#   'doctor_id': 110},
#  {'visit_id': 29,
#   'patient_id': 7,
#   'visit_date': '10/4/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.82,
#   'risk_score': 'Low',
#   'doctor_id': 144},
#  {'visit_id': 30,
#   'patient_id': 7,
#   'visit_date': '6/18/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.16,
#   'risk_score': 'Low',
#   'doctor_id': 190},
#  {'visit_id': 31,
#   'patient_id': 7,
#   'visit_date': '10/5/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 35.63,
#   'risk_score': 'Medium',
#   'doctor_id': 145},
#  {'visit_id': 32,
#   'patient_id': 7,
#   'visit_date': '3/10/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 50.98,
#   'risk_score': 'Medium',
#   'doctor_id': 181},
#  {'visit_id': 33,
#   'patient_id': 7,
#   'visit_date': '3/31/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.56,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 34,
#   'patient_id': 7,
#   'visit_date': '12/27/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 30.18,
#   'risk_score': 'Medium',
#   'doctor_id': 146},
#  {'visit_id': 35,
#   'patient_id': 8,
#   'visit_date': '5/26/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.06,
#   'risk_score': 'Low',
#   'doctor_id': 180},
#  {'visit_id': 36,
#   'patient_id': 8,
#   'visit_date': '10/23/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.95,
#   'risk_score': 'Low',
#   'doctor_id': 101},
#  {'visit_id': 37,
#   'patient_id': 8,
#   'visit_date': '8/24/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.05,
#   'risk_score': 'Low',
#   'doctor_id': 126},
#  {'visit_id': 38,
#   'patient_id': 9,
#   'visit_date': '10/17/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 73.67,
#   'risk_score': 'High',
#   'doctor_id': 192},
#  {'visit_id': 39,
#   'patient_id': 9,
#   'visit_date': '8/14/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 69.01,
#   'risk_score': 'High',
#   'doctor_id': 122},
#  {'visit_id': 40,
#   'patient_id': 9,
#   'visit_date': '5/29/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.53,
#   'risk_score': 'Medium',
#   'doctor_id': 170},
#  {'visit_id': 41,
#   'patient_id': 9,
#   'visit_date': '8/27/2025',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 156},
#  {'visit_id': 42,
#   'patient_id': 9,
#   'visit_date': '4/3/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 29.46,
#   'risk_score': 'High',
#   'doctor_id': 194},
#  {'visit_id': 43,
#   'patient_id': 9,
#   'visit_date': '11/14/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.24,
#   'risk_score': 'High',
#   'doctor_id': 171},
#  {'visit_id': 44,
#   'patient_id': 9,
#   'visit_date': '1/6/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 75.09,
#   'risk_score': 'High',
#   'doctor_id': 175},
#  {'visit_id': 45,
#   'patient_id': 9,
#   'visit_date': '4/12/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 43.25,
#   'risk_score': 'High',
#   'doctor_id': 135},
#  {'visit_id': 46,
#   'patient_id': 9,
#   'visit_date': '9/8/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 158},
#  {'visit_id': 47,
#   'patient_id': 9,
#   'visit_date': '11/16/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.32,
#   'risk_score': 'Medium',
#   'doctor_id': 121},
#  {'visit_id': 48,
#   'patient_id': 10,
#   'visit_date': '12/19/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 52.44,
#   'risk_score': 'High',
#   'doctor_id': 146},
#  {'visit_id': 49,
#   'patient_id': 10,
#   'visit_date': '9/6/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.55,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 50,
#   'patient_id': 10,
#   'visit_date': '10/18/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.65,
#   'risk_score': 'Low',
#   'doctor_id': 149},
#  {'visit_id': 51,
#   'patient_id': 10,
#   'visit_date': '7/10/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.94,
#   'risk_score': 'Low',
#   'doctor_id': 138},
#  {'visit_id': 52,
#   'patient_id': 10,
#   'visit_date': '8/8/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.27,
#   'risk_score': 'Medium',
#   'doctor_id': 164},
#  {'visit_id': 53,
#   'patient_id': 10,
#   'visit_date': '12/18/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.84,
#   'risk_score': 'Low',
#   'doctor_id': 157},
#  {'visit_id': 54,
#   'patient_id': 11,
#   'visit_date': '4/4/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.51,
#   'risk_score': 'Low',
#   'doctor_id': 170},
#  {'visit_id': 55,
#   'patient_id': 11,
#   'visit_date': '1/16/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.73,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 56,
#   'patient_id': 11,
#   'visit_date': '11/1/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.95,
#   'risk_score': 'Low',
#   'doctor_id': 180},
#  {'visit_id': 57,
#   'patient_id': 11,
#   'visit_date': '1/16/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.5,
#   'risk_score': 'Low',
#   'doctor_id': 154},
#  {'visit_id': 58,
#   'patient_id': 11,
#   'visit_date': '6/19/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.96,
#   'risk_score': 'Low',
#   'doctor_id': 112},
#  {'visit_id': 59,
#   'patient_id': 11,
#   'visit_date': '10/15/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.93,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 60,
#   'patient_id': 11,
#   'visit_date': '3/18/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.35,
#   'risk_score': 'Low',
#   'doctor_id': 100},
#  {'visit_id': 61,
#   'patient_id': 11,
#   'visit_date': '12/29/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.39,
#   'risk_score': 'Low',
#   'doctor_id': 136},
#  {'visit_id': 62,
#   'patient_id': 11,
#   'visit_date': '10/20/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.06,
#   'risk_score': 'Low',
#   'doctor_id': 148},
#  {'visit_id': 63,
#   'patient_id': 12,
#   'visit_date': '10/11/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 45.76,
#   'risk_score': 'Low',
#   'doctor_id': 146},
#  {'visit_id': 64,
#   'patient_id': 12,
#   'visit_date': '10/27/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.98,
#   'risk_score': 'Low',
#   'doctor_id': 107},
#  {'visit_id': 65,
#   'patient_id': 12,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 59.6,
#   'risk_score': 'High',
#   'doctor_id': 112},
#  {'visit_id': 66,
#   'patient_id': 12,
#   'visit_date': '9/4/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.26,
#   'risk_score': 'Low',
#   'doctor_id': 118},
#  {'visit_id': 67,
#   'patient_id': 12,
#   'visit_date': '1/20/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.09,
#   'risk_score': 'Low',
#   'doctor_id': 115},
#  {'visit_id': 68,
#   'patient_id': 12,
#   'visit_date': '9/10/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.43,
#   'risk_score': 'Low',
#   'doctor_id': 182},
#  {'visit_id': 69,
#   'patient_id': 12,
#   'visit_date': '12/6/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.9,
#   'risk_score': 'Low',
#   'doctor_id': 128},
#  {'visit_id': 70,
#   'patient_id': 12,
#   'visit_date': '11/3/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.98,
#   'risk_score': 'Low',
#   'doctor_id': 195},
#  {'visit_id': 71,
#   'patient_id': 13,
#   'visit_date': '11/8/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.43,
#   'risk_score': 'Low',
#   'doctor_id': 124},
#  {'visit_id': 72,
#   'patient_id': 13,
#   'visit_date': '10/11/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.99,
#   'risk_score': 'Low',
#   'doctor_id': 149},
#  {'visit_id': 73,
#   'patient_id': 13,
#   'visit_date': '10/27/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 37.07,
#   'risk_score': 'Low',
#   'doctor_id': 174},
#  {'visit_id': 74,
#   'patient_id': 14,
#   'visit_date': '10/4/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.74,
#   'risk_score': 'Low',
#   'doctor_id': 109},
#  {'visit_id': 75,
#   'patient_id': 14,
#   'visit_date': '10/22/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.43,
#   'risk_score': 'Low',
#   'doctor_id': 176},
#  {'visit_id': 76,
#   'patient_id': 14,
#   'visit_date': '7/7/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.85,
#   'risk_score': 'Low',
#   'doctor_id': 185},
#  {'visit_id': 77,
#   'patient_id': 14,
#   'visit_date': '12/12/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 34.09,
#   'risk_score': 'High',
#   'doctor_id': 156},
#  {'visit_id': 78,
#   'patient_id': 14,
#   'visit_date': '6/5/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 185},
#  {'visit_id': 79,
#   'patient_id': 15,
#   'visit_date': '7/19/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.83,
#   'risk_score': 'Low',
#   'doctor_id': 162},
#  {'visit_id': 80,
#   'patient_id': 15,
#   'visit_date': '8/3/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.77,
#   'risk_score': 'Low',
#   'doctor_id': 167},
#  {'visit_id': 81,
#   'patient_id': 15,
#   'visit_date': '6/3/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.68,
#   'risk_score': 'Low',
#   'doctor_id': 198},
#  {'visit_id': 82,
#   'patient_id': 15,
#   'visit_date': '1/16/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.75,
#   'risk_score': 'Low',
#   'doctor_id': 197},
#  {'visit_id': 83,
#   'patient_id': 15,
#   'visit_date': '6/16/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 40.13,
#   'risk_score': 'Medium',
#   'doctor_id': 175},
#  {'visit_id': 84,
#   'patient_id': 15,
#   'visit_date': '9/28/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.7,
#   'risk_score': 'Low',
#   'doctor_id': 198},
#  {'visit_id': 85,
#   'patient_id': 15,
#   'visit_date': '6/23/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.24,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 86,
#   'patient_id': 15,
#   'visit_date': '8/11/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.36,
#   'risk_score': 'Low',
#   'doctor_id': 133},
#  {'visit_id': 87,
#   'patient_id': 16,
#   'visit_date': '12/19/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.19,
#   'risk_score': 'Low',
#   'doctor_id': 187},
#  {'visit_id': 88,
#   'patient_id': 16,
#   'visit_date': '1/17/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.6,
#   'risk_score': 'Low',
#   'doctor_id': 175},
#  {'visit_id': 89,
#   'patient_id': 16,
#   'visit_date': '12/10/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.84,
#   'risk_score': 'Medium',
#   'doctor_id': 145},
#  {'visit_id': 90,
#   'patient_id': 16,
#   'visit_date': '11/16/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.2,
#   'risk_score': 'Low',
#   'doctor_id': 132},
#  {'visit_id': 91,
#   'patient_id': 16,
#   'visit_date': '12/15/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.49,
#   'risk_score': 'Medium',
#   'doctor_id': 116},
#  {'visit_id': 92,
#   'patient_id': 17,
#   'visit_date': '1/20/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.23,
#   'risk_score': 'Low',
#   'doctor_id': 189},
#  {'visit_id': 93,
#   'patient_id': 17,
#   'visit_date': '1/4/2026',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 11.34,
#   'risk_score': 'Low',
#   'doctor_id': 195},
#  {'visit_id': 94,
#   'patient_id': 17,
#   'visit_date': '1/2/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 4.27,
#   'risk_score': 'Low',
#   'doctor_id': 143},
#  {'visit_id': 95,
#   'patient_id': 18,
#   'visit_date': '8/11/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.08,
#   'risk_score': 'Low',
#   'doctor_id': 120},
#  {'visit_id': 96,
#   'patient_id': 18,
#   'visit_date': '9/16/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.58,
#   'risk_score': 'Low',
#   'doctor_id': 171},
#  {'visit_id': 97,
#   'patient_id': 18,
#   'visit_date': '9/2/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 46.98,
#   'risk_score': 'High',
#   'doctor_id': 143},
#  {'visit_id': 98,
#   'patient_id': 19,
#   'visit_date': '8/21/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.53,
#   'risk_score': 'Low',
#   'doctor_id': 155},
#  {'visit_id': 99,
#   'patient_id': 19,
#   'visit_date': '11/8/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.04,
#   'risk_score': 'Medium',
#   'doctor_id': 148},
#  {'visit_id': 100,
#   'patient_id': 19,
#   'visit_date': '10/2/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 27.02,
#   'risk_score': 'High',
#   'doctor_id': 123},
#  {'visit_id': 101,
#   'patient_id': 19,
#   'visit_date': '7/13/2025',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 34.8,
#   'risk_score': 'High',
#   'doctor_id': 136},
#  {'visit_id': 102,
#   'patient_id': 19,
#   'visit_date': '8/30/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.99,
#   'risk_score': 'Low',
#   'doctor_id': 175},
#  {'visit_id': 103,
#   'patient_id': 19,
#   'visit_date': '9/18/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.58,
#   'risk_score': 'Low',
#   'doctor_id': 162},
#  {'visit_id': 104,
#   'patient_id': 19,
#   'visit_date': '12/20/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.99,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 105,
#   'patient_id': 20,
#   'visit_date': '7/8/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.09,
#   'risk_score': 'Low',
#   'doctor_id': 128},
#  {'visit_id': 106,
#   'patient_id': 20,
#   'visit_date': '11/7/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.3,
#   'risk_score': 'Low',
#   'doctor_id': 195},
#  {'visit_id': 107,
#   'patient_id': 20,
#   'visit_date': '9/20/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.55,
#   'risk_score': 'Low',
#   'doctor_id': 150},
#  {'visit_id': 108,
#   'patient_id': 20,
#   'visit_date': '5/22/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 45.09,
#   'risk_score': 'High',
#   'doctor_id': 105},
#  {'visit_id': 109,
#   'patient_id': 21,
#   'visit_date': '11/2/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.96,
#   'risk_score': 'Medium',
#   'doctor_id': 136},
#  {'visit_id': 110,
#   'patient_id': 21,
#   'visit_date': '9/8/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.87,
#   'risk_score': 'Low',
#   'doctor_id': 183},
#  {'visit_id': 111,
#   'patient_id': 21,
#   'visit_date': '1/4/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.3,
#   'risk_score': 'Low',
#   'doctor_id': 192},
#  {'visit_id': 112,
#   'patient_id': 21,
#   'visit_date': '8/9/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.29,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 113,
#   'patient_id': 22,
#   'visit_date': '1/8/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 7.22,
#   'risk_score': 'Medium',
#   'doctor_id': 115},
#  {'visit_id': 114,
#   'patient_id': 22,
#   'visit_date': '2/26/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 50.56,
#   'risk_score': 'High',
#   'doctor_id': 150},
#  {'visit_id': 115,
#   'patient_id': 22,
#   'visit_date': '8/21/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.04,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 116,
#   'patient_id': 22,
#   'visit_date': '1/12/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.34,
#   'risk_score': 'Low',
#   'doctor_id': 181},
#  {'visit_id': 117,
#   'patient_id': 22,
#   'visit_date': '3/4/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.86,
#   'risk_score': 'Low',
#   'doctor_id': 100},
#  {'visit_id': 118,
#   'patient_id': 22,
#   'visit_date': '8/5/2025',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 55.89,
#   'risk_score': 'Medium',
#   'doctor_id': 162},
#  {'visit_id': 119,
#   'patient_id': 22,
#   'visit_date': '10/9/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.12,
#   'risk_score': 'Low',
#   'doctor_id': 167},
#  {'visit_id': 120,
#   'patient_id': 22,
#   'visit_date': '12/21/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.16,
#   'risk_score': 'Low',
#   'doctor_id': 159},
#  {'visit_id': 121,
#   'patient_id': 22,
#   'visit_date': '1/19/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.46,
#   'risk_score': 'Low',
#   'doctor_id': 166},
#  {'visit_id': 122,
#   'patient_id': 23,
#   'visit_date': '11/6/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.89,
#   'risk_score': 'Low',
#   'doctor_id': 171},
#  {'visit_id': 123,
#   'patient_id': 23,
#   'visit_date': '12/17/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.48,
#   'risk_score': 'Low',
#   'doctor_id': 158},
#  {'visit_id': 124,
#   'patient_id': 23,
#   'visit_date': '12/28/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.6,
#   'risk_score': 'Low',
#   'doctor_id': 125},
#  {'visit_id': 125,
#   'patient_id': 23,
#   'visit_date': '12/15/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 42.94,
#   'risk_score': 'High',
#   'doctor_id': 138},
#  {'visit_id': 126,
#   'patient_id': 23,
#   'visit_date': '12/23/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.46,
#   'risk_score': 'Low',
#   'doctor_id': 116},
#  {'visit_id': 127,
#   'patient_id': 23,
#   'visit_date': '12/28/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.19,
#   'risk_score': 'Low',
#   'doctor_id': 183},
#  {'visit_id': 128,
#   'patient_id': 23,
#   'visit_date': '12/19/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 33.35,
#   'risk_score': 'High',
#   'doctor_id': 150},
#  {'visit_id': 129,
#   'patient_id': 24,
#   'visit_date': '1/19/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 76.58,
#   'risk_score': 'High',
#   'doctor_id': 163},
#  {'visit_id': 130,
#   'patient_id': 24,
#   'visit_date': '1/19/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.83,
#   'risk_score': 'Medium',
#   'doctor_id': 138},
#  {'visit_id': 131,
#   'patient_id': 24,
#   'visit_date': '1/18/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.58,
#   'risk_score': 'Medium',
#   'doctor_id': 119},
#  {'visit_id': 132,
#   'patient_id': 24,
#   'visit_date': '1/19/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 40.71,
#   'risk_score': 'Medium',
#   'doctor_id': 123},
#  {'visit_id': 133,
#   'patient_id': 25,
#   'visit_date': '4/17/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 59.45,
#   'risk_score': 'High',
#   'doctor_id': 144},
#  {'visit_id': 134,
#   'patient_id': 25,
#   'visit_date': '5/2/2025',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 8.07,
#   'risk_score': 'Medium',
#   'doctor_id': 180},
#  {'visit_id': 135,
#   'patient_id': 25,
#   'visit_date': '10/2/2025',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 46.63,
#   'risk_score': 'High',
#   'doctor_id': 190},
#  {'visit_id': 136,
#   'patient_id': 25,
#   'visit_date': '10/1/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 4.83,
#   'risk_score': 'Low',
#   'doctor_id': 110},
#  {'visit_id': 137,
#   'patient_id': 25,
#   'visit_date': '4/5/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.26,
#   'risk_score': 'Low',
#   'doctor_id': 168},
#  {'visit_id': 138,
#   'patient_id': 25,
#   'visit_date': '6/7/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.65,
#   'risk_score': 'Low',
#   'doctor_id': 117},
#  {'visit_id': 139,
#   'patient_id': 26,
#   'visit_date': '8/30/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.46,
#   'risk_score': 'Medium',
#   'doctor_id': 173},
#  {'visit_id': 140,
#   'patient_id': 26,
#   'visit_date': '10/31/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.59,
#   'risk_score': 'Medium',
#   'doctor_id': 125},
#  {'visit_id': 141,
#   'patient_id': 26,
#   'visit_date': '4/16/2025',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.15,
#   'risk_score': 'Medium',
#   'doctor_id': 104},
#  {'visit_id': 142,
#   'patient_id': 26,
#   'visit_date': '4/27/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.66,
#   'risk_score': 'Low',
#   'doctor_id': 163},
#  {'visit_id': 143,
#   'patient_id': 27,
#   'visit_date': '8/8/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.88,
#   'risk_score': 'Low',
#   'doctor_id': 140},
#  {'visit_id': 144,
#   'patient_id': 28,
#   'visit_date': '12/19/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.25,
#   'risk_score': 'Low',
#   'doctor_id': 127},
#  {'visit_id': 145,
#   'patient_id': 28,
#   'visit_date': '7/10/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.11,
#   'risk_score': 'Medium',
#   'doctor_id': 169},
#  {'visit_id': 146,
#   'patient_id': 28,
#   'visit_date': '12/11/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.79,
#   'risk_score': 'Medium',
#   'doctor_id': 151},
#  {'visit_id': 147,
#   'patient_id': 28,
#   'visit_date': '11/8/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.96,
#   'risk_score': 'Low',
#   'doctor_id': 133},
#  {'visit_id': 148,
#   'patient_id': 28,
#   'visit_date': '12/14/2025',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.39,
#   'risk_score': 'Medium',
#   'doctor_id': 154},
#  {'visit_id': 149,
#   'patient_id': 28,
#   'visit_date': '12/3/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.66,
#   'risk_score': 'Medium',
#   'doctor_id': 105},
#  {'visit_id': 150,
#   'patient_id': 28,
#   'visit_date': '9/26/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 63.2,
#   'risk_score': 'High',
#   'doctor_id': 120},
#  {'visit_id': 151,
#   'patient_id': 28,
#   'visit_date': '1/9/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.25,
#   'risk_score': 'Medium',
#   'doctor_id': 161},
#  {'visit_id': 152,
#   'patient_id': 28,
#   'visit_date': '12/17/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 44.79,
#   'risk_score': 'Medium',
#   'doctor_id': 172},
#  {'visit_id': 153,
#   'patient_id': 29,
#   'visit_date': '1/6/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.83,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 154,
#   'patient_id': 29,
#   'visit_date': '1/4/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 42.69,
#   'risk_score': 'High',
#   'doctor_id': 138},
#  {'visit_id': 155,
#   'patient_id': 29,
#   'visit_date': '12/15/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 2.69,
#   'risk_score': 'Low',
#   'doctor_id': 187},
#  {'visit_id': 156,
#   'patient_id': 29,
#   'visit_date': '12/14/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.78,
#   'risk_score': 'Low',
#   'doctor_id': 174},
#  {'visit_id': 157,
#   'patient_id': 29,
#   'visit_date': '12/2/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.92,
#   'risk_score': 'Low',
#   'doctor_id': 199},
#  {'visit_id': 158,
#   'patient_id': 29,
#   'visit_date': '11/1/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.4,
#   'risk_score': 'Low',
#   'doctor_id': 176},
#  {'visit_id': 159,
#   'patient_id': 30,
#   'visit_date': '12/25/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.46,
#   'risk_score': 'Low',
#   'doctor_id': 167},
#  {'visit_id': 160,
#   'patient_id': 30,
#   'visit_date': '10/18/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.95,
#   'risk_score': 'Low',
#   'doctor_id': 156},
#  {'visit_id': 161,
#   'patient_id': 30,
#   'visit_date': '1/4/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.81,
#   'risk_score': 'Low',
#   'doctor_id': 132},
#  {'visit_id': 162,
#   'patient_id': 30,
#   'visit_date': '11/4/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.09,
#   'risk_score': 'Low',
#   'doctor_id': 156},
#  {'visit_id': 163,
#   'patient_id': 30,
#   'visit_date': '12/15/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.98,
#   'risk_score': 'Low',
#   'doctor_id': 199},
#  {'visit_id': 164,
#   'patient_id': 30,
#   'visit_date': '10/25/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.95,
#   'risk_score': 'Low',
#   'doctor_id': 101},
#  {'visit_id': 165,
#   'patient_id': 31,
#   'visit_date': '8/5/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 42.26,
#   'risk_score': 'Medium',
#   'doctor_id': 157},
#  {'visit_id': 166,
#   'patient_id': 31,
#   'visit_date': '5/24/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 67.69,
#   'risk_score': 'High',
#   'doctor_id': 135},
#  {'visit_id': 167,
#   'patient_id': 32,
#   'visit_date': '12/2/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.03,
#   'risk_score': 'High',
#   'doctor_id': 120},
#  {'visit_id': 168,
#   'patient_id': 32,
#   'visit_date': '12/17/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.25,
#   'risk_score': 'Medium',
#   'doctor_id': 150},
#  {'visit_id': 169,
#   'patient_id': 32,
#   'visit_date': '8/3/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.49,
#   'risk_score': 'Medium',
#   'doctor_id': 194},
#  {'visit_id': 170,
#   'patient_id': 32,
#   'visit_date': '1/4/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.03,
#   'risk_score': 'High',
#   'doctor_id': 130},
#  {'visit_id': 171,
#   'patient_id': 33,
#   'visit_date': '1/4/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.68,
#   'risk_score': 'Medium',
#   'doctor_id': 130},
#  {'visit_id': 172,
#   'patient_id': 33,
#   'visit_date': '9/10/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.58,
#   'risk_score': 'Low',
#   'doctor_id': 179},
#  {'visit_id': 173,
#   'patient_id': 33,
#   'visit_date': '11/29/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.06,
#   'risk_score': 'Low',
#   'doctor_id': 165},
#  {'visit_id': 174,
#   'patient_id': 33,
#   'visit_date': '7/15/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.88,
#   'risk_score': 'Medium',
#   'doctor_id': 112},
#  {'visit_id': 175,
#   'patient_id': 33,
#   'visit_date': '8/5/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 39.9,
#   'risk_score': 'Medium',
#   'doctor_id': 147},
#  {'visit_id': 176,
#   'patient_id': 33,
#   'visit_date': '11/22/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.85,
#   'risk_score': 'Medium',
#   'doctor_id': 198},
#  {'visit_id': 177,
#   'patient_id': 34,
#   'visit_date': '12/28/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.27,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 178,
#   'patient_id': 34,
#   'visit_date': '1/17/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.28,
#   'risk_score': 'Low',
#   'doctor_id': 162},
#  {'visit_id': 179,
#   'patient_id': 34,
#   'visit_date': '1/16/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.35,
#   'risk_score': 'Low',
#   'doctor_id': 132},
#  {'visit_id': 180,
#   'patient_id': 34,
#   'visit_date': '12/15/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.42,
#   'risk_score': 'Medium',
#   'doctor_id': 167},
#  {'visit_id': 181,
#   'patient_id': 34,
#   'visit_date': '11/29/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.1,
#   'risk_score': 'Low',
#   'doctor_id': 192},
#  {'visit_id': 182,
#   'patient_id': 34,
#   'visit_date': '11/29/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 144},
#  {'visit_id': 183,
#   'patient_id': 34,
#   'visit_date': '12/30/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.16,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 184,
#   'patient_id': 34,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.04,
#   'risk_score': 'Low',
#   'doctor_id': 173},
#  {'visit_id': 185,
#   'patient_id': 34,
#   'visit_date': '12/12/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.76,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 186,
#   'patient_id': 35,
#   'visit_date': '8/22/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.8,
#   'risk_score': 'Low',
#   'doctor_id': 123},
#  {'visit_id': 187,
#   'patient_id': 35,
#   'visit_date': '4/15/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.6,
#   'risk_score': 'Low',
#   'doctor_id': 152},
#  {'visit_id': 188,
#   'patient_id': 36,
#   'visit_date': '11/30/2025',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.24,
#   'risk_score': 'Medium',
#   'doctor_id': 143},
#  {'visit_id': 189,
#   'patient_id': 36,
#   'visit_date': '10/14/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 61.43,
#   'risk_score': 'High',
#   'doctor_id': 118},
#  {'visit_id': 190,
#   'patient_id': 36,
#   'visit_date': '12/10/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.92,
#   'risk_score': 'Low',
#   'doctor_id': 110},
#  {'visit_id': 191,
#   'patient_id': 36,
#   'visit_date': '9/14/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.59,
#   'risk_score': 'Medium',
#   'doctor_id': 134},
#  {'visit_id': 192,
#   'patient_id': 37,
#   'visit_date': '12/14/2025',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 50.72,
#   'risk_score': 'High',
#   'doctor_id': 191},
#  {'visit_id': 193,
#   'patient_id': 37,
#   'visit_date': '11/12/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.61,
#   'risk_score': 'Low',
#   'doctor_id': 131},
#  {'visit_id': 194,
#   'patient_id': 38,
#   'visit_date': '8/5/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 11.17,
#   'risk_score': 'Medium',
#   'doctor_id': 139},
#  {'visit_id': 195,
#   'patient_id': 38,
#   'visit_date': '6/17/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.78,
#   'risk_score': 'Low',
#   'doctor_id': 191},
#  {'visit_id': 196,
#   'patient_id': 38,
#   'visit_date': '3/19/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.69,
#   'risk_score': 'Low',
#   'doctor_id': 162},
#  {'visit_id': 197,
#   'patient_id': 39,
#   'visit_date': '1/8/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.28,
#   'risk_score': 'Low',
#   'doctor_id': 124},
#  {'visit_id': 198,
#   'patient_id': 39,
#   'visit_date': '1/6/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.94,
#   'risk_score': 'Medium',
#   'doctor_id': 124},
#  {'visit_id': 199,
#   'patient_id': 39,
#   'visit_date': '12/28/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 62.55,
#   'risk_score': 'High',
#   'doctor_id': 137},
#  {'visit_id': 200,
#   'patient_id': 39,
#   'visit_date': '11/28/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 32.47,
#   'risk_score': 'Medium',
#   'doctor_id': 196},
#  {'visit_id': 201,
#   'patient_id': 40,
#   'visit_date': '7/24/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.07,
#   'risk_score': 'Medium',
#   'doctor_id': 182},
#  {'visit_id': 202,
#   'patient_id': 40,
#   'visit_date': '10/15/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.82,
#   'risk_score': 'High',
#   'doctor_id': 104},
#  {'visit_id': 203,
#   'patient_id': 40,
#   'visit_date': '11/17/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.61,
#   'risk_score': 'High',
#   'doctor_id': 190},
#  {'visit_id': 204,
#   'patient_id': 40,
#   'visit_date': '12/9/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 67.39,
#   'risk_score': 'High',
#   'doctor_id': 198},
#  {'visit_id': 205,
#   'patient_id': 41,
#   'visit_date': '8/29/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 47.92,
#   'risk_score': 'High',
#   'doctor_id': 125},
#  {'visit_id': 206,
#   'patient_id': 41,
#   'visit_date': '9/4/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 119},
#  {'visit_id': 207,
#   'patient_id': 42,
#   'visit_date': '5/20/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 143},
#  {'visit_id': 208,
#   'patient_id': 42,
#   'visit_date': '12/18/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.77,
#   'risk_score': 'Medium',
#   'doctor_id': 199},
#  {'visit_id': 209,
#   'patient_id': 42,
#   'visit_date': '12/24/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.7,
#   'risk_score': 'Low',
#   'doctor_id': 131},
#  {'visit_id': 210,
#   'patient_id': 42,
#   'visit_date': '6/7/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.42,
#   'risk_score': 'Medium',
#   'doctor_id': 134},
#  {'visit_id': 211,
#   'patient_id': 42,
#   'visit_date': '7/8/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.67,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 212,
#   'patient_id': 42,
#   'visit_date': '9/10/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 26.31,
#   'risk_score': 'High',
#   'doctor_id': 135},
#  {'visit_id': 213,
#   'patient_id': 42,
#   'visit_date': '9/16/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.08,
#   'risk_score': 'Medium',
#   'doctor_id': 158},
#  {'visit_id': 214,
#   'patient_id': 42,
#   'visit_date': '12/27/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.3,
#   'risk_score': 'Medium',
#   'doctor_id': 104},
#  {'visit_id': 215,
#   'patient_id': 43,
#   'visit_date': '12/4/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.87,
#   'risk_score': 'Low',
#   'doctor_id': 189},
#  {'visit_id': 216,
#   'patient_id': 43,
#   'visit_date': '12/24/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 58.58,
#   'risk_score': 'High',
#   'doctor_id': 158},
#  {'visit_id': 217,
#   'patient_id': 43,
#   'visit_date': '12/23/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.95,
#   'risk_score': 'Medium',
#   'doctor_id': 129},
#  {'visit_id': 218,
#   'patient_id': 43,
#   'visit_date': '1/11/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.83,
#   'risk_score': 'Medium',
#   'doctor_id': 112},
#  {'visit_id': 219,
#   'patient_id': 44,
#   'visit_date': '10/9/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.78,
#   'risk_score': 'Low',
#   'doctor_id': 119},
#  {'visit_id': 220,
#   'patient_id': 44,
#   'visit_date': '10/12/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.56,
#   'risk_score': 'Low',
#   'doctor_id': 178},
#  {'visit_id': 221,
#   'patient_id': 44,
#   'visit_date': '1/15/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.57,
#   'risk_score': 'Low',
#   'doctor_id': 108},
#  {'visit_id': 222,
#   'patient_id': 44,
#   'visit_date': '1/18/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.81,
#   'risk_score': 'Low',
#   'doctor_id': 101},
#  {'visit_id': 223,
#   'patient_id': 45,
#   'visit_date': '8/6/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 40.25,
#   'risk_score': 'Medium',
#   'doctor_id': 191},
#  {'visit_id': 224,
#   'patient_id': 45,
#   'visit_date': '11/21/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.13,
#   'risk_score': 'Medium',
#   'doctor_id': 143},
#  {'visit_id': 225,
#   'patient_id': 45,
#   'visit_date': '9/27/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 74.14,
#   'risk_score': 'High',
#   'doctor_id': 144},
#  {'visit_id': 226,
#   'patient_id': 45,
#   'visit_date': '9/8/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.14,
#   'risk_score': 'Medium',
#   'doctor_id': 103},
#  {'visit_id': 227,
#   'patient_id': 45,
#   'visit_date': '6/29/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 100},
#  {'visit_id': 228,
#   'patient_id': 45,
#   'visit_date': '9/27/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.85,
#   'risk_score': 'Medium',
#   'doctor_id': 142},
#  {'visit_id': 229,
#   'patient_id': 46,
#   'visit_date': '10/15/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.44,
#   'risk_score': 'Low',
#   'doctor_id': 191},
#  {'visit_id': 230,
#   'patient_id': 46,
#   'visit_date': '11/27/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.05,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 231,
#   'patient_id': 46,
#   'visit_date': '11/27/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.3,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 232,
#   'patient_id': 47,
#   'visit_date': '11/6/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.18,
#   'risk_score': 'Low',
#   'doctor_id': 157},
#  {'visit_id': 233,
#   'patient_id': 48,
#   'visit_date': '6/6/2025',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 43.25,
#   'risk_score': 'Medium',
#   'doctor_id': 101},
#  {'visit_id': 234,
#   'patient_id': 48,
#   'visit_date': '11/30/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 41.48,
#   'risk_score': 'Low',
#   'doctor_id': 111},
#  {'visit_id': 235,
#   'patient_id': 48,
#   'visit_date': '6/2/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.02,
#   'risk_score': 'Medium',
#   'doctor_id': 150},
#  {'visit_id': 236,
#   'patient_id': 49,
#   'visit_date': '1/8/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 65.67,
#   'risk_score': 'High',
#   'doctor_id': 197},
#  {'visit_id': 237,
#   'patient_id': 49,
#   'visit_date': '5/28/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.89,
#   'risk_score': 'Medium',
#   'doctor_id': 160},
#  {'visit_id': 238,
#   'patient_id': 49,
#   'visit_date': '1/20/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 69.43,
#   'risk_score': 'High',
#   'doctor_id': 188},
#  {'visit_id': 239,
#   'patient_id': 49,
#   'visit_date': '7/30/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.4,
#   'risk_score': 'High',
#   'doctor_id': 191},
#  {'visit_id': 240,
#   'patient_id': 49,
#   'visit_date': '9/26/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 46.6,
#   'risk_score': 'High',
#   'doctor_id': 182},
#  {'visit_id': 241,
#   'patient_id': 49,
#   'visit_date': '10/11/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.8,
#   'risk_score': 'Medium',
#   'doctor_id': 102},
#  {'visit_id': 242,
#   'patient_id': 49,
#   'visit_date': '6/17/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.47,
#   'risk_score': 'Medium',
#   'doctor_id': 116},
#  {'visit_id': 243,
#   'patient_id': 50,
#   'visit_date': '1/12/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.14,
#   'risk_score': 'Medium',
#   'doctor_id': 128},
#  {'visit_id': 244,
#   'patient_id': 50,
#   'visit_date': '12/16/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.48,
#   'risk_score': 'Medium',
#   'doctor_id': 171},
#  {'visit_id': 245,
#   'patient_id': 50,
#   'visit_date': '12/23/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 37.28,
#   'risk_score': 'Medium',
#   'doctor_id': 173},
#  {'visit_id': 246,
#   'patient_id': 51,
#   'visit_date': '5/10/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.6,
#   'risk_score': 'Medium',
#   'doctor_id': 182},
#  {'visit_id': 247,
#   'patient_id': 51,
#   'visit_date': '11/9/2025',
# ...
#   'length_of_stay_hours': 28.04,
#   'risk_score': 'Low',
#   'doctor_id': 177},
#  {'visit_id': 920,
#   'patient_id': 187,
#   'visit_date': '11/2/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 51.89,
#   'risk_score': 'High',
#   'doctor_id': 148},
#  {'visit_id': 921,
#   'patient_id': 187,
#   'visit_date': '9/15/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 65.6,
#   'risk_score': 'High',
#   'doctor_id': 144},
#  {'visit_id': 922,
#   'patient_id': 188,
#   'visit_date': '12/12/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.76,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 923,
#   'patient_id': 188,
#   'visit_date': '8/26/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.07,
#   'risk_score': 'Low',
#   'doctor_id': 100},
#  {'visit_id': 924,
#   'patient_id': 188,
#   'visit_date': '9/7/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.49,
#   'risk_score': 'Medium',
#   'doctor_id': 106},
#  {'visit_id': 925,
#   'patient_id': 188,
#   'visit_date': '1/10/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.68,
#   'risk_score': 'Low',
#   'doctor_id': 127},
#  {'visit_id': 926,
#   'patient_id': 189,
#   'visit_date': '11/12/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 44.34,
#   'risk_score': 'High',
#   'doctor_id': 165},
#  {'visit_id': 927,
#   'patient_id': 189,
#   'visit_date': '10/8/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.35,
#   'risk_score': 'Low',
#   'doctor_id': 177},
#  {'visit_id': 928,
#   'patient_id': 190,
#   'visit_date': '7/25/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.39,
#   'risk_score': 'Low',
#   'doctor_id': 175},
#  {'visit_id': 929,
#   'patient_id': 190,
#   'visit_date': '11/1/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.15,
#   'risk_score': 'Medium',
#   'doctor_id': 150},
#  {'visit_id': 930,
#   'patient_id': 191,
#   'visit_date': '1/18/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.8,
#   'risk_score': 'High',
#   'doctor_id': 196},
#  {'visit_id': 931,
#   'patient_id': 191,
#   'visit_date': '1/14/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.45,
#   'risk_score': 'High',
#   'doctor_id': 176},
#  {'visit_id': 932,
#   'patient_id': 191,
#   'visit_date': '1/20/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.54,
#   'risk_score': 'Medium',
#   'doctor_id': 111},
#  {'visit_id': 933,
#   'patient_id': 192,
#   'visit_date': '11/3/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.38,
#   'risk_score': 'Low',
#   'doctor_id': 120},
#  {'visit_id': 934,
#   'patient_id': 192,
#   'visit_date': '11/19/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.79,
#   'risk_score': 'Low',
#   'doctor_id': 158},
#  {'visit_id': 935,
#   'patient_id': 192,
#   'visit_date': '1/7/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.62,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 936,
#   'patient_id': 193,
#   'visit_date': '9/28/2025',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 61.65,
#   'risk_score': 'High',
#   'doctor_id': 113},
#  {'visit_id': 937,
#   'patient_id': 193,
#   'visit_date': '4/22/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.0,
#   'risk_score': 'Low',
#   'doctor_id': 126},
#  {'visit_id': 938,
#   'patient_id': 194,
#   'visit_date': '5/14/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.04,
#   'risk_score': 'Medium',
#   'doctor_id': 174},
#  {'visit_id': 939,
#   'patient_id': 194,
#   'visit_date': '5/8/2025',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.97,
#   'risk_score': 'High',
#   'doctor_id': 195},
#  {'visit_id': 940,
#   'patient_id': 194,
#   'visit_date': '10/29/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 24.64,
#   'risk_score': 'High',
#   'doctor_id': 169},
#  {'visit_id': 941,
#   'patient_id': 194,
#   'visit_date': '1/8/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 189},
#  {'visit_id': 942,
#   'patient_id': 194,
#   'visit_date': '7/5/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.17,
#   'risk_score': 'Medium',
#   'doctor_id': 162},
#  {'visit_id': 943,
#   'patient_id': 194,
#   'visit_date': '6/26/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.16,
#   'risk_score': 'Medium',
#   'doctor_id': 189},
#  {'visit_id': 944,
#   'patient_id': 194,
#   'visit_date': '1/4/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.93,
#   'risk_score': 'High',
#   'doctor_id': 179},
#  {'visit_id': 945,
#   'patient_id': 195,
#   'visit_date': '7/9/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.16,
#   'risk_score': 'Low',
#   'doctor_id': 135},
#  {'visit_id': 946,
#   'patient_id': 195,
#   'visit_date': '10/15/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.48,
#   'risk_score': 'Low',
#   'doctor_id': 124},
#  {'visit_id': 947,
#   'patient_id': 195,
#   'visit_date': '4/18/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 39.25,
#   'risk_score': 'Medium',
#   'doctor_id': 143},
#  {'visit_id': 948,
#   'patient_id': 195,
#   'visit_date': '5/2/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.37,
#   'risk_score': 'Medium',
#   'doctor_id': 145},
#  {'visit_id': 949,
#   'patient_id': 196,
#   'visit_date': '12/12/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.26,
#   'risk_score': 'Low',
#   'doctor_id': 131},
#  {'visit_id': 950,
#   'patient_id': 196,
#   'visit_date': '8/20/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 47.79,
#   'risk_score': 'High',
#   'doctor_id': 128},
#  {'visit_id': 951,
#   'patient_id': 196,
#   'visit_date': '4/10/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.98,
#   'risk_score': 'Low',
#   'doctor_id': 142},
#  {'visit_id': 952,
#   'patient_id': 196,
#   'visit_date': '10/27/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.35,
#   'risk_score': 'Low',
#   'doctor_id': 177},
#  {'visit_id': 953,
#   'patient_id': 196,
#   'visit_date': '5/28/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 17.21,
#   'risk_score': 'Medium',
#   'doctor_id': 171},
#  {'visit_id': 954,
#   'patient_id': 196,
#   'visit_date': '5/16/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.34,
#   'risk_score': 'Low',
#   'doctor_id': 103},
#  {'visit_id': 955,
#   'patient_id': 196,
#   'visit_date': '5/19/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.87,
#   'risk_score': 'Low',
#   'doctor_id': 131},
#  {'visit_id': 956,
#   'patient_id': 196,
#   'visit_date': '10/3/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.15,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 957,
#   'patient_id': 197,
#   'visit_date': '9/29/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.38,
#   'risk_score': 'Low',
#   'doctor_id': 145},
#  {'visit_id': 958,
#   'patient_id': 197,
#   'visit_date': '1/9/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.28,
#   'risk_score': 'Low',
#   'doctor_id': 200},
#  {'visit_id': 959,
#   'patient_id': 197,
#   'visit_date': '11/9/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.27,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 960,
#   'patient_id': 197,
#   'visit_date': '12/22/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.35,
#   'risk_score': 'Low',
#   'doctor_id': 191},
#  {'visit_id': 961,
#   'patient_id': 198,
#   'visit_date': '5/13/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.22,
#   'risk_score': 'Medium',
#   'doctor_id': 111},
#  {'visit_id': 962,
#   'patient_id': 198,
#   'visit_date': '8/2/2025',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.93,
#   'risk_score': 'Low',
#   'doctor_id': 140},
#  {'visit_id': 963,
#   'patient_id': 198,
#   'visit_date': '10/13/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 45.34,
#   'risk_score': 'Medium',
#   'doctor_id': 196},
#  {'visit_id': 964,
#   'patient_id': 198,
#   'visit_date': '12/22/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.47,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 965,
#   'patient_id': 198,
#   'visit_date': '11/25/2025',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'Medium',
#   'doctor_id': 141},
#  {'visit_id': 966,
#   'patient_id': 198,
#   'visit_date': '9/29/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.46,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 967,
#   'patient_id': 199,
#   'visit_date': '1/3/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.61,
#   'risk_score': 'Low',
#   'doctor_id': 116},
#  {'visit_id': 968,
#   'patient_id': 199,
#   'visit_date': '1/14/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 24.01,
#   'risk_score': 'Medium',
#   'doctor_id': 147},
#  {'visit_id': 969,
#   'patient_id': 199,
#   'visit_date': '12/9/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.91,
#   'risk_score': 'Medium',
#   'doctor_id': 200},
#  {'visit_id': 970,
#   'patient_id': 200,
#   'visit_date': '5/3/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.68,
#   'risk_score': 'Low',
#   'doctor_id': 126},
#  {'visit_id': 971,
#   'patient_id': 200,
#   'visit_date': '4/23/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.65,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 972,
#   'patient_id': 200,
#   'visit_date': '12/30/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.74,
#   'risk_score': 'Low',
#   'doctor_id': 139},
#  {'visit_id': 973,
#   'patient_id': 201,
#   'visit_date': '9/6/2025',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.24,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 974,
#   'patient_id': 201,
#   'visit_date': '11/16/2025',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.7,
#   'risk_score': 'Medium',
#   'doctor_id': 162},
#  {'visit_id': 975,
#   'patient_id': 201,
#   'visit_date': '11/15/2025',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.92,
#   'risk_score': 'Medium',
#   'doctor_id': 176},
#  {'visit_id': 976,
#   'patient_id': 201,
#   'visit_date': '9/22/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.83,
#   'risk_score': 'Low',
#   'doctor_id': 110},
#  {'visit_id': 977,
#   'patient_id': 201,
#   'visit_date': '8/26/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 1.24,
#   'risk_score': 'Low',
#   'doctor_id': 152},
#  {'visit_id': 978,
#   'patient_id': 202,
#   'visit_date': '1/20/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.09,
#   'risk_score': 'Medium',
#   'doctor_id': 134},
#  {'visit_id': 979,
#   'patient_id': 202,
#   'visit_date': '12/22/2025',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.27,
#   'risk_score': 'Low',
#   'doctor_id': 174},
#  {'visit_id': 980,
#   'patient_id': 202,
#   'visit_date': '10/2/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.46,
#   'risk_score': 'Low',
#   'doctor_id': 196},
#  {'visit_id': 981,
#   'patient_id': 202,
#   'visit_date': '10/9/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.77,
#   'risk_score': 'High',
#   'doctor_id': 182},
#  {'visit_id': 982,
#   'patient_id': 202,
#   'visit_date': '11/8/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 68.63,
#   'risk_score': 'High',
#   'doctor_id': 155},
#  {'visit_id': 983,
#   'patient_id': 202,
#   'visit_date': '12/30/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.66,
#   'risk_score': 'Low',
#   'doctor_id': 115},
#  {'visit_id': 984,
#   'patient_id': 202,
#   'visit_date': '9/10/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.74,
#   'risk_score': 'Low',
#   'doctor_id': 155},
#  {'visit_id': 985,
#   'patient_id': 202,
#   'visit_date': '10/5/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.82,
#   'risk_score': 'Low',
#   'doctor_id': 152},
#  {'visit_id': 986,
#   'patient_id': 202,
#   'visit_date': '9/8/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 31.42,
#   'risk_score': 'High',
#   'doctor_id': 135},
#  {'visit_id': 987,
#   'patient_id': 203,
#   'visit_date': '3/21/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.7,
#   'risk_score': 'Medium',
#   'doctor_id': 132},
#  {'visit_id': 988,
#   'patient_id': 203,
#   'visit_date': '4/9/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.79,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 989,
#   'patient_id': 203,
#   'visit_date': '7/15/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.64,
#   'risk_score': 'Low',
#   'doctor_id': 189},
#  {'visit_id': 990,
#   'patient_id': 204,
#   'visit_date': '5/23/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.72,
#   'risk_score': 'Medium',
#   'doctor_id': 124},
#  {'visit_id': 991,
#   'patient_id': 204,
#   'visit_date': '5/14/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 61.71,
#   'risk_score': 'High',
#   'doctor_id': 193},
#  {'visit_id': 992,
#   'patient_id': 204,
#   'visit_date': '11/27/2025',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 49.27,
#   'risk_score': 'High',
#   'doctor_id': 189},
#  {'visit_id': 993,
#   'patient_id': 204,
#   'visit_date': '3/31/2025',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 33.59,
#   'risk_score': 'High',
#   'doctor_id': 165},
#  {'visit_id': 994,
#   'patient_id': 205,
#   'visit_date': '5/29/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.46,
#   'risk_score': 'Low',
#   'doctor_id': 168},
#  {'visit_id': 995,
#   'patient_id': 205,
#   'visit_date': '10/18/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.89,
#   'risk_score': 'Low',
#   'doctor_id': 164},
#  {'visit_id': 996,
#   'patient_id': 205,
#   'visit_date': '1/4/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.67,
#   'risk_score': 'Low',
#   'doctor_id': 172},
#  {'visit_id': 997,
#   'patient_id': 205,
#   'visit_date': '6/15/2025',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 47.34,
#   'risk_score': 'High',
#   'doctor_id': 162},
#  {'visit_id': 998,
#   'patient_id': 205,
#   'visit_date': '6/19/2025',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.32,
#   'risk_score': 'Low',
#   'doctor_id': 183},
#  {'visit_id': 999,
#   'patient_id': 205,
#   'visit_date': '7/13/2025',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.04,
#   'risk_score': 'Low',
#   'doctor_id': 122},
#  {'visit_id': 1000,
#   'patient_id': 205,
#   'visit_date': '11/2/2025',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.62,
#   'risk_score': 'Low',
#   'doctor_id': 173},
#  ...]

# %%
len(visits_data)
# Out:
# 25000

# %%
patient_data= patient.to_dict(orient="records")
patient_data
# Out:
# [{'patient_id': 1,
#   'age': 52,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '5/6/2025'},
#  {'patient_id': 2,
#   'age': 15,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/27/2025'},
#  {'patient_id': 3,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/28/2025'},
#  {'patient_id': 4,
#   'age': 61,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2/8/2025'},
#  {'patient_id': 5,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '6/17/2025'},
#  {'patient_id': 6,
#   'age': 83,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2/5/2025'},
#  {'patient_id': 7,
#   'age': 87,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '1/31/2025'},
#  {'patient_id': 8,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '4/11/2025'},
#  {'patient_id': 9,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '3/27/2025'},
#  {'patient_id': 10,
#   'age': 88,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '6/1/2025'},
#  {'patient_id': 11,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/13/2025'},
#  {'patient_id': 12,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/13/2025'},
#  {'patient_id': 13,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '9/9/2025'},
#  {'patient_id': 14,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/14/2025'},
#  {'patient_id': 15,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/28/2025'},
#  {'patient_id': 16,
#   'age': 88,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '11/6/2025'},
#  {'patient_id': 17,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/29/2025'},
#  {'patient_id': 18,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '7/7/2025'},
#  {'patient_id': 19,
#   'age': 2,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '6/29/2025'},
#  {'patient_id': 20,
#   'age': 64,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/3/2025'},
#  {'patient_id': 21,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/29/2025'},
#  {'patient_id': 22,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2/3/2025'},
#  {'patient_id': 23,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/2/2025'},
#  {'patient_id': 24,
#   'age': 76,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/17/2026'},
#  {'patient_id': 25,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '1/29/2025'},
#  {'patient_id': 26,
#   'age': 22,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '3/17/2025'},
#  {'patient_id': 27,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/6/2025'},
#  {'patient_id': 28,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/29/2025'},
#  {'patient_id': 29,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/9/2025'},
#  {'patient_id': 30,
#   'age': 42,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/29/2025'},
#  {'patient_id': 31,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/18/2025'},
#  {'patient_id': 32,
#   'age': 80,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '4/9/2025'},
#  {'patient_id': 33,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '5/23/2025'},
#  {'patient_id': 34,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '11/28/2025'},
#  {'patient_id': 35,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/1/2025'},
#  {'patient_id': 36,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/6/2025'},
#  {'patient_id': 37,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '10/30/2025'},
#  {'patient_id': 38,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/24/2025'},
#  {'patient_id': 39,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/27/2025'},
#  {'patient_id': 40,
#   'age': 64,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/13/2025'},
#  {'patient_id': 41,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '8/6/2025'},
#  {'patient_id': 42,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '5/15/2025'},
#  {'patient_id': 43,
#   'age': 7,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/30/2025'},
#  {'patient_id': 44,
#   'age': 21,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/27/2025'},
#  {'patient_id': 45,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '3/26/2025'},
#  {'patient_id': 46,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '10/11/2025'},
#  {'patient_id': 47,
#   'age': 18,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/2/2025'},
#  {'patient_id': 48,
#   'age': 4,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '5/18/2025'},
#  {'patient_id': 49,
#   'age': 89,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '5/21/2025'},
#  {'patient_id': 50,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/6/2025'},
#  {'patient_id': 51,
#   'age': 14,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '4/16/2025'},
#  {'patient_id': 52,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '11/4/2025'},
#  {'patient_id': 53,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '6/5/2025'},
#  {'patient_id': 54,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/13/2025'},
#  {'patient_id': 55,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '8/12/2025'},
#  {'patient_id': 56,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/2/2026'},
#  {'patient_id': 57,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/11/2025'},
#  {'patient_id': 58,
#   'age': 71,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/12/2025'},
#  {'patient_id': 59,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2/28/2025'},
#  {'patient_id': 60,
#   'age': 8,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '9/26/2025'},
#  {'patient_id': 61,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '8/25/2025'},
#  {'patient_id': 62,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/17/2025'},
#  {'patient_id': 63,
#   'age': 78,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/27/2025'},
#  {'patient_id': 64,
#   'age': 81,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/21/2025'},
#  {'patient_id': 65,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '8/31/2025'},
#  {'patient_id': 66,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/2/2025'},
#  {'patient_id': 67,
#   'age': 4,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '9/10/2025'},
#  {'patient_id': 68,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/31/2025'},
#  {'patient_id': 69,
#   'age': 6,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '4/14/2025'},
#  {'patient_id': 70,
#   'age': 54,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '9/19/2025'},
#  {'patient_id': 71,
#   'age': 4,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/11/2025'},
#  {'patient_id': 72,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/25/2025'},
#  {'patient_id': 73,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '4/16/2025'},
#  {'patient_id': 74,
#   'age': 18,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '5/28/2025'},
#  {'patient_id': 75,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/1/2025'},
#  {'patient_id': 76,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/4/2025'},
#  {'patient_id': 77,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/3/2025'},
#  {'patient_id': 78,
#   'age': 74,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '1/10/2026'},
#  {'patient_id': 79,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '6/27/2025'},
#  {'patient_id': 80,
#   'age': 14,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '5/4/2025'},
#  {'patient_id': 81,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '9/5/2025'},
#  {'patient_id': 82,
#   'age': 15,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '8/24/2025'},
#  {'patient_id': 83,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '10/10/2025'},
#  {'patient_id': 84,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '3/9/2025'},
#  {'patient_id': 85,
#   'age': 87,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/6/2026'},
#  {'patient_id': 86,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '5/22/2025'},
#  {'patient_id': 87,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/18/2025'},
#  {'patient_id': 88,
#   'age': 85,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/13/2025'},
#  {'patient_id': 89,
#   'age': 80,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '5/30/2025'},
#  {'patient_id': 90,
#   'age': 82,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/31/2025'},
#  {'patient_id': 91,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '4/28/2025'},
#  {'patient_id': 92,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/6/2026'},
#  {'patient_id': 93,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/5/2025'},
#  {'patient_id': 94,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/4/2025'},
#  {'patient_id': 95,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '5/8/2025'},
#  {'patient_id': 96,
#   'age': 41,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '1/2/2026'},
#  {'patient_id': 97,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/27/2025'},
#  {'patient_id': 98,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/10/2025'},
#  {'patient_id': 99,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '8/15/2025'},
#  {'patient_id': 100,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/4/2025'},
#  {'patient_id': 101,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/11/2025'},
#  {'patient_id': 102,
#   'age': 71,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/13/2025'},
#  {'patient_id': 103,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/24/2025'},
#  {'patient_id': 104,
#   'age': 88,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '1/27/2025'},
#  {'patient_id': 105,
#   'age': 1,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '5/23/2025'},
#  {'patient_id': 106,
#   'age': 8,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '6/17/2025'},
#  {'patient_id': 107,
#   'age': 88,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/27/2025'},
#  {'patient_id': 108,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/23/2025'},
#  {'patient_id': 109,
#   'age': 11,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/30/2025'},
#  {'patient_id': 110,
#   'age': 81,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '8/25/2025'},
#  {'patient_id': 111,
#   'age': 8,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '10/5/2025'},
#  {'patient_id': 112,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/10/2026'},
#  {'patient_id': 113,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '1/30/2025'},
#  {'patient_id': 114,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '3/19/2025'},
#  {'patient_id': 115,
#   'age': 5,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '9/26/2025'},
#  {'patient_id': 116,
#   'age': 41,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/8/2025'},
#  {'patient_id': 117,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/20/2025'},
#  {'patient_id': 118,
#   'age': 7,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/26/2025'},
#  {'patient_id': 119,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/21/2025'},
#  {'patient_id': 120,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '3/25/2025'},
#  {'patient_id': 121,
#   'age': 12,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '6/14/2025'},
#  {'patient_id': 122,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/17/2025'},
#  {'patient_id': 123,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/24/2025'},
#  {'patient_id': 124,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '11/27/2025'},
#  {'patient_id': 125,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/29/2025'},
#  {'patient_id': 126,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '10/9/2025'},
#  {'patient_id': 127,
#   'age': 88,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '1/15/2026'},
#  {'patient_id': 128,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '11/11/2025'},
#  {'patient_id': 129,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/20/2025'},
#  {'patient_id': 130,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '6/27/2025'},
#  {'patient_id': 131,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '1/7/2026'},
#  {'patient_id': 132,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '11/23/2025'},
#  {'patient_id': 133,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/2/2025'},
#  {'patient_id': 134,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/30/2025'},
#  {'patient_id': 135,
#   'age': 3,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '10/9/2025'},
#  {'patient_id': 136,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '8/24/2025'},
#  {'patient_id': 137,
#   'age': 5,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '7/19/2025'},
#  {'patient_id': 138,
#   'age': 90,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '4/20/2025'},
#  {'patient_id': 139,
#   'age': 14,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/5/2025'},
#  {'patient_id': 140,
#   'age': 27,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '5/24/2025'},
#  {'patient_id': 141,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '10/6/2025'},
#  {'patient_id': 142,
#   'age': 79,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/9/2026'},
#  {'patient_id': 143,
#   'age': 15,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/21/2025'},
#  {'patient_id': 144,
#   'age': 90,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '9/15/2025'},
#  {'patient_id': 145,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/18/2025'},
#  {'patient_id': 146,
#   'age': 77,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/10/2025'},
#  {'patient_id': 147,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/11/2025'},
#  {'patient_id': 148,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/2/2025'},
#  {'patient_id': 149,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/20/2025'},
#  {'patient_id': 150,
#   'age': 4,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '9/8/2025'},
#  {'patient_id': 151,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/10/2025'},
#  {'patient_id': 152,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '10/23/2025'},
#  {'patient_id': 153,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '4/6/2025'},
#  {'patient_id': 154,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '11/18/2025'},
#  {'patient_id': 155,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/16/2025'},
#  {'patient_id': 156,
#   'age': 13,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '3/9/2025'},
#  {'patient_id': 157,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '9/24/2025'},
#  {'patient_id': 158,
#   'age': 71,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '10/29/2025'},
#  {'patient_id': 159,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/2/2025'},
#  {'patient_id': 160,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2/20/2025'},
#  {'patient_id': 161,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/26/2025'},
#  {'patient_id': 162,
#   'age': 66,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2/6/2025'},
#  {'patient_id': 163,
#   'age': 42,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '3/23/2025'},
#  {'patient_id': 164,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '5/27/2025'},
#  {'patient_id': 165,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/4/2025'},
#  {'patient_id': 166,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '7/1/2025'},
#  {'patient_id': 167,
#   'age': 6,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '9/27/2025'},
#  {'patient_id': 168,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '6/5/2025'},
#  {'patient_id': 169,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/3/2025'},
#  {'patient_id': 170,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/10/2025'},
#  {'patient_id': 171,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '7/17/2025'},
#  {'patient_id': 172,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/5/2025'},
#  {'patient_id': 173,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/18/2025'},
#  {'patient_id': 174,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/1/2025'},
#  {'patient_id': 175,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/3/2025'},
#  {'patient_id': 176,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '4/12/2025'},
#  {'patient_id': 177,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '6/4/2025'},
#  {'patient_id': 178,
#   'age': 27,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/25/2025'},
#  {'patient_id': 179,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '5/8/2025'},
#  {'patient_id': 180,
#   'age': 77,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/18/2025'},
#  {'patient_id': 181,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2/6/2025'},
#  {'patient_id': 182,
#   'age': 70,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/17/2025'},
#  {'patient_id': 183,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/22/2025'},
#  {'patient_id': 184,
#   'age': 27,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '1/30/2025'},
#  {'patient_id': 185,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/6/2025'},
#  {'patient_id': 186,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/22/2025'},
#  {'patient_id': 187,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '3/31/2025'},
#  {'patient_id': 188,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '3/21/2025'},
#  {'patient_id': 189,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '5/31/2025'},
#  {'patient_id': 190,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '3/21/2025'},
#  {'patient_id': 191,
#   'age': 79,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/12/2026'},
#  {'patient_id': 192,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/15/2025'},
#  {'patient_id': 193,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/31/2025'},
#  {'patient_id': 194,
#   'age': 88,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/23/2025'},
#  {'patient_id': 195,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '3/11/2025'},
#  {'patient_id': 196,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/3/2025'},
#  {'patient_id': 197,
#   'age': 58,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '9/4/2025'},
#  {'patient_id': 198,
#   'age': 52,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/10/2025'},
#  {'patient_id': 199,
#   'age': 12,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/7/2025'},
#  {'patient_id': 200,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/3/2025'},
#  {'patient_id': 201,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/15/2025'},
#  {'patient_id': 202,
#   'age': 3,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/30/2025'},
#  {'patient_id': 203,
#   'age': 56,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/27/2025'},
#  {'patient_id': 204,
#   'age': 81,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/14/2025'},
#  {'patient_id': 205,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '5/11/2025'},
#  {'patient_id': 206,
#   'age': 2,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '3/11/2025'},
#  {'patient_id': 207,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '4/27/2025'},
#  {'patient_id': 208,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '7/8/2025'},
#  {'patient_id': 209,
#   'age': 87,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/16/2025'},
#  {'patient_id': 210,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '8/28/2025'},
#  {'patient_id': 211,
#   'age': 19,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/10/2025'},
#  {'patient_id': 212,
#   'age': 2,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '6/14/2025'},
#  {'patient_id': 213,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/6/2025'},
#  {'patient_id': 214,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '5/28/2025'},
#  {'patient_id': 215,
#   'age': 90,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/10/2025'},
#  {'patient_id': 216,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/25/2025'},
#  {'patient_id': 217,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/11/2025'},
#  {'patient_id': 218,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/8/2025'},
#  {'patient_id': 219,
#   'age': 68,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '7/12/2025'},
#  {'patient_id': 220,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '10/29/2025'},
#  {'patient_id': 221,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/14/2025'},
#  {'patient_id': 222,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/28/2025'},
#  {'patient_id': 223,
#   'age': 17,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '1/29/2025'},
#  {'patient_id': 224,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/11/2025'},
#  {'patient_id': 225,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '10/2/2025'},
#  {'patient_id': 226,
#   'age': 69,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '5/4/2025'},
#  {'patient_id': 227,
#   'age': 70,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/8/2025'},
#  {'patient_id': 228,
#   'age': 86,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/9/2025'},
#  {'patient_id': 229,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/29/2025'},
#  {'patient_id': 230,
#   'age': 16,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/12/2025'},
#  {'patient_id': 231,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '3/6/2025'},
#  {'patient_id': 232,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/24/2025'},
#  {'patient_id': 233,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '3/15/2025'},
#  {'patient_id': 234,
#   'age': 80,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/7/2025'},
#  {'patient_id': 235,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/27/2025'},
#  {'patient_id': 236,
#   'age': 20,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/29/2025'},
#  {'patient_id': 237,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '10/18/2025'},
#  {'patient_id': 238,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '6/16/2025'},
#  {'patient_id': 239,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2/26/2025'},
#  {'patient_id': 240,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '5/10/2025'},
#  {'patient_id': 241,
#   'age': 67,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/3/2025'},
#  {'patient_id': 242,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/7/2025'},
#  {'patient_id': 243,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '4/5/2025'},
#  {'patient_id': 244,
#   'age': 71,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/13/2025'},
#  {'patient_id': 245,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/21/2025'},
#  {'patient_id': 246,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '8/4/2025'},
#  {'patient_id': 247,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/26/2025'},
#  {'patient_id': 248,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/23/2025'},
#  {'patient_id': 249,
#   'age': 82,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '1/15/2026'},
#  {'patient_id': 250,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/20/2025'},
#  {'patient_id': 251,
#   'age': 11,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '9/9/2025'},
#  {'patient_id': 252,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '5/9/2025'},
#  {'patient_id': 253,
#   'age': 89,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/3/2025'},
#  {'patient_id': 254,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '8/1/2025'},
#  {'patient_id': 255,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '1/26/2025'},
#  {'patient_id': 256,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '6/7/2025'},
#  {'patient_id': 257,
#   'age': 42,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/28/2025'},
#  {'patient_id': 258,
#   'age': 7,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/2/2025'},
#  {'patient_id': 259,
#   'age': 16,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/16/2025'},
#  {'patient_id': 260,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '3/16/2025'},
#  {'patient_id': 261,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '6/28/2025'},
#  {'patient_id': 262,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/17/2025'},
#  {'patient_id': 263,
#   'age': 1,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/2/2025'},
#  {'patient_id': 264,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/3/2025'},
#  {'patient_id': 265,
#   'age': 12,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '6/7/2025'},
#  {'patient_id': 266,
#   'age': 69,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '1/3/2026'},
#  {'patient_id': 267,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/9/2025'},
#  {'patient_id': 268,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '11/7/2025'},
#  {'patient_id': 269,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/20/2025'},
#  {'patient_id': 270,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/25/2025'},
#  {'patient_id': 271,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/8/2025'},
#  {'patient_id': 272,
#   'age': 80,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '7/22/2025'},
#  {'patient_id': 273,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/22/2025'},
#  {'patient_id': 274,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '10/8/2025'},
#  {'patient_id': 275,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/25/2025'},
#  {'patient_id': 276,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/29/2025'},
#  {'patient_id': 277,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/13/2025'},
#  {'patient_id': 278,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '10/7/2025'},
#  {'patient_id': 279,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/21/2025'},
#  {'patient_id': 280,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/29/2025'},
#  {'patient_id': 281,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '1/31/2025'},
#  {'patient_id': 282,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '10/7/2025'},
#  {'patient_id': 283,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/16/2026'},
#  {'patient_id': 284,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '7/7/2025'},
#  {'patient_id': 285,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/16/2025'},
#  {'patient_id': 286,
#   'age': 18,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '8/7/2025'},
#  {'patient_id': 287,
#   'age': 82,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/27/2025'},
#  {'patient_id': 288,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/30/2025'},
#  {'patient_id': 289,
#   'age': 54,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
# ...
#  {'patient_id': 905,
#   'age': 70,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/31/2025'},
#  {'patient_id': 906,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '3/20/2025'},
#  {'patient_id': 907,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/27/2025'},
#  {'patient_id': 908,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/13/2025'},
#  {'patient_id': 909,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '5/25/2025'},
#  {'patient_id': 910,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '8/10/2025'},
#  {'patient_id': 911,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/7/2025'},
#  {'patient_id': 912,
#   'age': 4,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/20/2025'},
#  {'patient_id': 913,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/27/2025'},
#  {'patient_id': 914,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '10/7/2025'},
#  {'patient_id': 915,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/31/2025'},
#  {'patient_id': 916,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '4/23/2025'},
#  {'patient_id': 917,
#   'age': 55,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/13/2025'},
#  {'patient_id': 918,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '4/29/2025'},
#  {'patient_id': 919,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '10/31/2025'},
#  {'patient_id': 920,
#   'age': 31,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/30/2025'},
#  {'patient_id': 921,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2/13/2025'},
#  {'patient_id': 922,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '1/7/2026'},
#  {'patient_id': 923,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/11/2026'},
#  {'patient_id': 924,
#   'age': 6,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '5/16/2025'},
#  {'patient_id': 925,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/6/2025'},
#  {'patient_id': 926,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '10/25/2025'},
#  {'patient_id': 927,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/30/2025'},
#  {'patient_id': 928,
#   'age': 4,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/20/2025'},
#  {'patient_id': 929,
#   'age': 79,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '4/8/2025'},
#  {'patient_id': 930,
#   'age': 6,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '1/8/2026'},
#  {'patient_id': 931,
#   'age': 51,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/2/2025'},
#  {'patient_id': 932,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2/17/2025'},
#  {'patient_id': 933,
#   'age': 57,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '6/12/2025'},
#  {'patient_id': 934,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/28/2025'},
#  {'patient_id': 935,
#   'age': 79,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '1/29/2025'},
#  {'patient_id': 936,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/7/2025'},
#  {'patient_id': 937,
#   'age': 8,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '10/6/2025'},
#  {'patient_id': 938,
#   'age': 26,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/31/2025'},
#  {'patient_id': 939,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '11/13/2025'},
#  {'patient_id': 940,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '9/2/2025'},
#  {'patient_id': 941,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '10/6/2025'},
#  {'patient_id': 942,
#   'age': 5,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/13/2025'},
#  {'patient_id': 943,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/2/2026'},
#  {'patient_id': 944,
#   'age': 26,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '1/2/2026'},
#  {'patient_id': 945,
#   'age': 68,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '1/25/2025'},
#  {'patient_id': 946,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '9/23/2025'},
#  {'patient_id': 947,
#   'age': 84,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2/23/2025'},
#  {'patient_id': 948,
#   'age': 20,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/13/2025'},
#  {'patient_id': 949,
#   'age': 12,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '3/25/2025'},
#  {'patient_id': 950,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '6/15/2025'},
#  {'patient_id': 951,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '3/17/2025'},
#  {'patient_id': 952,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/31/2025'},
#  {'patient_id': 953,
#   'age': 14,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2/1/2025'},
#  {'patient_id': 954,
#   'age': 64,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/6/2025'},
#  {'patient_id': 955,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '9/22/2025'},
#  {'patient_id': 956,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '7/1/2025'},
#  {'patient_id': 957,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/28/2025'},
#  {'patient_id': 958,
#   'age': 77,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '5/13/2025'},
#  {'patient_id': 959,
#   'age': 3,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '10/28/2025'},
#  {'patient_id': 960,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '9/9/2025'},
#  {'patient_id': 961,
#   'age': 6,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '7/4/2025'},
#  {'patient_id': 962,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/7/2025'},
#  {'patient_id': 963,
#   'age': 10,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2/14/2025'},
#  {'patient_id': 964,
#   'age': 5,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '5/25/2025'},
#  {'patient_id': 965,
#   'age': 23,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/28/2025'},
#  {'patient_id': 966,
#   'age': 10,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '10/27/2025'},
#  {'patient_id': 967,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/1/2025'},
#  {'patient_id': 968,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '10/29/2025'},
#  {'patient_id': 969,
#   'age': 13,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/7/2025'},
#  {'patient_id': 970,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '4/30/2025'},
#  {'patient_id': 971,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/30/2025'},
#  {'patient_id': 972,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/23/2025'},
#  {'patient_id': 973,
#   'age': 65,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/18/2025'},
#  {'patient_id': 974,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/23/2025'},
#  {'patient_id': 975,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '5/15/2025'},
#  {'patient_id': 976,
#   'age': 17,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '10/17/2025'},
#  {'patient_id': 977,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/6/2025'},
#  {'patient_id': 978,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2/27/2025'},
#  {'patient_id': 979,
#   'age': 15,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/12/2025'},
#  {'patient_id': 980,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/10/2025'},
#  {'patient_id': 981,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '3/3/2025'},
#  {'patient_id': 982,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/8/2025'},
#  {'patient_id': 983,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/25/2025'},
#  {'patient_id': 984,
#   'age': 69,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '7/7/2025'},
#  {'patient_id': 985,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/18/2025'},
#  {'patient_id': 986,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/14/2025'},
#  {'patient_id': 987,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/18/2025'},
#  {'patient_id': 988,
#   'age': 78,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '6/18/2025'},
#  {'patient_id': 989,
#   'age': 75,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/1/2025'},
#  {'patient_id': 990,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/11/2025'},
#  {'patient_id': 991,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/2/2025'},
#  {'patient_id': 992,
#   'age': 76,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '4/30/2025'},
#  {'patient_id': 993,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '3/23/2025'},
#  {'patient_id': 994,
#   'age': 1,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '4/22/2025'},
#  {'patient_id': 995,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/14/2025'},
#  {'patient_id': 996,
#   'age': 64,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/26/2025'},
#  {'patient_id': 997,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/1/2025'},
#  {'patient_id': 998,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '3/20/2025'},
#  {'patient_id': 999,
#   'age': 64,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2/17/2025'},
#  {'patient_id': 1000,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2/7/2025'},
#  ...]

# %%
len(patient_data)
# Out:
# 5000

# %%
DB_NAME="hospital_miops"
COLLECTION_PATIENT="patient_data"
COLLECTION_VISITS="visits_data"
COLLECTION_BILLING="billing_data_data"
CONNECTION_URL="new_url"

# %%
import pymongo
import pandas as pd

# %%
client=pymongo.MongoClient(CONNECTION_URL)
db=client[DB_NAME]
patient_collection=db[COLLECTION_PATIENT]
visits_collection=db[COLLECTION_VISITS]
billing_collection=db[COLLECTION_BILLING]

patient_rec=patient_collection.insert_many(patient_data)
visits_rec=visits_collection.insert_many(visits_data)      
billing_rec=billing_collection.insert_many(billing_data)

# %%
patient_df=pd.DataFrame(list(patient_collection.find()))
patient_df.head()
# Out:
#                         _id  patient_id  age gender       city  \
# 0  6a286bfbdb5bb3abac6f50c2          14   10      F     Mumbai
# 1  6a286bfbdb5bb3abac6f50e8          52   38      F  Bangalore
# 2  6a286bfbdb5bb3abac6f50f3          63   25      M      Delhi
# 3  6a286bfbdb5bb3abac6f50fc          72   72      M      Delhi
# 4  6a286bfbdb5bb3abac6f5108          84   35      F     Mumbai
#
#   insurance_provider  chronic_flag registration_date
# 0          MediCareX             1        2026-01-14
# 1          MediCareX             1        2025-05-11
# 2         SecureLife             0        2025-12-27
# 3          MediCareX             0        2025-06-26
# 4         SecureLife             1        2025-11-26

# %%
billing_df=pd.DataFrame(list(billing_collection.find()))
billing_df.head()
# Out:
#                         _id  bill_id  visit_id  billed_amount  \
# 0  6a286c11db5bb3abac6fc600       28        28       38162.87
# 1  6a286c11db5bb3abac6fc601       29        29        6851.33
# 2  6a286c11db5bb3abac6fc606       34        34        5893.50
# 3  6a286c11db5bb3abac6fc625       65        65       31990.78
# 4  6a286c11db5bb3abac6fc63c       88        88       37790.01
#
#    approved_amount claim_status  payment_days billing_date
# 0              NaN         Paid          21.0   2025-09-30
# 1          6851.33         Paid          12.0   2025-03-23
# 2          5893.50         Paid           6.0   2025-06-20
# 3         21941.52      Pending           2.0   2025-10-02
# 4         37790.01         Paid          16.0   2025-06-24

# %%
visits_df=pd.DataFrame(list(visits_collection.find()))
visits_df.head()
# Out:
#                         _id  visit_id  patient_id  visit_date department  \
# 0  6a286c04db5bb3abac6f6446        10        4442  2025-12-07         ER
# 1  6a286c04db5bb3abac6f6464        40        3989  2025-09-03  Neurology
# 2  6a286c04db5bb3abac6f6467        43        2608  2025-09-02         ER
# 3  6a286c04db5bb3abac6f6469        45        4944  2025-12-31         ER
# 4  6a286c04db5bb3abac6f6487        75         675  2025-12-07    General
#
#   visit_type  length_of_stay_hours risk_score  doctor_id
# 0         ER                 23.22        Low        107
# 1        ICU                  0.92        Low        112
# 2        OPD                 31.29        Low        145
# 3        OPD                  9.69     Medium        166
# 4         ER                 16.32        Low        194

# %%
if"_id" in patient_df.columns:
    patient_df.drop("_id",axis=1,inplace=True)
if"_id" in billing_df.columns:
    billing_df.drop("_id",axis=1,inplace=True)
if"_id" in visits_df.columns:
    visits_df.drop("_id",axis=1,inplace=True)

# %%
visits_df.head()
# Out:
#    visit_id  patient_id  visit_date department visit_type  \
# 0        10        4442  2025-12-07         ER         ER
# 1        40        3989  2025-09-03  Neurology        ICU
# 2        43        2608  2025-09-02         ER        OPD
# 3        45        4944  2025-12-31         ER        OPD
# 4        75         675  2025-12-07    General         ER
#
#    length_of_stay_hours risk_score  doctor_id
# 0                 23.22        Low        107
# 1                  0.92        Low        112
# 2                 31.29        Low        145
# 3                  9.69     Medium        166
# 4                 16.32        Low        194

# %%
# Create db folder, if it doesn't exits
import pandas as pd
import sqlite3
import os


os.makedirs("../db", exist_ok=True)

# Connect to sqlite and then create db
conn = sqlite3.connect("../db/hospital.db")
cursor = conn.cursor()
print("Database connected:", conn)
# Out:
# Database connected: <sqlite3.Connection object at 0x000001A9E021A2F0>

# %%
billing = pd.read_csv("data/billing.csv")
visits = pd.read_csv("data/visits.csv")
patient = pd.read_csv("data/patients.csv")

print("patient shape :",patient.shape)
print("billing shape :",billing.shape)
print("visits shape :",visits.shape)
# write all three dataframes into sqlite tables
patient.to_sql("patients", conn, if_exists="replace", index=False)
visits.to_sql("visits", conn, if_exists="replace", index=False)
billing.to_sql("billing", conn, if_exists="replace", index=False)

print("All three tables loaded into hospital db")
# Out:
# patient shape : (5000, 7)
# billing shape : (25000, 7)
# visits shape : (25000, 8)
# All three tables loaded into hospital db

# %%
# Quick preview of tables
print("=== PATIENTS (first 3 rows) ===")
print(pd.read_sql("select * from patients limit 5", conn).to_string())

print("=== VISITS (first 3 rows) ===")
print(pd.read_sql("select * from visits limit 5", conn).to_string())

print("=== BILLING (first 3 rows) ===")
print(pd.read_sql("select * from billing limit 5", conn).to_string())
# Out:
# === PATIENTS (first 3 rows) ===
#    patient_id  age gender       city insurance_provider  chronic_flag registration_date
# 0           1   52      M  Bangalore            CareOne             1          5/6/2025
# 1           2   15      F     Mumbai            CareOne             0        12/27/2025
# 2           3   72      F  Bangalore         SecureLife             1         1/28/2025
# 3           4   61      M     Mumbai          MediCareX             1          2/8/2025
# 4           5   21      F     Mumbai            CareOne             1         6/17/2025
# === VISITS (first 3 rows) ===
#    visit_id  patient_id  visit_date  department visit_type  length_of_stay_hours risk_score  doctor_id
# 0         1           1  10/16/2025  Cardiology        OPD                 23.15        Low        186
# 1         2           1   12/9/2025         ICU        ICU                 39.98       High        149
# 2         3           1  10/29/2025          ER         ER                 20.97     Medium        122
# 3         4           1   7/31/2025          ER         ER                  8.32     Medium        193
# 4         5           1    8/2/2025         ICU        ICU                 41.43       High        141
# === BILLING (first 3 rows) ===
#    bill_id  visit_id  billed_amount  approved_amount claim_status  payment_days billing_date
# 0        1         1       23550.00         21429.62         Paid           8.0   2025-11-03
# 1        2         2       88539.01         19725.49      Pending           NaN   2025-12-16
# 2        3         3       25949.30          1580.95     Rejected           NaN   2025-11-20
# 3        4         4        8349.57              NaN      Pending           NaN   2025-08-16
# 4        5         5       88539.01         86803.45         Paid          30.0   2025-08-23

# %% [markdown]
# ## Financial Analytics

# %%
#department workload analysis
query = """
SELECT department, COUNT(*) AS num_visits, 
ROUND(AVG(length_of_stay_hours),2) AS avg_stay_hours,
ROUND(MAX(length_of_stay_hours),2) AS max_stay_hours,
SUM(CASE
    WHEN risk_score = 'High'
    THEN 1
    ELSE 0
END) AS high_risk_count
FROM visits
GROUP BY department
order by num_visits DESC
"""
department_workload = pd.read_sql(query, conn)
print("Department Workload:")
print(department_workload.to_string(index=False))
# Out:
# Department Workload:
#  department  num_visits  avg_stay_hours  max_stay_hours  high_risk_count
#     General        5757           14.01           36.54               24
# Orthopedics        4474           23.02           52.99               54
#  Cardiology        4071           32.59           70.74              489
#          ER        3896           11.95           30.78              139
#         ICU        3415           56.86           78.42             2975
#   Neurology        3387           27.69           66.16              635

# %%
#which doctor handled most critical patients
query = """
SELECT 
        doctor_id,
        COUNT(visit_id)                              AS total_visits,
        SUM(CASE WHEN risk_score = 'High' 
            THEN 1 ELSE 0 END)                       AS high_risk_cases,
        ROUND(
            100.0 * SUM(CASE WHEN risk_score = 'High' 
            THEN 1 ELSE 0 END) / COUNT(visit_id), 1) AS high_risk_pct
    FROM visits
    GROUP BY doctor_id
    ORDER BY high_risk_cases DESC
    LIMIT 10
"""
doctor_risk = pd.read_sql(query, conn)
print("Doctor Risk Analysis:")
print(doctor_risk.to_string(index=False))
# Out:
# Doctor Risk Analysis:
#  doctor_id  total_visits  high_risk_cases  high_risk_pct
#        114           260               61           23.5
#        130           264               60           22.7
#        187           262               57           21.8
#        126           244               55           22.5
#        102           271               55           20.3
#        189           240               54           22.5
#        158           252               53           21.0
#        171           260               52           20.0
#        150           252               52           20.6
#        194           267               51           19.1

# %%
#Patient Visit Patterns distribution
query = """
  SELECT 
        visit_frequency_bucket,
        COUNT(patient_id) AS num_patients
    FROM (
        SELECT 
            patient_id,
            COUNT(visit_id) AS visit_count,
            CASE 
                WHEN COUNT(visit_id) = 1     THEN '1 visit'
                WHEN COUNT(visit_id) BETWEEN 2 AND 3 THEN '2-3 visits'
                WHEN COUNT(visit_id) BETWEEN 4 AND 5 THEN '4-5 visits'
                ELSE '6+ visits'
            END AS visit_frequency_bucket
        FROM visits
        GROUP BY patient_id
    )
    GROUP BY visit_frequency_bucket
    ORDER BY num_patients DESC

"""
visit_patterns = pd.read_sql(query, conn)
print("Visit Patterns Analysis:")
print(visit_patterns.to_string(index=False))
# Out:
# Visit Patterns Analysis:
# visit_frequency_bucket  num_patients
#              6+ visits          1816
#             4-5 visits          1776
#             2-3 visits          1267
#                1 visit           141

# %%
# Risk Score Distribution
query = """
   SELECT 
        department,
        SUM(CASE WHEN risk_score = 'Low'    THEN 1 ELSE 0 END) AS low,
        SUM(CASE WHEN risk_score = 'Medium' THEN 1 ELSE 0 END) AS medium,
        SUM(CASE WHEN risk_score = 'High'   THEN 1 ELSE 0 END) AS high,
        COUNT(*) AS total
    FROM visits
    GROUP BY department
    ORDER BY high DESC

"""
risk_by_dept = pd.read_sql(query, conn)
print("Risk Score Distribution by Department:")
print(risk_by_dept.to_string(index=False))
# Out:
# Risk Score Distribution by Department:
#  department  low  medium  high  total
#         ICU   10     430  2975   3415
#   Neurology  875    1877   635   3387
#  Cardiology 1063    2519   489   4071
#          ER 1771    1986   139   3896
# Orthopedics 3426     994    54   4474
#     General 4590    1143    24   5757

# %% [markdown]
# ## Financial Analytics

# %%
#  Revenue and claim outcomes by insurance provider
query = """
  SELECT 
        p.insurance_provider,
        COUNT(b.bill_id)                         AS total_claims,
        ROUND(SUM(b.billed_amount), 0)           AS total_billed,
        ROUND(AVG(b.billed_amount), 0)           AS avg_billed,
        ROUND(SUM(b.approved_amount), 0)         AS total_approved,
        SUM(CASE WHEN b.claim_status = 'Paid'     
            THEN 1 ELSE 0 END)                   AS paid,
        SUM(CASE WHEN b.claim_status = 'Pending'  
            THEN 1 ELSE 0 END)                   AS pending,
        SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END)                   AS rejected
    FROM billing b
    JOIN visits  v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    GROUP BY p.insurance_provider
    ORDER BY total_billed DESC

"""
insurance_billing = pd.read_sql(query, conn)
print("Risk Score Distribution by Department:")
print(insurance_billing.to_string(index=False))
# Out:
# Risk Score Distribution by Department:
# insurance_provider  total_claims  total_billed  avg_billed  total_approved  paid  pending  rejected
#         HealthPlus          6499   251723095.0     38733.0     124033289.0  3727     1557      1215
#            CareOne          6326   246192121.0     38918.0     107084590.0  3160     1541      1625
#         SecureLife          6197   242381528.0     39113.0     128230940.0  3723     1498       976
#          MediCareX          5978   229000682.0     38307.0     100849491.0  3028     1500      1450

# %%
# Which insurance providers reject the most claims?
query = """
 SELECT 
        p.insurance_provider,
        COUNT(b.bill_id)                              AS total_claims,
        SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END)                        AS rejected_claims,
        ROUND(
            100.0 * SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END) / COUNT(b.bill_id), 1) AS rejection_rate_pct
    FROM billing b
    JOIN visits   v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    GROUP BY p.insurance_provider
    ORDER BY rejection_rate_pct DESC

"""
rejection_analysis = pd.read_sql(query, conn)
print("Claim Rejection Analysis by Insurance Provider:")
print(rejection_analysis.to_string(index=False))
# Out:
# Claim Rejection Analysis by Insurance Provider:
# insurance_provider  total_claims  rejected_claims  rejection_rate_pct
#            CareOne          6326             1625                25.7
#          MediCareX          5978             1450                24.3
#         HealthPlus          6499             1215                18.7
#         SecureLife          6197              976                15.7

# %%
#How much of what we bill actually gets approved
query = """
    SELECT 
        p.insurance_provider,
        ROUND(SUM(b.billed_amount), 0)                AS total_billed,
        ROUND(SUM(b.approved_amount), 0)              AS total_approved,
        ROUND(
            100.0 * SUM(b.approved_amount) / 
            SUM(b.billed_amount), 1)                  AS realization_rate_pct
    FROM billing b
    JOIN visits   v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    WHERE b.approved_amount IS NOT NULL
    GROUP BY p.insurance_provider
    ORDER BY realization_rate_pct DESC

"""
revenue_realization = pd.read_sql(query, conn)
print("Revenue Realization Analysis by Insurance Provider:")
print(revenue_realization.to_string(index=False))
# Out:
# Revenue Realization Analysis by Insurance Provider:
# insurance_provider  total_billed  total_approved  realization_rate_pct
#         SecureLife   181215374.0     128230940.0                  70.8
#         HealthPlus   180661516.0     124033289.0                  68.7
#          MediCareX   157807601.0     100849491.0                  63.9
#            CareOne   169349090.0     107084590.0                  63.2

# %% [markdown]
# ## Data Quality

# %%
# Missing Records Check
print("=== MISSING VALUES CHECK ===\n")

for table in ['patients', 'visits', 'billing']:
    df = pd.read_sql(f"SELECT * FROM {table}", conn)
    nulls = df.isnull().sum()
    nulls = nulls[nulls > 0]
    if len(nulls) > 0:
        print(f"{table}:")
        print(nulls.to_string())
        print()
    else:
        print(f"{table}: ✓ No missing values\n")
# Out:
# === MISSING VALUES CHECK ===
#
# patients: ✓ No missing values
#
# visits: ✓ No missing values
#
# billing:
# approved_amount    6156
# payment_days       9532

# %%
# Duplicate Patients Check
duplicate_patients = pd.read_sql("""
    SELECT 
        patient_id,
        COUNT(*) AS occurrences
    FROM patients
    GROUP BY patient_id
    HAVING COUNT(*) > 1
""", conn)

if len(duplicate_patients) == 0:
    print("✓ No duplicate patient_ids found")
else:
    print(f"⚠ Found {len(duplicate_patients)} duplicate patient_ids")
    print(duplicate_patients)
# Out:
# ✓ No duplicate patient_ids found

# %%
# Orphan Records Check
# Visits without matching patients
orphan_visits = pd.read_sql("""
    SELECT COUNT(*) AS orphan_visits
    FROM visits v
    LEFT JOIN patients p ON v.patient_id = p.patient_id
    WHERE p.patient_id IS NULL
""", conn)

# Billing without matching visits
orphan_billing = pd.read_sql("""
    SELECT COUNT(*) AS orphan_billing
    FROM billing b
    LEFT JOIN visits v ON b.visit_id = v.visit_id
    WHERE v.visit_id IS NULL
""", conn)

print("Orphan visits  (no matching patient):", 
      orphan_visits['orphan_visits'][0])
print("Orphan billing (no matching visit)  :", 
      orphan_billing['orphan_billing'][0])
# Out:
# Orphan visits  (no matching patient): 0
# Orphan billing (no matching visit)  : 0

# %%
#Invalid LOS Check
invalid_los = pd.read_sql("""
    SELECT 
        COUNT(CASE WHEN length_of_stay_hours <= 0  THEN 1 END) AS zero_or_negative,
        COUNT(CASE WHEN length_of_stay_hours > 720 THEN 1 END) AS over_30_days,
        MIN(length_of_stay_hours)                              AS min_los,
        MAX(length_of_stay_hours)                             AS max_los,
        ROUND(AVG(length_of_stay_hours), 2)                   AS avg_los
    FROM visits
""", conn)

print("LOS Validation:")
print(invalid_los.to_string(index=False))
# Out:
# LOS Validation:
#  zero_or_negative  over_30_days  min_los  max_los  avg_los
#                 0             0      0.5    78.42    26.03

# %%
# Invalid Payment Days Check
invalid_payment = pd.read_sql("""
    SELECT 
        COUNT(CASE WHEN payment_days < 0   THEN 1 END) AS negative_days,
        COUNT(CASE WHEN payment_days > 365 THEN 1 END) AS over_1_year,
        COUNT(CASE WHEN payment_days IS NULL THEN 1 END) AS nulls,
        MIN(payment_days)                               AS min_days,
        MAX(payment_days)                               AS max_days
    FROM billing
""", conn)

print("Payment Days Validation:")
print(invalid_payment.to_string(index=False))
# Out:
# Payment Days Validation:
#  negative_days  over_1_year  nulls  min_days  max_days
#              0            0   9532       1.0      55.0

# %%
# Join all three tables into one flat table for ML modeling.
# This is the single source of truth for Phase 2 EDA and Phase 3 Modeling.
model_table = pd.read_sql("""
    SELECT
        -- Patient features
        p.patient_id,
        p.age,
        p.gender,
        p.city,
        p.insurance_provider,
        p.chronic_flag,
        p.registration_date,

        -- Visit features
        v.visit_id,
        v.visit_date,
        v.department,
        v.visit_type,
        v.length_of_stay_hours,
        v.risk_score,
        v.doctor_id,

        -- Billing features
        b.bill_id,
        b.billed_amount,
        b.approved_amount,
        b.claim_status,
        b.payment_days,
        b.billing_date

    FROM visits v
    JOIN patients p ON v.patient_id = p.patient_id
    JOIN billing  b ON v.visit_id   = b.visit_id
    ORDER BY v.visit_date
""", conn)

print("model_table shape:", model_table.shape)
print("Columns:", model_table.columns.tolist())
model_table.head(3)
# Out:
# model_table shape: (25000, 20)
# Columns: ['patient_id', 'age', 'gender', 'city', 'insurance_provider', 'chronic_flag', 'registration_date', 'visit_id', 'visit_date', 'department', 'visit_type', 'length_of_stay_hours', 'risk_score', 'doctor_id', 'bill_id', 'billed_amount', 'approved_amount', 'claim_status', 'payment_days', 'billing_date']
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0           2   15      F     Mumbai            CareOne             0
# 1          12    3      M  Bangalore            CareOne             0
# 2         129   44      M       Pune          MediCareX             1
#
#   registration_date  visit_id visit_date department visit_type  \
# 0        12/27/2025         8   1/1/2026    General        OPD
# 1         8/13/2025        65   1/1/2026        ICU        ICU
# 2         7/20/2025       651   1/1/2026        ICU         ER
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                  9.63        Low        105        8        9612.77
# 1                 59.60       High        112       65       88539.01
# 2                 59.28       High        150      651       88539.01
#
#    approved_amount claim_status  payment_days billing_date
# 0              NaN     Rejected           NaN   2026-01-19
# 1              NaN     Rejected           NaN   2026-01-05
# 2              NaN      Pending           NaN   2026-01-20

# %%
# save the table
import os
os.makedirs("../outputs", exist_ok=True)
model_table.to_csv("../outputs/model_table.csv", index=False)
print(f"model_table.csv saved --> /outputs/model_table.csv")
print(f"Shape: {model_table.shape}")
print(f"Size: {os.path.getsize('../outputs/model_table.csv')/1024:.1f} KB")
# Out:
# model_table.csv saved --> /outputs/model_table.csv
# Shape: (25000, 20)
# Size: 3049.5 KB

# %%
model_table= pd.read_csv("../outputs/model_table.csv")
model_table.head()
# Out:
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0           2   15      F     Mumbai            CareOne             0
# 1          12    3      M  Bangalore            CareOne             0
# 2         129   44      M       Pune          MediCareX             1
# 3         133   47      F      Delhi            CareOne             1
# 4         139   14      F    Chennai         SecureLife             1
#
#   registration_date  visit_id visit_date  department visit_type  \
# 0        12/27/2025         8   1/1/2026     General        OPD
# 1         8/13/2025        65   1/1/2026         ICU        ICU
# 2         7/20/2025       651   1/1/2026         ICU         ER
# 3         11/2/2025       670   1/1/2026     General        OPD
# 4          2/5/2025       706   1/1/2026  Cardiology         ER
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                  9.63        Low        105        8        9612.77
# 1                 59.60       High        112       65       88539.01
# 2                 59.28       High        150      651       88539.01
# 3                 25.15     Medium        145      670       20958.52
# 4                 42.88     Medium        148      706       74921.48
#
#    approved_amount claim_status  payment_days billing_date
# 0              NaN     Rejected           NaN   2026-01-19
# 1              NaN     Rejected           NaN   2026-01-05
# 2              NaN      Pending           NaN   2026-01-20
# 3         20322.91         Paid          48.0   2026-01-15
# 4         72277.09         Paid          27.0   2026-01-16

# %%
model_table_df= model_table.to_dict(orient="records")
model_table_df
# Out:
# [{'patient_id': 2,
#   'age': 15,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/27/2025',
#   'visit_id': 8,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.63,
#   'risk_score': 'Low',
#   'doctor_id': 105,
#   'bill_id': 8,
#   'billed_amount': 9612.77,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 12,
#   'age': 3,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '8/13/2025',
#   'visit_id': 65,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 59.6,
#   'risk_score': 'High',
#   'doctor_id': 112,
#   'bill_id': 65,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-05'},
#  {'patient_id': 129,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/20/2025',
#   'visit_id': 651,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 59.28,
#   'risk_score': 'High',
#   'doctor_id': 150,
#   'bill_id': 651,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 133,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/2/2025',
#   'visit_id': 670,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.15,
#   'risk_score': 'Medium',
#   'doctor_id': 145,
#   'bill_id': 670,
#   'billed_amount': 20958.52,
#   'approved_amount': 20322.91,
#   'claim_status': 'Paid',
#   'payment_days': 48.0,
#   'billing_date': '2026-01-15'},
#  {'patient_id': 139,
#   'age': 14,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/5/2025',
#   'visit_id': 706,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 42.88,
#   'risk_score': 'Medium',
#   'doctor_id': 148,
#   'bill_id': 706,
#   'billed_amount': 74921.48,
#   'approved_amount': 72277.09,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2026-01-16'},
#  {'patient_id': 170,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/10/2025',
#   'visit_id': 849,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.25,
#   'risk_score': 'Medium',
#   'doctor_id': 185,
#   'bill_id': 849,
#   'billed_amount': 31867.91,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-03'},
#  {'patient_id': 216,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/25/2025',
#   'visit_id': 1048,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.99,
#   'risk_score': 'Medium',
#   'doctor_id': 187,
#   'bill_id': 1048,
#   'billed_amount': 74288.71,
#   'approved_amount': 73100.85,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 222,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '6/28/2025',
#   'visit_id': 1083,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.91,
#   'risk_score': 'Medium',
#   'doctor_id': 177,
#   'bill_id': 1083,
#   'billed_amount': 19358.98,
#   'approved_amount': 1709.54,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 243,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '4/5/2025',
#   'visit_id': 1197,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 44.31,
#   'risk_score': 'Medium',
#   'doctor_id': 130,
#   'bill_id': 1197,
#   'billed_amount': 78869.93,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 335,
#   'age': 37,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '11/25/2025',
#   'visit_id': 1663,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 33.95,
#   'risk_score': 'Medium',
#   'doctor_id': 126,
#   'bill_id': 1663,
#   'billed_amount': 67258.54,
#   'approved_amount': 14081.42,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 341,
#   'age': 85,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/2/2025',
#   'visit_id': 1694,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.81,
#   'risk_score': 'Low',
#   'doctor_id': 172,
#   'bill_id': 1694,
#   'billed_amount': 49582.9,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 344,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '8/11/2025',
#   'visit_id': 1711,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.81,
#   'risk_score': 'Low',
#   'doctor_id': 153,
#   'bill_id': 1711,
#   'billed_amount': 11896.06,
#   'approved_amount': 11628.19,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2026-01-12'},
#  {'patient_id': 391,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/19/2025',
#   'visit_id': 1951,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.67,
#   'risk_score': 'Low',
#   'doctor_id': 122,
#   'bill_id': 1951,
#   'billed_amount': 26371.08,
#   'approved_amount': 3550.65,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 394,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '10/29/2025',
#   'visit_id': 1966,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.53,
#   'risk_score': 'Low',
#   'doctor_id': 193,
#   'bill_id': 1966,
#   'billed_amount': 9311.04,
#   'approved_amount': 8469.39,
#   'claim_status': 'Paid',
#   'payment_days': 34.0,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 401,
#   'age': 52,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/27/2025',
#   'visit_id': 1999,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.36,
#   'risk_score': 'Low',
#   'doctor_id': 103,
#   'bill_id': 1999,
#   'billed_amount': 16901.68,
#   'approved_amount': 16798.71,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2026-01-05'},
#  {'patient_id': 445,
#   'age': 67,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/27/2025',
#   'visit_id': 2200,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 107,
#   'bill_id': 2200,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-06'},
#  {'patient_id': 445,
#   'age': 67,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/27/2025',
#   'visit_id': 2203,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 190,
#   'bill_id': 2203,
#   'billed_amount': 576.41,
#   'approved_amount': 494.23,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2026-01-08'},
#  {'patient_id': 450,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '11/26/2025',
#   'visit_id': 2223,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.03,
#   'risk_score': 'Low',
#   'doctor_id': 104,
#   'bill_id': 2223,
#   'billed_amount': 29870.56,
#   'approved_amount': 2947.8,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 477,
#   'age': 16,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/17/2025',
#   'visit_id': 2384,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.78,
#   'risk_score': 'Medium',
#   'doctor_id': 176,
#   'bill_id': 2384,
#   'billed_amount': 14101.16,
#   'approved_amount': 2589.34,
#   'claim_status': 'Pending',
#   'payment_days': 38.0,
#   'billing_date': '2026-01-16'},
#  {'patient_id': 525,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/2/2025',
#   'visit_id': 2648,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.59,
#   'risk_score': 'Low',
#   'doctor_id': 176,
#   'bill_id': 2648,
#   'billed_amount': 6354.88,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 527,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/4/2025',
#   'visit_id': 2659,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.05,
#   'risk_score': 'High',
#   'doctor_id': 158,
#   'bill_id': 2659,
#   'billed_amount': 88539.01,
#   'approved_amount': 8834.63,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 553,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '9/5/2025',
#   'visit_id': 2791,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.41,
#   'risk_score': 'Low',
#   'doctor_id': 130,
#   'bill_id': 2791,
#   'billed_amount': 22362.64,
#   'approved_amount': 19089.8,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 555,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '5/18/2025',
#   'visit_id': 2804,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.16,
#   'risk_score': 'Low',
#   'doctor_id': 153,
#   'bill_id': 2804,
#   'billed_amount': 13094.56,
#   'approved_amount': 12003.28,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 605,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/20/2025',
#   'visit_id': 3070,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 76.6,
#   'risk_score': 'High',
#   'doctor_id': 102,
#   'bill_id': 3070,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-12'},
#  {'patient_id': 620,
#   'age': 13,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/22/2025',
#   'visit_id': 3155,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.3,
#   'risk_score': 'Medium',
#   'doctor_id': 108,
#   'bill_id': 3155,
#   'billed_amount': 20391.64,
#   'approved_amount': 819.67,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-11'},
#  {'patient_id': 639,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '7/16/2025',
#   'visit_id': 3243,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.73,
#   'risk_score': 'Low',
#   'doctor_id': 107,
#   'bill_id': 3243,
#   'billed_amount': 23036.16,
#   'approved_amount': 21613.64,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2026-01-05'},
#  {'patient_id': 655,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '3/26/2025',
#   'visit_id': 3334,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 168,
#   'bill_id': 3334,
#   'billed_amount': 553.3,
#   'approved_amount': 476.95,
#   'claim_status': 'Paid',
#   'payment_days': 42.0,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 657,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '12/16/2025',
#   'visit_id': 3347,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.82,
#   'risk_score': 'Low',
#   'doctor_id': 128,
#   'bill_id': 3347,
#   'billed_amount': 12455.05,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-04'},
#  {'patient_id': 706,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/2/2025',
#   'visit_id': 3557,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.03,
#   'risk_score': 'Low',
#   'doctor_id': 103,
#   'bill_id': 3557,
#   'billed_amount': 55006.03,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-03'},
#  {'patient_id': 741,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/9/2025',
#   'visit_id': 3731,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.29,
#   'risk_score': 'Low',
#   'doctor_id': 175,
#   'bill_id': 3731,
#   'billed_amount': 11231.94,
#   'approved_amount': 10985.81,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 778,
#   'age': 79,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/19/2025',
#   'visit_id': 3927,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.68,
#   'risk_score': 'Medium',
#   'doctor_id': 160,
#   'bill_id': 3927,
#   'billed_amount': 1768.7,
#   'approved_amount': 643.73,
#   'claim_status': 'Pending',
#   'payment_days': 22.0,
#   'billing_date': '2026-01-05'},
#  {'patient_id': 847,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '9/27/2025',
#   'visit_id': 4266,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.15,
#   'risk_score': 'High',
#   'doctor_id': 126,
#   'bill_id': 4266,
#   'billed_amount': 48079.64,
#   'approved_amount': 43614.99,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2026-01-10'},
#  {'patient_id': 858,
#   'age': 87,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '3/22/2025',
#   'visit_id': 4332,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 67.35,
#   'risk_score': 'High',
#   'doctor_id': 199,
#   'bill_id': 4332,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-11'},
#  {'patient_id': 957,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/28/2025',
#   'visit_id': 4785,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.85,
#   'risk_score': 'Medium',
#   'doctor_id': 162,
#   'bill_id': 4785,
#   'billed_amount': 14438.86,
#   'approved_amount': 14255.83,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 965,
#   'age': 23,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/28/2025',
#   'visit_id': 4828,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.38,
#   'risk_score': 'Low',
#   'doctor_id': 158,
#   'bill_id': 4828,
#   'billed_amount': 4039.98,
#   'approved_amount': 3965.45,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2026-01-15'},
#  {'patient_id': 1024,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/15/2025',
#   'visit_id': 5086,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.88,
#   'risk_score': 'Low',
#   'doctor_id': 134,
#   'bill_id': 5086,
#   'billed_amount': 8192.33,
#   'approved_amount': 7741.78,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2026-01-10'},
#  {'patient_id': 1049,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2/19/2025',
#   'visit_id': 5223,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.3,
#   'risk_score': 'Low',
#   'doctor_id': 105,
#   'bill_id': 5223,
#   'billed_amount': 14318.07,
#   'approved_amount': 12981.28,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1057,
#   'age': 66,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '4/1/2025',
#   'visit_id': 5252,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.91,
#   'risk_score': 'Low',
#   'doctor_id': 126,
#   'bill_id': 5252,
#   'billed_amount': 7152.64,
#   'approved_amount': 6226.76,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1140,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/30/2025',
#   'visit_id': 5645,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.06,
#   'risk_score': 'Medium',
#   'doctor_id': 147,
#   'bill_id': 5645,
#   'billed_amount': 64591.88,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1140,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/30/2025',
#   'visit_id': 5647,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 135,
#   'bill_id': 5647,
#   'billed_amount': 647.36,
#   'approved_amount': 563.73,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1150,
#   'age': 82,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '4/1/2025',
#   'visit_id': 5696,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.47,
#   'risk_score': 'Medium',
#   'doctor_id': 165,
#   'bill_id': 5696,
#   'billed_amount': 37593.51,
#   'approved_amount': 32721.01,
#   'claim_status': 'Paid',
#   'payment_days': 53.0,
#   'billing_date': '2026-01-05'},
#  {'patient_id': 1184,
#   'age': 87,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/3/2025',
#   'visit_id': 5842,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.06,
#   'risk_score': 'Medium',
#   'doctor_id': 167,
#   'bill_id': 5842,
#   'billed_amount': 60382.72,
#   'approved_amount': 56859.06,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 1198,
#   'age': 18,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/15/2025',
#   'visit_id': 5906,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.78,
#   'risk_score': 'Medium',
#   'doctor_id': 108,
#   'bill_id': 5906,
#   'billed_amount': 45749.63,
#   'approved_amount': 39081.99,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 1231,
#   'age': 67,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/4/2025',
#   'visit_id': 6071,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 12.4,
#   'risk_score': 'Medium',
#   'doctor_id': 174,
#   'bill_id': 6071,
#   'billed_amount': 11844.23,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1254,
#   'age': 85,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '5/7/2025',
#   'visit_id': 6201,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.84,
#   'risk_score': 'Low',
#   'doctor_id': 114,
#   'bill_id': 6201,
#   'billed_amount': 24515.98,
#   'approved_amount': 23649.74,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2026-01-12'},
#  {'patient_id': 1266,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '3/19/2025',
#   'visit_id': 6262,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.97,
#   'risk_score': 'Medium',
#   'doctor_id': 142,
#   'bill_id': 6262,
#   'billed_amount': 56731.25,
#   'approved_amount': 56253.17,
#   'claim_status': 'Paid',
#   'payment_days': 25.0,
#   'billing_date': '2026-01-06'},
#  {'patient_id': 1266,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '3/19/2025',
#   'visit_id': 6266,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.28,
#   'risk_score': 'Low',
#   'doctor_id': 133,
#   'bill_id': 6266,
#   'billed_amount': 12393.22,
#   'approved_amount': 3443.38,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1279,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/4/2025',
#   'visit_id': 6341,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 56.64,
#   'risk_score': 'Medium',
#   'doctor_id': 127,
#   'bill_id': 6341,
#   'billed_amount': 88539.01,
#   'approved_amount': 76869.69,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1292,
#   'age': 73,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/23/2025',
#   'visit_id': 6395,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.43,
#   'risk_score': 'High',
#   'doctor_id': 117,
#   'bill_id': 6395,
#   'billed_amount': 47050.42,
#   'approved_amount': 45996.97,
#   'claim_status': 'Paid',
#   'payment_days': 29.0,
#   'billing_date': '2026-01-18'},
#  {'patient_id': 1402,
#   'age': 12,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/14/2025',
#   'visit_id': 6934,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.21,
#   'risk_score': 'Low',
#   'doctor_id': 130,
#   'bill_id': 6934,
#   'billed_amount': 21278.6,
#   'approved_amount': 18557.53,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1413,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '11/24/2025',
#   'visit_id': 7005,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.48,
#   'risk_score': 'Medium',
#   'doctor_id': 139,
#   'bill_id': 7005,
#   'billed_amount': 32850.57,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-17'},
#  {'patient_id': 1419,
#   'age': 79,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '1/23/2025',
#   'visit_id': 7043,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 40.17,
#   'risk_score': 'High',
#   'doctor_id': 144,
#   'bill_id': 7043,
#   'billed_amount': 73578.22,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1487,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/1/2025',
#   'visit_id': 7369,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.77,
#   'risk_score': 'Low',
#   'doctor_id': 198,
#   'bill_id': 7369,
#   'billed_amount': 25666.5,
#   'approved_amount': 22731.06,
#   'claim_status': 'Paid',
#   'payment_days': 37.0,
#   'billing_date': '2026-01-09'},
#  {'patient_id': 1566,
#   'age': 5,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/26/2025',
#   'visit_id': 7785,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.0,
#   'risk_score': 'Low',
#   'doctor_id': 176,
#   'bill_id': 7785,
#   'billed_amount': 34469.72,
#   'approved_amount': 3176.52,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 1590,
#   'age': 88,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '10/25/2025',
#   'visit_id': 7915,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 49.01,
#   'risk_score': 'High',
#   'doctor_id': 198,
#   'bill_id': 7915,
#   'billed_amount': 88539.01,
#   'approved_amount': 80815.07,
#   'claim_status': 'Paid',
#   'payment_days': 41.0,
#   'billing_date': '2026-01-16'},
#  {'patient_id': 1631,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '11/30/2025',
#   'visit_id': 8138,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.0,
#   'risk_score': 'Low',
#   'doctor_id': 161,
#   'bill_id': 8138,
#   'billed_amount': 9716.53,
#   'approved_amount': 8662.25,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1643,
#   'age': 79,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/30/2025',
#   'visit_id': 8196,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.05,
#   'risk_score': 'Low',
#   'doctor_id': 151,
#   'bill_id': 8196,
#   'billed_amount': 9487.3,
#   'approved_amount': 16.77,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1647,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '8/26/2025',
#   'visit_id': 8215,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 33.55,
#   'risk_score': 'High',
#   'doctor_id': 169,
#   'bill_id': 8215,
#   'billed_amount': 60437.66,
#   'approved_amount': 56503.21,
#   'claim_status': 'Paid',
#   'payment_days': 33.0,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 1691,
#   'age': 2,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/31/2025',
#   'visit_id': 8418,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.27,
#   'risk_score': 'Low',
#   'doctor_id': 197,
#   'bill_id': 8418,
#   'billed_amount': 17639.74,
#   'approved_amount': 15610.71,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1696,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/9/2025',
#   'visit_id': 8448,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 19.31,
#   'risk_score': 'High',
#   'doctor_id': 154,
#   'bill_id': 8448,
#   'billed_amount': 33077.84,
#   'approved_amount': 29913.65,
#   'claim_status': 'Paid',
#   'payment_days': 44.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1708,
#   'age': 57,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '4/6/2025',
#   'visit_id': 8512,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 196,
#   'bill_id': 8512,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-08'},
#  {'patient_id': 1709,
#   'age': 69,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/25/2025',
#   'visit_id': 8522,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.23,
#   'risk_score': 'Low',
#   'doctor_id': 128,
#   'bill_id': 8522,
#   'billed_amount': 13101.39,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1738,
#   'age': 3,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/2/2025',
#   'visit_id': 8682,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.13,
#   'risk_score': 'Low',
#   'doctor_id': 194,
#   'bill_id': 8682,
#   'billed_amount': 12918.11,
#   'approved_amount': 11842.86,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1753,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/19/2025',
#   'visit_id': 8770,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.49,
#   'risk_score': 'Low',
#   'doctor_id': 157,
#   'bill_id': 8770,
#   'billed_amount': 18590.52,
#   'approved_amount': 17544.41,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1754,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/30/2025',
#   'visit_id': 8778,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 46.27,
#   'risk_score': 'High',
#   'doctor_id': 131,
#   'bill_id': 8778,
#   'billed_amount': 88539.01,
#   'approved_amount': 85342.33,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1793,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '7/18/2025',
#   'visit_id': 9007,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.67,
#   'risk_score': 'Low',
#   'doctor_id': 176,
#   'bill_id': 9007,
#   'billed_amount': 45198.13,
#   'approved_amount': 41364.83,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1795,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '9/4/2025',
#   'visit_id': 9016,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 46.18,
#   'risk_score': 'High',
#   'doctor_id': 143,
#   'bill_id': 9016,
#   'billed_amount': 88539.01,
#   'approved_amount': 8830.99,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1797,
#   'age': 2,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '11/14/2025',
#   'visit_id': 9020,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.87,
#   'risk_score': 'Low',
#   'doctor_id': 124,
#   'bill_id': 9020,
#   'billed_amount': 48639.17,
#   'approved_amount': 44724.41,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2026-01-18'},
#  {'patient_id': 1810,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/27/2025',
#   'visit_id': 9084,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 3.96,
#   'risk_score': 'Low',
#   'doctor_id': 171,
#   'bill_id': 9084,
#   'billed_amount': 4915.19,
#   'approved_amount': 4242.71,
#   'claim_status': 'Paid',
#   'payment_days': 40.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1826,
#   'age': 84,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '5/21/2025',
#   'visit_id': 9166,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 44.2,
#   'risk_score': 'Medium',
#   'doctor_id': 174,
#   'bill_id': 9166,
#   'billed_amount': 88539.01,
#   'approved_amount': 79650.12,
#   'claim_status': 'Paid',
#   'payment_days': 52.0,
#   'billing_date': '2026-01-10'},
#  {'patient_id': 1870,
#   'age': 61,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '5/8/2025',
#   'visit_id': 9377,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 62.63,
#   'risk_score': 'High',
#   'doctor_id': 184,
#   'bill_id': 9377,
#   'billed_amount': 88539.01,
#   'approved_amount': 75929.4,
#   'claim_status': 'Paid',
#   'payment_days': 52.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1915,
#   'age': 69,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/1/2025',
#   'visit_id': 9568,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.51,
#   'risk_score': 'Low',
#   'doctor_id': 103,
#   'bill_id': 9568,
#   'billed_amount': 4148.49,
#   'approved_amount': 1151.23,
#   'claim_status': 'Pending',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-15'},
#  {'patient_id': 1954,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/23/2025',
#   'visit_id': 9745,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.51,
#   'risk_score': 'Low',
#   'doctor_id': 137,
#   'bill_id': 9745,
#   'billed_amount': 33755.04,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 1960,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/20/2025',
#   'visit_id': 9773,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.64,
#   'risk_score': 'Low',
#   'doctor_id': 149,
#   'bill_id': 9773,
#   'billed_amount': 46381.65,
#   'approved_amount': 4500.35,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 1999,
#   'age': 23,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/30/2025',
#   'visit_id': 9972,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 41.76,
#   'risk_score': 'Low',
#   'doctor_id': 165,
#   'bill_id': 9972,
#   'billed_amount': 68365.35,
#   'approved_amount': 67480.57,
#   'claim_status': 'Paid',
#   'payment_days': 23.0,
#   'billing_date': '2026-01-09'},
#  {'patient_id': 2020,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '11/18/2025',
#   'visit_id': 10085,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.26,
#   'risk_score': 'Low',
#   'doctor_id': 137,
#   'bill_id': 10085,
#   'billed_amount': 14059.65,
#   'approved_amount': 13724.9,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2024,
#   'age': 17,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '11/21/2025',
#   'visit_id': 10106,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.48,
#   'risk_score': 'Medium',
#   'doctor_id': 128,
#   'bill_id': 10106,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-10'},
#  {'patient_id': 2037,
#   'age': 80,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/14/2025',
#   'visit_id': 10173,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 72.02,
#   'risk_score': 'High',
#   'doctor_id': 186,
#   'bill_id': 10173,
#   'billed_amount': 88539.01,
#   'approved_amount': 79700.77,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2093,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '9/29/2025',
#   'visit_id': 10453,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.59,
#   'risk_score': 'Low',
#   'doctor_id': 161,
#   'bill_id': 10453,
#   'billed_amount': 14880.96,
#   'approved_amount': 7422.86,
#   'claim_status': 'Pending',
#   'payment_days': 21.0,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 2107,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/5/2025',
#   'visit_id': 10511,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.03,
#   'risk_score': 'Low',
#   'doctor_id': 192,
#   'bill_id': 10511,
#   'billed_amount': 6145.51,
#   'approved_amount': 742.81,
#   'claim_status': 'Pending',
#   'payment_days': 30.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2163,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '11/12/2025',
#   'visit_id': 10797,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.97,
#   'risk_score': 'Low',
#   'doctor_id': 191,
#   'bill_id': 10797,
#   'billed_amount': 11914.94,
#   'approved_amount': 10947.89,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2181,
#   'age': 10,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '5/28/2025',
#   'visit_id': 10898,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.48,
#   'risk_score': 'Low',
#   'doctor_id': 166,
#   'bill_id': 10898,
#   'billed_amount': 16945.99,
#   'approved_amount': 15897.64,
#   'claim_status': 'Paid',
#   'payment_days': 40.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2191,
#   'age': 50,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/24/2025',
#   'visit_id': 10945,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 41.65,
#   'risk_score': 'High',
#   'doctor_id': 106,
#   'bill_id': 10945,
#   'billed_amount': 88539.01,
#   'approved_amount': 2958.21,
#   'claim_status': 'Pending',
#   'payment_days': 33.0,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 2233,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '4/23/2025',
#   'visit_id': 11164,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 77.67,
#   'risk_score': 'High',
#   'doctor_id': 123,
#   'bill_id': 11164,
#   'billed_amount': 88539.01,
#   'approved_amount': 29019.19,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 2273,
#   'age': 2,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/17/2025',
#   'visit_id': 11374,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.63,
#   'risk_score': 'Low',
#   'doctor_id': 156,
#   'bill_id': 11374,
#   'billed_amount': 3479.51,
#   'approved_amount': 3276.86,
#   'claim_status': 'Paid',
#   'payment_days': 51.0,
#   'billing_date': '2026-01-04'},
#  {'patient_id': 2286,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/3/2025',
#   'visit_id': 11444,
#   'visit_date': '1/1/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.17,
#   'risk_score': 'Low',
#   'doctor_id': 116,
#   'bill_id': 11444,
#   'billed_amount': 4286.03,
#   'approved_amount': 3755.53,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2026-01-10'},
#  {'patient_id': 2296,
#   'age': 12,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/16/2025',
#   'visit_id': 11485,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.73,
#   'risk_score': 'Medium',
#   'doctor_id': 135,
#   'bill_id': 11485,
#   'billed_amount': 5778.66,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 2331,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/21/2025',
#   'visit_id': 11660,
#   'visit_date': '1/1/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 33.9,
#   'risk_score': 'Medium',
#   'doctor_id': 193,
#   'bill_id': 11660,
#   'billed_amount': 75002.19,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-14'},
#  {'patient_id': 2384,
#   'age': 6,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '12/4/2025',
#   'visit_id': 11918,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.18,
#   'risk_score': 'Low',
#   'doctor_id': 128,
#   'bill_id': 11918,
#   'billed_amount': 16440.73,
#   'approved_amount': 14121.21,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2026-01-09'},
#  {'patient_id': 2406,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '6/23/2025',
#   'visit_id': 12025,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.64,
#   'risk_score': 'Low',
#   'doctor_id': 104,
#   'bill_id': 12025,
#   'billed_amount': 21331.95,
#   'approved_amount': 19823.95,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2026-01-18'},
#  {'patient_id': 2427,
#   'age': 21,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/11/2025',
#   'visit_id': 12129,
#   'visit_date': '1/1/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 34.71,
#   'risk_score': 'High',
#   'doctor_id': 199,
#   'bill_id': 12129,
#   'billed_amount': 88539.01,
#   'approved_amount': 4915.92,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 2431,
#   'age': 7,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '7/20/2025',
#   'visit_id': 12148,
#   'visit_date': '1/1/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 30.21,
#   'risk_score': 'Medium',
#   'doctor_id': 188,
#   'bill_id': 12148,
#   'billed_amount': 42443.33,
#   'approved_amount': 38763.87,
#   'claim_status': 'Paid',
#   'payment_days': 52.0,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 2507,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '12/13/2025',
#   'visit_id': 12534,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.41,
#   'risk_score': 'Medium',
#   'doctor_id': 162,
#   'bill_id': 12534,
#   'billed_amount': 20750.88,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-02'},
#  {'patient_id': 2588,
#   'age': 73,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2/10/2025',
#   'visit_id': 12928,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 45.62,
#   'risk_score': 'Medium',
#   'doctor_id': 176,
#   'bill_id': 12928,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-09'},
#  {'patient_id': 2633,
#   'age': 77,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/16/2025',
#   'visit_id': 13134,
#   'visit_date': '1/1/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 51.19,
#   'risk_score': 'Medium',
#   'doctor_id': 179,
#   'bill_id': 13134,
#   'billed_amount': 88539.01,
#   'approved_amount': 87219.04,
#   'claim_status': 'Paid',
#   'payment_days': 45.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 2633,
#   'age': 77,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/16/2025',
#   'visit_id': 13136,
#   'visit_date': '1/1/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
# ...
#   'chronic_flag': 1,
#   'registration_date': '6/14/2025',
#   'visit_id': 605,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.14,
#   'risk_score': 'Medium',
#   'doctor_id': 199,
#   'bill_id': 605,
#   'billed_amount': 13666.42,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 131,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '1/7/2026',
#   'visit_id': 660,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.66,
#   'risk_score': 'Medium',
#   'doctor_id': 172,
#   'bill_id': 660,
#   'billed_amount': 48457.49,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 142,
#   'age': 79,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/9/2026',
#   'visit_id': 715,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.27,
#   'risk_score': 'Low',
#   'doctor_id': 148,
#   'bill_id': 715,
#   'billed_amount': 18626.12,
#   'approved_amount': 7409.26,
#   'claim_status': 'Pending',
#   'payment_days': 41.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 217,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/11/2025',
#   'visit_id': 1053,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.34,
#   'risk_score': 'Medium',
#   'doctor_id': 196,
#   'bill_id': 1053,
#   'billed_amount': 17922.78,
#   'approved_amount': 16581.33,
#   'claim_status': 'Paid',
#   'payment_days': 35.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 230,
#   'age': 16,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2/12/2025',
#   'visit_id': 1127,
#   'visit_date': '1/13/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 56.34,
#   'risk_score': 'High',
#   'doctor_id': 199,
#   'bill_id': 1127,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 33.0,
#   'billing_date': '2026-01-18'},
#  {'patient_id': 258,
#   'age': 7,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '11/2/2025',
#   'visit_id': 1278,
#   'visit_date': '1/13/2026',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.04,
#   'risk_score': 'High',
#   'doctor_id': 181,
#   'bill_id': 1278,
#   'billed_amount': 46583.04,
#   'approved_amount': 6267.62,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 276,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '12/29/2025',
#   'visit_id': 1364,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.53,
#   'risk_score': 'Low',
#   'doctor_id': 139,
#   'bill_id': 1364,
#   'billed_amount': 26125.88,
#   'approved_amount': 25434.0,
#   'claim_status': 'Paid',
#   'payment_days': 40.0,
#   'billing_date': '2026-01-17'},
#  {'patient_id': 301,
#   'age': 8,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '9/6/2025',
#   'visit_id': 1485,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.73,
#   'risk_score': 'Low',
#   'doctor_id': 102,
#   'bill_id': 1485,
#   'billed_amount': 40085.23,
#   'approved_amount': 34570.07,
#   'claim_status': 'Paid',
#   'payment_days': 48.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 327,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '7/18/2025',
#   'visit_id': 1628,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.26,
#   'risk_score': 'Low',
#   'doctor_id': 191,
#   'bill_id': 1628,
#   'billed_amount': 14568.73,
#   'approved_amount': 12833.68,
#   'claim_status': 'Paid',
#   'payment_days': 32.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 356,
#   'age': 23,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/13/2025',
#   'visit_id': 1778,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.75,
#   'risk_score': 'Low',
#   'doctor_id': 128,
#   'bill_id': 1778,
#   'billed_amount': 9950.02,
#   'approved_amount': 9365.22,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 364,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2/26/2025',
#   'visit_id': 1819,
#   'visit_date': '1/13/2026',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.72,
#   'risk_score': 'Medium',
#   'doctor_id': 199,
#   'bill_id': 1819,
#   'billed_amount': 56410.84,
#   'approved_amount': 55981.63,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 365,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '1/12/2026',
#   'visit_id': 1829,
#   'visit_date': '1/13/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.43,
#   'risk_score': 'High',
#   'doctor_id': 105,
#   'bill_id': 1829,
#   'billed_amount': 88539.01,
#   'approved_amount': 78865.8,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 390,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/5/2026',
#   'visit_id': 1942,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.28,
#   'risk_score': 'Medium',
#   'doctor_id': 189,
#   'bill_id': 1942,
#   'billed_amount': 21031.11,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 390,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/5/2026',
#   'visit_id': 1943,
#   'visit_date': '1/13/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 126,
#   'bill_id': 1943,
#   'billed_amount': 88539.01,
#   'approved_amount': 22752.26,
#   'claim_status': 'Pending',
#   'payment_days': 24.0,
#   'billing_date': '2026-01-19'},
#  {'patient_id': 390,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/5/2026',
#   'visit_id': 1946,
#   'visit_date': '1/13/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 43.24,
#   'risk_score': 'Medium',
#   'doctor_id': 108,
#   'bill_id': 1946,
#   'billed_amount': 83431.38,
#   'approved_amount': 82793.73,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 416,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '11/14/2025',
#   'visit_id': 2068,
#   'visit_date': '1/13/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.74,
#   'risk_score': 'Low',
#   'doctor_id': 131,
#   'bill_id': 2068,
#   'billed_amount': 67144.5,
#   'approved_amount': 62182.47,
#   'claim_status': 'Paid',
#   'payment_days': 52.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 428,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '1/6/2026',
#   'visit_id': 2116,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.28,
#   'risk_score': 'Low',
#   'doctor_id': 170,
#   'bill_id': 2116,
#   'billed_amount': 8933.17,
#   'approved_amount': 2669.13,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-14'},
#  {'patient_id': 467,
#   'age': 10,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '4/30/2025',
#   'visit_id': 2329,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.16,
#   'risk_score': 'Low',
#   'doctor_id': 137,
#   'bill_id': 2329,
#   'billed_amount': 14851.7,
#   'approved_amount': 12700.76,
#   'claim_status': 'Paid',
#   'payment_days': 31.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 479,
#   'age': 80,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '12/3/2025',
#   'visit_id': 2397,
#   'visit_date': '1/13/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 62.19,
#   'risk_score': 'High',
#   'doctor_id': 122,
#   'bill_id': 2397,
#   'billed_amount': 88539.01,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 499,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '12/28/2025',
#   'visit_id': 2506,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.73,
#   'risk_score': 'Low',
#   'doctor_id': 168,
#   'bill_id': 2506,
#   'billed_amount': 7428.14,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 534,
#   'age': 12,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '5/30/2025',
#   'visit_id': 2684,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.15,
#   'risk_score': 'Low',
#   'doctor_id': 199,
#   'bill_id': 2684,
#   'billed_amount': 24684.36,
#   'approved_amount': 2158.97,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 542,
#   'age': 84,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '3/22/2025',
#   'visit_id': 2733,
#   'visit_date': '1/13/2026',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 78.42,
#   'risk_score': 'High',
#   'doctor_id': 136,
#   'bill_id': 2733,
#   'billed_amount': 88539.01,
#   'approved_amount': 8816.09,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 546,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '11/12/2025',
#   'visit_id': 2757,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.7,
#   'risk_score': 'Low',
#   'doctor_id': 149,
#   'bill_id': 2757,
#   'billed_amount': 32229.21,
#   'approved_amount': 29615.86,
#   'claim_status': 'Paid',
#   'payment_days': 46.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 592,
#   'age': 27,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '6/3/2025',
#   'visit_id': 3000,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.47,
#   'risk_score': 'Low',
#   'doctor_id': 191,
#   'bill_id': 3000,
#   'billed_amount': 13713.47,
#   'approved_amount': 13416.07,
#   'claim_status': 'Paid',
#   'payment_days': 50.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 601,
#   'age': 86,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '1/7/2026',
#   'visit_id': 3054,
#   'visit_date': '1/13/2026',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.55,
#   'risk_score': 'High',
#   'doctor_id': 141,
#   'bill_id': 3054,
#   'billed_amount': 23333.47,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 614,
#   'age': 74,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '9/29/2025',
#   'visit_id': 3123,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.08,
#   'risk_score': 'Low',
#   'doctor_id': 164,
#   'bill_id': 3123,
#   'billed_amount': 8721.68,
#   'approved_amount': 8721.45,
#   'claim_status': 'Paid',
#   'payment_days': 49.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 620,
#   'age': 13,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '12/22/2025',
#   'visit_id': 3159,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.97,
#   'risk_score': 'Low',
#   'doctor_id': 155,
#   'bill_id': 3159,
#   'billed_amount': 7253.62,
#   'approved_amount': 7181.39,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 644,
#   'age': 80,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '3/8/2025',
#   'visit_id': 3271,
#   'visit_date': '1/13/2026',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.22,
#   'risk_score': 'Medium',
#   'doctor_id': 118,
#   'bill_id': 3271,
#   'billed_amount': 48407.86,
#   'approved_amount': 47763.24,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 653,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '10/18/2025',
#   'visit_id': 3317,
#   'visit_date': '1/13/2026',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.47,
#   'risk_score': 'Low',
#   'doctor_id': 149,
#   'bill_id': 3317,
#   'billed_amount': 12398.83,
#   'approved_amount': 1176.42,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 656,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '12/24/2025',
#   'visit_id': 3340,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.91,
#   'risk_score': 'Low',
#   'doctor_id': 179,
#   'bill_id': 3340,
#   'billed_amount': 20058.83,
#   'approved_amount': 18156.98,
#   'claim_status': 'Paid',
#   'payment_days': 47.0,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 669,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '8/17/2025',
#   'visit_id': 3392,
#   'visit_date': '1/13/2026',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 33.26,
#   'risk_score': 'Medium',
#   'doctor_id': 180,
#   'bill_id': 3392,
#   'billed_amount': 48151.37,
#   'approved_amount': 11407.72,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  {'patient_id': 709,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '8/3/2025',
#   'visit_id': 3575,
#   'visit_date': '1/13/2026',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.39,
#   'risk_score': 'Low',
#   'doctor_id': 189,
#   'bill_id': 3575,
#   'billed_amount': 29707.35,
#   'approved_amount': 391.89,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-20'},
#  ...]

# %%
import pymongo
import pandas as pd
DB_NAME="hospital_miops"
COLLECTION_MODEL_TABLE="model_table_df"
CONNECTION_URL="now"

client=pymongo.MongoClient(CONNECTION_URL)
db=client[DB_NAME]
model_table_collection=db[COLLECTION_MODEL_TABLE]


model_table=model_table_collection.insert_many(model_table_df)

# %%
model_table_df=pd.DataFrame(list(model_table_collection.find()))
model_table_df.head()
# Out:
#                         _id  patient_id  age gender       city  \
# 0  6a32926c02c411335d6fa4a0        3393   43      M  Hyderabad
# 1  6a32926c02c411335d6fa4bd        4887   31      M       Pune
# 2  6a32926c02c411335d6fa4d8         493   46      M  Bangalore
# 3  6a32926c02c411335d6fa4de        1549   58      F  Hyderabad
# 4  6a32926c02c411335d6fa4ec         434   57      F    Chennai
#
#   insurance_provider  chronic_flag registration_date  visit_id  visit_date  \
# 0         HealthPlus             0        2025-07-10      1510  2025-01-20
# 1         HealthPlus             1        2025-10-01      9727  2025-01-20
# 2          MediCareX             1        2025-06-07     19504  2025-01-20
# 3         SecureLife             0        2025-03-13     21687  2025-01-20
# 4          MediCareX             0        2026-01-03      2754  2025-01-21
#
#    ... visit_type length_of_stay_hours  risk_score doctor_id  bill_id  \
# 0  ...        ICU                31.37      Medium       135     1510
# 1  ...        ICU                 3.47         Low       160     9727
# 2  ...        ICU                18.44         Low       144    19504
# 3  ...        ICU                37.49      Medium       145    21687
# 4  ...        ICU                 8.49         Low       136     2754
#
#    billed_amount  approved_amount  claim_status payment_days  billing_date
# 0       16529.35             0.00      Rejected          7.0    2025-04-24
# 1       15948.64             0.00      Rejected          2.0    2025-12-21
# 2       20313.48         20313.48          Paid         17.0    2025-05-06
# 3       25607.61         16108.89       Pending          2.0    2025-04-23
# 4         500.00           500.00          Paid         19.0    2025-05-11
#
# [5 rows x 21 columns]

# %%
if"_id" in model_table_df.columns:
    model_table_df.drop("_id",axis=1,inplace=True)
    
model_table_df.head()
# Out:
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0        3393   43      M  Hyderabad         HealthPlus             0
# 1        4887   31      M       Pune         HealthPlus             1
# 2         493   46      M  Bangalore          MediCareX             1
# 3        1549   58      F  Hyderabad         SecureLife             0
# 4         434   57      F    Chennai          MediCareX             0
#
#   registration_date  visit_id  visit_date department visit_type  \
# 0        2025-07-10      1510  2025-01-20        ICU        ICU
# 1        2025-10-01      9727  2025-01-20         ER        ICU
# 2        2025-06-07     19504  2025-01-20        ICU        ICU
# 3        2025-03-13     21687  2025-01-20    General        ICU
# 4        2026-01-03      2754  2025-01-21        ICU        ICU
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                 31.37     Medium        135     1510       16529.35
# 1                  3.47        Low        160     9727       15948.64
# 2                 18.44        Low        144    19504       20313.48
# 3                 37.49     Medium        145    21687       25607.61
# 4                  8.49        Low        136     2754         500.00
#
#    approved_amount claim_status  payment_days billing_date
# 0             0.00     Rejected           7.0   2025-04-24
# 1             0.00     Rejected           2.0   2025-12-21
# 2         20313.48         Paid          17.0   2025-05-06
# 3         16108.89      Pending           2.0   2025-04-23
# 4           500.00         Paid          19.0   2025-05-11

# %%
conn.close()
print("Database connection closed successfully")
# Out:
# Database connection closed successfully
