# %% [markdown]
# ### import csv and check shape

# %%
import pandas as pd
import os

# %%
billing = pd.read_csv("data/billing.csv")
visits = pd.read_csv("data/visits.csv")
patient = pd.read_csv("data/patients.csv")

print("patient shape :",patient.shape)
print("billing shape :",billing.shape)
print("visits shape :",visits.shape)
# Out:
# patient shape : (5000, 7)
# billing shape : (25000, 7)
# visits shape : (25000, 8)

# %%
billing_data= billing.to_dict(orient="records")
billing_data
# Out:
# [{'bill_id': 1,
#   'visit_id': 1,
#   'billed_amount': 23577.37,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 16.0,
#   'billing_date': '2025-06-18'},
#  {'bill_id': 2,
#   'visit_id': 2,
#   'billed_amount': 38178.81,
#   'approved_amount': 38178.81,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-10-09'},
#  {'bill_id': 3,
#   'visit_id': 3,
#   'billed_amount': 5038.97,
#   'approved_amount': 5038.97,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-01-20'},
#  {'bill_id': 4,
#   'visit_id': 4,
#   'billed_amount': 22813.34,
#   'approved_amount': 22813.34,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 5,
#   'visit_id': 5,
#   'billed_amount': 27106.95,
#   'approved_amount': 27106.95,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 6,
#   'visit_id': 6,
#   'billed_amount': 19453.77,
#   'approved_amount': 19453.77,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-12'},
#  {'bill_id': 7,
#   'visit_id': 7,
#   'billed_amount': 6269.47,
#   'approved_amount': 4437.65,
#   'claim_status': 'Pending',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-16'},
#  {'bill_id': 8,
#   'visit_id': 8,
#   'billed_amount': 38178.73,
#   'approved_amount': 38178.73,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-06-27'},
#  {'bill_id': 9,
#   'visit_id': 9,
#   'billed_amount': 21258.56,
#   'approved_amount': 21258.56,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-10-06'},
#  {'bill_id': 10,
#   'visit_id': 10,
#   'billed_amount': 18161.42,
#   'approved_amount': 18161.42,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-07-16'},
#  {'bill_id': 11,
#   'visit_id': 11,
#   'billed_amount': 67173.53,
#   'approved_amount': 67173.53,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-10-14'},
#  {'bill_id': 12,
#   'visit_id': 12,
#   'billed_amount': 28707.29,
#   'approved_amount': 28707.29,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-04-13'},
#  {'bill_id': 13,
#   'visit_id': 13,
#   'billed_amount': 40519.31,
#   'approved_amount': 40519.31,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-06-05'},
#  {'bill_id': 14,
#   'visit_id': 14,
#   'billed_amount': 13584.7,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-03-06'},
#  {'bill_id': 15,
#   'visit_id': 15,
#   'billed_amount': 500.0,
#   'approved_amount': 500.0,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-06-23'},
#  {'bill_id': 16,
#   'visit_id': 16,
#   'billed_amount': 35715.64,
#   'approved_amount': 35715.64,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 17,
#   'visit_id': 17,
#   'billed_amount': 12504.15,
#   'approved_amount': 12504.15,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-11-23'},
#  {'bill_id': 18,
#   'visit_id': 18,
#   'billed_amount': 22747.32,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 6.0,
#   'billing_date': '2025-04-17'},
#  {'bill_id': 19,
#   'visit_id': 19,
#   'billed_amount': 27057.64,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 8.0,
#   'billing_date': '2025-10-20'},
#  {'bill_id': 20,
#   'visit_id': 20,
#   'billed_amount': 22973.3,
#   'approved_amount': 14714.66,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-10-03'},
#  {'bill_id': 21,
#   'visit_id': 21,
#   'billed_amount': 19675.19,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 21.0,
#   'billing_date': '2025-04-18'},
#  {'bill_id': 22,
#   'visit_id': 22,
#   'billed_amount': 31418.34,
#   'approved_amount': 31418.34,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-11-16'},
#  {'bill_id': 23,
#   'visit_id': 23,
#   'billed_amount': 37342.68,
#   'approved_amount': 37342.68,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 24,
#   'visit_id': 24,
#   'billed_amount': 23945.34,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 11.0,
#   'billing_date': '2025-03-10'},
#  {'bill_id': 25,
#   'visit_id': 25,
#   'billed_amount': 22471.65,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 26.0,
#   'billing_date': '2025-05-04'},
#  {'bill_id': 26,
#   'visit_id': 26,
#   'billed_amount': 28546.45,
#   'approved_amount': 28546.45,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-02-09'},
#  {'bill_id': 27,
#   'visit_id': 27,
#   'billed_amount': 17856.85,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 19.0,
#   'billing_date': '2025-03-14'},
#  {'bill_id': 28,
#   'visit_id': 28,
#   'billed_amount': 38162.87,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-09-30'},
#  {'bill_id': 29,
#   'visit_id': 29,
#   'billed_amount': 6851.33,
#   'approved_amount': 6851.33,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-03-23'},
#  {'bill_id': 30,
#   'visit_id': 30,
#   'billed_amount': 16187.46,
#   'approved_amount': 16187.46,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-10-03'},
#  {'bill_id': 31,
#   'visit_id': 31,
#   'billed_amount': 24205.08,
#   'approved_amount': 16925.68,
#   'claim_status': 'Pending',
#   'payment_days': 23.0,
#   'billing_date': '2025-06-01'},
#  {'bill_id': 32,
#   'visit_id': 32,
#   'billed_amount': 4515.5,
#   'approved_amount': 4515.5,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2026-01-15'},
#  {'bill_id': 33,
#   'visit_id': 33,
#   'billed_amount': 10524.42,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 10.0,
#   'billing_date': '2025-03-04'},
#  {'bill_id': 34,
#   'visit_id': 34,
#   'billed_amount': 5893.5,
#   'approved_amount': 5893.5,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-06-20'},
#  {'bill_id': 35,
#   'visit_id': 35,
#   'billed_amount': 27633.69,
#   'approved_amount': 19531.97,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-06-04'},
#  {'bill_id': 36,
#   'visit_id': 36,
#   'billed_amount': 45946.24,
#   'approved_amount': 45946.24,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-08-31'},
#  {'bill_id': 37,
#   'visit_id': 37,
#   'billed_amount': 27971.27,
#   'approved_amount': 27971.27,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-02-06'},
#  {'bill_id': 38,
#   'visit_id': 38,
#   'billed_amount': 22795.89,
#   'approved_amount': 16428.31,
#   'claim_status': 'Pending',
#   'payment_days': 6.0,
#   'billing_date': '2025-03-03'},
#  {'bill_id': 39,
#   'visit_id': 39,
#   'billed_amount': 17192.08,
#   'approved_amount': 17192.08,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-03-28'},
#  {'bill_id': 40,
#   'visit_id': 40,
#   'billed_amount': 73969.13,
#   'approved_amount': 73969.13,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-10-31'},
#  {'bill_id': 41,
#   'visit_id': 41,
#   'billed_amount': 12924.18,
#   'approved_amount': 12924.18,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-06-03'},
#  {'bill_id': 42,
#   'visit_id': 42,
#   'billed_amount': 42479.44,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-08-02'},
#  {'bill_id': 43,
#   'visit_id': 43,
#   'billed_amount': 21254.64,
#   'approved_amount': 21254.64,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2025-06-02'},
#  {'bill_id': 44,
#   'visit_id': 44,
#   'billed_amount': 48235.07,
#   'approved_amount': 48235.07,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-12-09'},
#  {'bill_id': 45,
#   'visit_id': 45,
#   'billed_amount': 16183.51,
#   'approved_amount': 12921.2,
#   'claim_status': 'Pending',
#   'payment_days': 17.0,
#   'billing_date': '2025-04-05'},
#  {'bill_id': 46,
#   'visit_id': 46,
#   'billed_amount': 32966.33,
#   'approved_amount': 32966.33,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-06-30'},
#  {'bill_id': 47,
#   'visit_id': 47,
#   'billed_amount': 27393.16,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 8.0,
#   'billing_date': '2025-08-09'},
#  {'bill_id': 48,
#   'visit_id': 48,
#   'billed_amount': 27314.84,
#   'approved_amount': 27314.84,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-04-30'},
#  {'bill_id': 49,
#   'visit_id': 49,
#   'billed_amount': 25679.0,
#   'approved_amount': 18086.57,
#   'claim_status': 'Pending',
#   'payment_days': 29.0,
#   'billing_date': '2025-11-11'},
#  {'bill_id': 50,
#   'visit_id': 50,
#   'billed_amount': 26911.8,
#   'approved_amount': 26911.8,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 51,
#   'visit_id': 51,
#   'billed_amount': 27290.81,
#   'approved_amount': 18977.87,
#   'claim_status': 'Pending',
#   'payment_days': 25.0,
#   'billing_date': '2025-08-13'},
#  {'bill_id': 52,
#   'visit_id': 52,
#   'billed_amount': 24578.38,
#   'approved_amount': 14552.77,
#   'claim_status': 'Pending',
#   'payment_days': 13.0,
#   'billing_date': '2025-09-18'},
#  {'bill_id': 53,
#   'visit_id': 53,
#   'billed_amount': 2465.08,
#   'approved_amount': 2465.08,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-13'},
#  {'bill_id': 54,
#   'visit_id': 54,
#   'billed_amount': 20194.57,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 17.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 55,
#   'visit_id': 55,
#   'billed_amount': 16188.62,
#   'approved_amount': 16188.62,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-09-27'},
#  {'bill_id': 56,
#   'visit_id': 56,
#   'billed_amount': 38872.98,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-06-08'},
#  {'bill_id': 57,
#   'visit_id': 57,
#   'billed_amount': 25262.34,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 18.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 58,
#   'visit_id': 58,
#   'billed_amount': 3753.73,
#   'approved_amount': 2369.49,
#   'claim_status': 'Pending',
#   'payment_days': 12.0,
#   'billing_date': '2026-01-07'},
#  {'bill_id': 59,
#   'visit_id': 59,
#   'billed_amount': 29548.02,
#   'approved_amount': 29548.02,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2025-08-15'},
#  {'bill_id': 60,
#   'visit_id': 60,
#   'billed_amount': 19675.77,
#   'approved_amount': 19675.77,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-09-06'},
#  {'bill_id': 61,
#   'visit_id': 61,
#   'billed_amount': 13673.72,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-11-19'},
#  {'bill_id': 62,
#   'visit_id': 62,
#   'billed_amount': 6278.88,
#   'approved_amount': 6278.88,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-11-18'},
#  {'bill_id': 63,
#   'visit_id': 63,
#   'billed_amount': 15201.02,
#   'approved_amount': 15201.02,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-11-01'},
#  {'bill_id': 64,
#   'visit_id': 64,
#   'billed_amount': 18861.19,
#   'approved_amount': 18861.19,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-10-08'},
#  {'bill_id': 65,
#   'visit_id': 65,
#   'billed_amount': 31990.78,
#   'approved_amount': 21941.52,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-10-02'},
#  {'bill_id': 66,
#   'visit_id': 66,
#   'billed_amount': 28126.25,
#   'approved_amount': 28126.25,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-07-15'},
#  {'bill_id': 67,
#   'visit_id': 67,
#   'billed_amount': 13592.74,
#   'approved_amount': 13592.74,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-04-10'},
#  {'bill_id': 68,
#   'visit_id': 68,
#   'billed_amount': 3202.97,
#   'approved_amount': 2641.89,
#   'claim_status': 'Pending',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-01'},
#  {'bill_id': 69,
#   'visit_id': 69,
#   'billed_amount': 14662.16,
#   'approved_amount': 14662.16,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-06-23'},
#  {'bill_id': 70,
#   'visit_id': 70,
#   'billed_amount': 19288.95,
#   'approved_amount': 11886.22,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-06-24'},
#  {'bill_id': 71,
#   'visit_id': 71,
#   'billed_amount': 6302.28,
#   'approved_amount': 6302.28,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-04-15'},
#  {'bill_id': 72,
#   'visit_id': 72,
#   'billed_amount': 25833.24,
#   'approved_amount': 25833.24,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-02-06'},
#  {'bill_id': 73,
#   'visit_id': 73,
#   'billed_amount': 8644.27,
#   'approved_amount': 8644.27,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-07-20'},
#  {'bill_id': 74,
#   'visit_id': 74,
#   'billed_amount': 22838.64,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 22.0,
#   'billing_date': '2025-12-13'},
#  {'bill_id': 75,
#   'visit_id': 75,
#   'billed_amount': 3477.97,
#   'approved_amount': 3477.97,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-12-15'},
#  {'bill_id': 76,
#   'visit_id': 76,
#   'billed_amount': 20281.3,
#   'approved_amount': 20281.3,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-04-18'},
#  {'bill_id': 77,
#   'visit_id': 77,
#   'billed_amount': 16469.11,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 2.0,
#   'billing_date': '2025-10-27'},
#  {'bill_id': 78,
#   'visit_id': 78,
#   'billed_amount': 14754.72,
#   'approved_amount': 14754.72,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-05-14'},
#  {'bill_id': 79,
#   'visit_id': 79,
#   'billed_amount': 15595.63,
#   'approved_amount': 15595.63,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-10-08'},
#  {'bill_id': 80,
#   'visit_id': 80,
#   'billed_amount': 35291.26,
#   'approved_amount': 35291.26,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-04-29'},
#  {'bill_id': 81,
#   'visit_id': 81,
#   'billed_amount': 19121.91,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-22'},
#  {'bill_id': 82,
#   'visit_id': 82,
#   'billed_amount': 35287.06,
#   'approved_amount': 35287.06,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-08-02'},
#  {'bill_id': 83,
#   'visit_id': 83,
#   'billed_amount': 17852.54,
#   'approved_amount': 17852.54,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-03-16'},
#  {'bill_id': 84,
#   'visit_id': 84,
#   'billed_amount': 11212.48,
#   'approved_amount': 11212.48,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2026-01-02'},
#  {'bill_id': 85,
#   'visit_id': 85,
#   'billed_amount': 22294.34,
#   'approved_amount': 22294.34,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-10-30'},
#  {'bill_id': 86,
#   'visit_id': 86,
#   'billed_amount': 30899.47,
#   'approved_amount': 30899.47,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-12-24'},
#  {'bill_id': 87,
#   'visit_id': 87,
#   'billed_amount': 19498.13,
#   'approved_amount': 19498.13,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-05-28'},
#  {'bill_id': 88,
#   'visit_id': 88,
#   'billed_amount': 37790.01,
#   'approved_amount': 37790.01,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-06-24'},
#  {'bill_id': 89,
#   'visit_id': 89,
#   'billed_amount': 20657.89,
#   'approved_amount': 13996.82,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-03-25'},
#  {'bill_id': 90,
#   'visit_id': 90,
#   'billed_amount': 12767.99,
#   'approved_amount': 12767.99,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-07-01'},
#  {'bill_id': 91,
#   'visit_id': 91,
#   'billed_amount': 27703.97,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-06-09'},
#  {'bill_id': 92,
#   'visit_id': 92,
#   'billed_amount': 11434.68,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 9.0,
#   'billing_date': '2025-09-21'},
#  {'bill_id': 93,
#   'visit_id': 93,
#   'billed_amount': 31323.86,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 21.0,
#   'billing_date': '2026-01-17'},
#  {'bill_id': 94,
#   'visit_id': 94,
#   'billed_amount': 2693.11,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 14.0,
#   'billing_date': '2026-01-09'},
#  {'bill_id': 95,
#   'visit_id': 95,
#   'billed_amount': 3681.58,
#   'approved_amount': 3135.24,
#   'claim_status': 'Pending',
#   'payment_days': 16.0,
#   'billing_date': '2025-10-05'},
#  {'bill_id': 96,
#   'visit_id': 96,
#   'billed_amount': 22328.26,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-03'},
#  {'bill_id': 97,
#   'visit_id': 97,
#   'billed_amount': 10536.41,
#   'approved_amount': 10536.41,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-09-29'},
#  {'bill_id': 98,
#   'visit_id': 98,
#   'billed_amount': 25744.31,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-02-22'},
#  {'bill_id': 99,
#   'visit_id': 99,
#   'billed_amount': 37780.91,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 19.0,
#   'billing_date': '2025-11-25'},
#  {'bill_id': 100,
#   'visit_id': 100,
#   'billed_amount': 48517.28,
#   'approved_amount': 48517.28,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-04-21'},
#  {'bill_id': 101,
#   'visit_id': 101,
#   'billed_amount': 17551.46,
#   'approved_amount': 17551.46,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-09-24'},
#  {'bill_id': 102,
#   'visit_id': 102,
#   'billed_amount': 12665.02,
#   'approved_amount': 12665.02,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-07-05'},
#  {'bill_id': 103,
#   'visit_id': 103,
#   'billed_amount': 24050.53,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 6.0,
#   'billing_date': '2025-05-29'},
#  {'bill_id': 104,
#   'visit_id': 104,
#   'billed_amount': 36494.63,
#   'approved_amount': 36494.63,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-04-26'},
#  {'bill_id': 105,
#   'visit_id': 105,
#   'billed_amount': 27755.16,
#   'approved_amount': 27755.16,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-08-07'},
#  {'bill_id': 106,
#   'visit_id': 106,
#   'billed_amount': 37210.04,
#   'approved_amount': 29482.68,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-02-12'},
#  {'bill_id': 107,
#   'visit_id': 107,
#   'billed_amount': 10425.86,
#   'approved_amount': 10425.86,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-02-13'},
#  {'bill_id': 108,
#   'visit_id': 108,
#   'billed_amount': 36760.4,
#   'approved_amount': 23524.0,
#   'claim_status': 'Pending',
#   'payment_days': 11.0,
#   'billing_date': '2025-08-27'},
#  {'bill_id': 109,
#   'visit_id': 109,
#   'billed_amount': 1233.62,
#   'approved_amount': 911.46,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-20'},
#  {'bill_id': 110,
#   'visit_id': 110,
#   'billed_amount': 30151.08,
#   'approved_amount': 22537.77,
#   'claim_status': 'Pending',
#   'payment_days': 30.0,
#   'billing_date': '2025-03-16'},
#  {'bill_id': 111,
#   'visit_id': 111,
#   'billed_amount': 26557.88,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 16.0,
#   'billing_date': '2025-02-21'},
#  {'bill_id': 112,
#   'visit_id': 112,
#   'billed_amount': 9248.4,
#   'approved_amount': 9248.4,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-11-23'},
#  {'bill_id': 113,
#   'visit_id': 113,
#   'billed_amount': 12095.72,
#   'approved_amount': 8952.02,
#   'claim_status': 'Pending',
#   'payment_days': 36.0,
#   'billing_date': '2025-09-16'},
#  {'bill_id': 114,
#   'visit_id': 114,
#   'billed_amount': 44069.82,
#   'approved_amount': 44069.82,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-04-01'},
#  {'bill_id': 115,
#   'visit_id': 115,
#   'billed_amount': 12600.68,
#   'approved_amount': 12600.68,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-05-22'},
#  {'bill_id': 116,
#   'visit_id': 116,
#   'billed_amount': 44927.83,
#   'approved_amount': 23955.06,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-11-06'},
#  {'bill_id': 117,
#   'visit_id': 117,
#   'billed_amount': 2102.84,
#   'approved_amount': 1826.24,
#   'claim_status': 'Pending',
#   'payment_days': 36.0,
#   'billing_date': '2025-07-04'},
#  {'bill_id': 118,
#   'visit_id': 118,
#   'billed_amount': 14080.21,
#   'approved_amount': 14080.21,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-06-05'},
#  {'bill_id': 119,
#   'visit_id': 119,
#   'billed_amount': 24515.58,
#   'approved_amount': 13859.72,
#   'claim_status': 'Pending',
#   'payment_days': 14.0,
#   'billing_date': '2025-11-19'},
#  {'bill_id': 120,
#   'visit_id': 120,
#   'billed_amount': 23218.37,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 121,
#   'visit_id': 121,
#   'billed_amount': 30825.01,
#   'approved_amount': 30825.01,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-06-30'},
#  {'bill_id': 122,
#   'visit_id': 122,
#   'billed_amount': 8601.64,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 4.0,
#   'billing_date': '2025-03-28'},
#  {'bill_id': 123,
#   'visit_id': 123,
#   'billed_amount': 29746.87,
#   'approved_amount': 29746.87,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-08-20'},
#  {'bill_id': 124,
#   'visit_id': 124,
#   'billed_amount': 19431.43,
#   'approved_amount': 19431.43,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-08-31'},
#  {'bill_id': 125,
#   'visit_id': 125,
#   'billed_amount': 15123.93,
#   'approved_amount': 15123.93,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-04-20'},
#  {'bill_id': 126,
#   'visit_id': 126,
#   'billed_amount': 10968.98,
#   'approved_amount': 10968.98,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-05-19'},
#  {'bill_id': 127,
#   'visit_id': 127,
#   'billed_amount': 20132.46,
#   'approved_amount': 20132.46,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-07-10'},
#  {'bill_id': 128,
#   'visit_id': 128,
#   'billed_amount': 10197.2,
#   'approved_amount': 10197.2,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-03-13'},
#  {'bill_id': 129,
#   'visit_id': 129,
#   'billed_amount': 3185.19,
#   'approved_amount': 3185.19,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-02-07'},
#  {'bill_id': 130,
#   'visit_id': 130,
#   'billed_amount': 5161.55,
#   'approved_amount': 5161.55,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2026-01-05'},
#  {'bill_id': 131,
#   'visit_id': 131,
#   'billed_amount': 36734.15,
#   'approved_amount': 36734.15,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-01'},
#  {'bill_id': 132,
#   'visit_id': 132,
#   'billed_amount': 5816.18,
#   'approved_amount': 5167.5,
#   'claim_status': 'Pending',
#   'payment_days': 16.0,
#   'billing_date': '2026-01-19'},
#  {'bill_id': 133,
#   'visit_id': 133,
#   'billed_amount': 500.0,
#   'approved_amount': 500.0,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-03-08'},
#  {'bill_id': 134,
#   'visit_id': 134,
#   'billed_amount': 44184.62,
#   'approved_amount': 44184.62,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-11-18'},
#  {'bill_id': 135,
#   'visit_id': 135,
#   'billed_amount': 15760.49,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-03-25'},
#  {'bill_id': 136,
#   'visit_id': 136,
#   'billed_amount': 15836.0,
#   'approved_amount': 12167.41,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-12-04'},
#  {'bill_id': 137,
#   'visit_id': 137,
#   'billed_amount': 29154.13,
#   'approved_amount': 29154.13,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-08-11'},
#  {'bill_id': 138,
#   'visit_id': 138,
#   'billed_amount': 18673.27,
#   'approved_amount': 14898.42,
#   'claim_status': 'Pending',
#   'payment_days': 3.0,
#   'billing_date': '2025-03-05'},
#  {'bill_id': 139,
#   'visit_id': 139,
#   'billed_amount': 22997.0,
#   'approved_amount': 22997.0,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-17'},
#  {'bill_id': 140,
#   'visit_id': 140,
#   'billed_amount': 10358.16,
#   'approved_amount': 8503.42,
#   'claim_status': 'Pending',
#   'payment_days': 8.0,
#   'billing_date': '2025-02-22'},
#  {'bill_id': 141,
#   'visit_id': 141,
#   'billed_amount': 18341.39,
#   'approved_amount': 18341.39,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-02-03'},
#  {'bill_id': 142,
#   'visit_id': 142,
#   'billed_amount': 24760.98,
#   'approved_amount': 19819.77,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-09-03'},
#  {'bill_id': 143,
#   'visit_id': 143,
#   'billed_amount': 35226.97,
#   'approved_amount': 35226.97,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-14'},
#  {'bill_id': 144,
#   'visit_id': 144,
#   'billed_amount': 39218.24,
#   'approved_amount': 33792.0,
#   'claim_status': 'Pending',
#   'payment_days': 13.0,
#   'billing_date': '2025-03-30'},
#  {'bill_id': 145,
#   'visit_id': 145,
#   'billed_amount': 29024.17,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-03-10'},
#  {'bill_id': 146,
#   'visit_id': 146,
#   'billed_amount': 20193.38,
#   'approved_amount': 20193.38,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-06-27'},
#  {'bill_id': 147,
#   'visit_id': 147,
#   'billed_amount': 18039.5,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 9.0,
#   'billing_date': '2025-02-21'},
#  {'bill_id': 148,
#   'visit_id': 148,
#   'billed_amount': 5061.51,
#   'approved_amount': 2554.55,
#   'claim_status': 'Pending',
#   'payment_days': 3.0,
#   'billing_date': '2025-05-18'},
#  {'bill_id': 149,
#   'visit_id': 149,
#   'billed_amount': 35624.0,
#   'approved_amount': 35624.0,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 150,
#   'visit_id': 150,
#   'billed_amount': 1691.22,
#   'approved_amount': 1691.22,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-10-02'},
#  {'bill_id': 151,
#   'visit_id': 151,
#   'billed_amount': 16632.76,
#   'approved_amount': 16632.76,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-03-19'},
#  {'bill_id': 152,
#   'visit_id': 152,
#   'billed_amount': 27574.08,
#   'approved_amount': 27574.08,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-06-29'},
#  {'bill_id': 153,
#   'visit_id': 153,
#   'billed_amount': 6955.43,
#   'approved_amount': 6955.43,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-07-15'},
#  {'bill_id': 154,
#   'visit_id': 154,
#   'billed_amount': 976.1,
#   'approved_amount': 976.1,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-11-25'},
#  {'bill_id': 155,
#   'visit_id': 155,
#   'billed_amount': 24939.19,
#   'approved_amount': 16078.23,
#   'claim_status': 'Pending',
#   'payment_days': 10.0,
#   'billing_date': '2025-09-03'},
#  {'bill_id': 156,
#   'visit_id': 156,
#   'billed_amount': 38227.35,
#   'approved_amount': 38227.35,
#   'claim_status': 'Paid',
#   'payment_days': 24.0,
#   'billing_date': '2025-05-25'},
#  {'bill_id': 157,
#   'visit_id': 157,
#   'billed_amount': 14398.84,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-03-30'},
#  {'bill_id': 158,
#   'visit_id': 158,
#   'billed_amount': 9451.07,
#   'approved_amount': 9451.07,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-05-11'},
#  {'bill_id': 159,
#   'visit_id': 159,
#   'billed_amount': 66119.69,
#   'approved_amount': 66119.69,
#   'claim_status': 'Paid',
#   'payment_days': 25.0,
#   'billing_date': '2025-11-28'},
#  {'bill_id': 160,
#   'visit_id': 160,
#   'billed_amount': 43178.51,
#   'approved_amount': 43178.51,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-07'},
#  {'bill_id': 161,
#   'visit_id': 161,
#   'billed_amount': 58110.15,
#   'approved_amount': 58110.15,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-06-16'},
#  {'bill_id': 162,
#   'visit_id': 162,
#   'billed_amount': 2165.93,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-10-03'},
#  {'bill_id': 163,
#   'visit_id': 163,
#   'billed_amount': 8324.22,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 23.0,
#   'billing_date': '2025-08-19'},
#  {'bill_id': 164,
#   'visit_id': 164,
#   'billed_amount': 32844.03,
#   'approved_amount': 32844.03,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-08-25'},
#  {'bill_id': 165,
#   'visit_id': 165,
#   'billed_amount': 28971.87,
#   'approved_amount': 20026.0,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-12-13'},
#  {'bill_id': 166,
#   'visit_id': 166,
#   'billed_amount': 58947.88,
#   'approved_amount': 58947.88,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-07-10'},
#  {'bill_id': 167,
#   'visit_id': 167,
#   'billed_amount': 12137.24,
#   'approved_amount': 12137.24,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-08-24'},
#  {'bill_id': 168,
#   'visit_id': 168,
#   'billed_amount': 13504.87,
#   'approved_amount': 13504.87,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-08-07'},
#  {'bill_id': 169,
#   'visit_id': 169,
#   'billed_amount': 14861.73,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-05-01'},
#  {'bill_id': 170,
#   'visit_id': 170,
#   'billed_amount': 21622.04,
#   'approved_amount': 16165.05,
#   'claim_status': 'Pending',
#   'payment_days': 32.0,
#   'billing_date': '2026-01-02'},
#  {'bill_id': 171,
#   'visit_id': 171,
#   'billed_amount': 27657.61,
#   'approved_amount': 27657.61,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2026-01-08'},
#  {'bill_id': 172,
#   'visit_id': 172,
#   'billed_amount': 20347.08,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-02-28'},
#  {'bill_id': 173,
#   'visit_id': 173,
#   'billed_amount': 11493.55,
#   'approved_amount': 8735.77,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-03-24'},
#  {'bill_id': 174,
#   'visit_id': 174,
#   'billed_amount': 28988.16,
#   'approved_amount': 28988.16,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-08-25'},
#  {'bill_id': 175,
#   'visit_id': 175,
#   'billed_amount': 13794.8,
#   'approved_amount': 13794.8,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-06-10'},
#  {'bill_id': 176,
#   'visit_id': 176,
#   'billed_amount': 18015.97,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 20.0,
#   'billing_date': '2025-10-22'},
#  {'bill_id': 177,
#   'visit_id': 177,
#   'billed_amount': 16852.71,
#   'approved_amount': 16852.71,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-05-24'},
#  {'bill_id': 178,
#   'visit_id': 178,
#   'billed_amount': 27471.42,
#   'approved_amount': 27471.42,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-09'},
#  {'bill_id': 179,
#   'visit_id': 179,
#   'billed_amount': 1536.14,
#   'approved_amount': 1536.14,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-04-02'},
#  {'bill_id': 180,
#   'visit_id': 180,
#   'billed_amount': 12601.32,
#   'approved_amount': 12601.32,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-02-03'},
#  {'bill_id': 181,
#   'visit_id': 181,
#   'billed_amount': 49363.32,
#   'approved_amount': 49363.32,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-12-04'},
#  {'bill_id': 182,
#   'visit_id': 182,
#   'billed_amount': 22544.0,
#   'approved_amount': 22544.0,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-10-31'},
#  {'bill_id': 183,
#   'visit_id': 183,
#   'billed_amount': 37545.01,
#   'approved_amount': 37545.01,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2026-01-16'},
#  {'bill_id': 184,
#   'visit_id': 184,
#   'billed_amount': 17248.42,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-19'},
#  {'bill_id': 185,
#   'visit_id': 185,
#   'billed_amount': 24706.41,
#   'approved_amount': 15833.82,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-09-29'},
#  {'bill_id': 186,
#   'visit_id': 186,
#   'billed_amount': 16551.75,
#   'approved_amount': 16551.75,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-05-30'},
#  {'bill_id': 187,
#   'visit_id': 187,
#   'billed_amount': 20336.63,
#   'approved_amount': 20336.63,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-08-01'},
#  {'bill_id': 188,
#   'visit_id': 188,
#   'billed_amount': 12073.36,
#   'approved_amount': 12073.36,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-12-20'},
#  {'bill_id': 189,
#   'visit_id': 189,
#   'billed_amount': 21168.99,
#   'approved_amount': 21168.99,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-04-03'},
#  {'bill_id': 190,
#   'visit_id': 190,
#   'billed_amount': 11221.04,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-06-05'},
#  {'bill_id': 191,
#   'visit_id': 191,
#   'billed_amount': 14675.28,
#   'approved_amount': 14675.28,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-03-23'},
#  {'bill_id': 192,
#   'visit_id': 192,
#   'billed_amount': 31953.38,
#   'approved_amount': 23569.84,
#   'claim_status': 'Pending',
#   'payment_days': 3.0,
#   'billing_date': '2025-08-19'},
#  {'bill_id': 193,
#   'visit_id': 193,
#   'billed_amount': 7082.43,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 19.0,
#   'billing_date': '2025-07-02'},
#  {'bill_id': 194,
#   'visit_id': 194,
#   'billed_amount': 27894.89,
#   'approved_amount': 27894.89,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-10-24'},
#  {'bill_id': 195,
#   'visit_id': 195,
#   'billed_amount': 34506.51,
#   'approved_amount': 34506.51,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-04-11'},
#  {'bill_id': 196,
#   'visit_id': 196,
#   'billed_amount': 19115.39,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-06'},
#  {'bill_id': 197,
#   'visit_id': 197,
#   'billed_amount': 21374.02,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 16.0,
#   'billing_date': '2025-02-28'},
#  {'bill_id': 198,
#   'visit_id': 198,
#   'billed_amount': 17713.12,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 4.0,
#   'billing_date': '2025-07-30'},
#  {'bill_id': 199,
#   'visit_id': 199,
#   'billed_amount': 12249.79,
#   'approved_amount': 12249.79,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-06-13'},
#  {'bill_id': 200,
#   'visit_id': 200,
#   'billed_amount': 42105.81,
#   'approved_amount': 26668.83,
#   'claim_status': 'Pending',
#   'payment_days': 9.0,
#   'billing_date': '2025-06-03'},
#  {'bill_id': 201,
#   'visit_id': 201,
#   'billed_amount': 18303.11,
#   'approved_amount': 18303.11,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-05-20'},
#  {'bill_id': 202,
#   'visit_id': 202,
#   'billed_amount': 20722.01,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 8.0,
#   'billing_date': '2025-06-04'},
#  {'bill_id': 203,
#   'visit_id': 203,
#   'billed_amount': 2584.28,
#   'approved_amount': 2584.28,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-15'},
#  {'bill_id': 204,
#   'visit_id': 204,
#   'billed_amount': 19339.22,
#   'approved_amount': 19339.22,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-07-24'},
#  {'bill_id': 205,
#   'visit_id': 205,
#   'billed_amount': 9695.84,
#   'approved_amount': 9695.84,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-09-06'},
#  {'bill_id': 206,
#   'visit_id': 206,
#   'billed_amount': 32305.31,
#   'approved_amount': 27667.78,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-07-27'},
#  {'bill_id': 207,
#   'visit_id': 207,
#   'billed_amount': 18607.26,
#   'approved_amount': 11646.71,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-10-08'},
#  {'bill_id': 208,
#   'visit_id': 208,
#   'billed_amount': 40924.89,
#   'approved_amount': 40924.89,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-04-30'},
#  {'bill_id': 209,
#   'visit_id': 209,
#   'billed_amount': 29922.11,
#   'approved_amount': 29922.11,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-12-18'},
#  {'bill_id': 210,
#   'visit_id': 210,
#   'billed_amount': 6899.44,
#   'approved_amount': 6899.44,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-09-01'},
#  {'bill_id': 211,
#   'visit_id': 211,
#   'billed_amount': 33135.09,
#   'approved_amount': 33135.09,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-06-19'},
#  {'bill_id': 212,
#   'visit_id': 212,
#   'billed_amount': 17216.8,
#   'approved_amount': 17216.8,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-11-07'},
#  {'bill_id': 213,
#   'visit_id': 213,
#   'billed_amount': 32012.61,
#   'approved_amount': 32012.61,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-11-05'},
#  {'bill_id': 214,
#   'visit_id': 214,
#   'billed_amount': 23407.85,
#   'approved_amount': 23407.85,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 215,
#   'visit_id': 215,
#   'billed_amount': 10942.6,
#   'approved_amount': 10942.6,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-04-30'},
#  {'bill_id': 216,
#   'visit_id': 216,
#   'billed_amount': 25924.18,
#   'approved_amount': 25924.18,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2026-01-06'},
#  {'bill_id': 217,
#   'visit_id': 217,
#   'billed_amount': 42936.35,
#   'approved_amount': 42936.35,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-12-19'},
#  {'bill_id': 218,
#   'visit_id': 218,
#   'billed_amount': 8716.52,
#   'approved_amount': 8716.52,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2026-01-17'},
#  {'bill_id': 219,
#   'visit_id': 219,
#   'billed_amount': 31519.15,
#   'approved_amount': 31519.15,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-03-24'},
#  {'bill_id': 220,
#   'visit_id': 220,
#   'billed_amount': 27563.09,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-08-31'},
#  {'bill_id': 221,
#   'visit_id': 221,
#   'billed_amount': 22633.88,
#   'approved_amount': 22633.88,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-12-12'},
#  {'bill_id': 222,
#   'visit_id': 222,
#   'billed_amount': 38939.17,
#   'approved_amount': 38939.17,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-09-14'},
#  {'bill_id': 223,
#   'visit_id': 223,
#   'billed_amount': 12065.42,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-07-12'},
#  {'bill_id': 224,
#   'visit_id': 224,
#   'billed_amount': 27045.44,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-10-22'},
#  {'bill_id': 225,
#   'visit_id': 225,
#   'billed_amount': 12049.28,
#   'approved_amount': 8822.17,
#   'claim_status': 'Pending',
#   'payment_days': 34.0,
#   'billing_date': '2025-10-07'},
#  {'bill_id': 226,
#   'visit_id': 226,
#   'billed_amount': 12356.86,
#   'approved_amount': 7943.28,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-04-28'},
#  {'bill_id': 227,
#   'visit_id': 227,
#   'billed_amount': 34309.03,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-04-21'},
#  {'bill_id': 228,
#   'visit_id': 228,
#   'billed_amount': 35388.47,
#   'approved_amount': 35388.47,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-10-10'},
#  {'bill_id': 229,
#   'visit_id': 229,
#   'billed_amount': 4922.64,
#   'approved_amount': 2575.2,
#   'claim_status': 'Pending',
#   'payment_days': 5.0,
#   'billing_date': '2026-01-11'},
#  {'bill_id': 230,
#   'visit_id': 230,
#   'billed_amount': 28737.3,
#   'approved_amount': 18041.81,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-02-09'},
#  {'bill_id': 231,
#   'visit_id': 231,
#   'billed_amount': 3341.2,
#   'approved_amount': 3341.2,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-01-25'},
#  {'bill_id': 232,
#   'visit_id': 232,
#   'billed_amount': 29963.79,
#   'approved_amount': 29963.79,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-10-16'},
#  {'bill_id': 233,
#   'visit_id': 233,
#   'billed_amount': 12196.71,
#   'approved_amount': 12196.71,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-09-07'},
#  {'bill_id': 234,
#   'visit_id': 234,
#   'billed_amount': 25193.29,
#   'approved_amount': 25193.29,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-09-02'},
#  {'bill_id': 235,
#   'visit_id': 235,
#   'billed_amount': 14605.11,
#   'approved_amount': 14605.11,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-06-17'},
#  {'bill_id': 236,
#   'visit_id': 236,
#   'billed_amount': 9525.67,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-09-27'},
#  {'bill_id': 237,
#   'visit_id': 237,
#   'billed_amount': 66037.73,
#   'approved_amount': 66037.73,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-01-24'},
#  {'bill_id': 238,
#   'visit_id': 238,
#   'billed_amount': 7910.76,
#   'approved_amount': 7910.76,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-06-24'},
#  {'bill_id': 239,
#   'visit_id': 239,
#   'billed_amount': 18483.63,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-03-18'},
#  {'bill_id': 240,
#   'visit_id': 240,
#   'billed_amount': 37659.07,
#   'approved_amount': 37659.07,
#   'claim_status': 'Paid',
#   'payment_days': 28.0,
#   'billing_date': '2025-06-07'},
#  {'bill_id': 241,
#   'visit_id': 241,
#   'billed_amount': 32669.24,
#   'approved_amount': 32669.24,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2025-11-18'},
#  {'bill_id': 242,
#   'visit_id': 242,
#   'billed_amount': 20280.35,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 15.0,
#   'billing_date': '2025-05-26'},
#  {'bill_id': 243,
#   'visit_id': 243,
#   'billed_amount': 1735.65,
#   'approved_amount': 1735.65,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-11-09'},
#  {'bill_id': 244,
#   'visit_id': 244,
#   'billed_amount': 500.0,
#   'approved_amount': 500.0,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-04-16'},
#  {'bill_id': 245,
#   'visit_id': 245,
#   'billed_amount': 33216.43,
#   'approved_amount': 33216.43,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-07-11'},
#  {'bill_id': 246,
#   'visit_id': 246,
#   'billed_amount': 5990.73,
#   'approved_amount': 5990.73,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-10-06'},
#  {'bill_id': 247,
#   'visit_id': 247,
#   'billed_amount': 2105.98,
#   'approved_amount': 1491.33,
#   'claim_status': 'Pending',
#   'payment_days': 22.0,
#   'billing_date': '2025-08-26'},
#  {'bill_id': 248,
#   'visit_id': 248,
#   'billed_amount': 30763.51,
#   'approved_amount': 17355.34,
#   'claim_status': 'Pending',
#   'payment_days': 24.0,
#   'billing_date': '2025-06-28'},
#  {'bill_id': 249,
#   'visit_id': 249,
#   'billed_amount': 19722.71,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-08-30'},
#  {'bill_id': 250,
#   'visit_id': 250,
#   'billed_amount': 9939.08,
#   'approved_amount': 9939.08,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-06-10'},
#  {'bill_id': 251,
#   'visit_id': 251,
#   'billed_amount': 26063.37,
#   'approved_amount': 20822.63,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-02-08'},
#  {'bill_id': 252,
#   'visit_id': 252,
#   'billed_amount': 20712.47,
#   'approved_amount': 17753.55,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-15'},
#  {'bill_id': 253,
#   'visit_id': 253,
#   'billed_amount': 19241.46,
#   'approved_amount': 19241.46,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2026-01-05'},
#  {'bill_id': 254,
#   'visit_id': 254,
#   'billed_amount': 43187.74,
#   'approved_amount': 43187.74,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-02'},
#  {'bill_id': 255,
#   'visit_id': 255,
#   'billed_amount': 14687.67,
#   'approved_amount': 8399.65,
#   'claim_status': 'Pending',
#   'payment_days': 21.0,
#   'billing_date': '2025-02-07'},
#  {'bill_id': 256,
#   'visit_id': 256,
#   'billed_amount': 3651.98,
#   'approved_amount': 3651.98,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-03-09'},
#  {'bill_id': 257,
#   'visit_id': 257,
#   'billed_amount': 20013.84,
#   'approved_amount': 20013.84,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-07-23'},
#  {'bill_id': 258,
#   'visit_id': 258,
#   'billed_amount': 20878.83,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-02-28'},
#  {'bill_id': 259,
#   'visit_id': 259,
#   'billed_amount': 27178.54,
#   'approved_amount': 27178.54,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-02-21'},
#  {'bill_id': 260,
#   'visit_id': 260,
#   'billed_amount': 30861.99,
#   'approved_amount': 30861.99,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-10-02'},
#  {'bill_id': 261,
#   'visit_id': 261,
#   'billed_amount': 2496.78,
#   'approved_amount': 1442.49,
#   'claim_status': 'Pending',
#   'payment_days': 6.0,
#   'billing_date': '2025-12-26'},
#  {'bill_id': 262,
#   'visit_id': 262,
#   'billed_amount': 13003.21,
#   'approved_amount': 13003.21,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-04-26'},
#  {'bill_id': 263,
#   'visit_id': 263,
#   'billed_amount': 10775.94,
#   'approved_amount': 6159.58,
#   'claim_status': 'Pending',
#   'payment_days': 28.0,
#   'billing_date': '2025-09-26'},
#  {'bill_id': 264,
#   'visit_id': 264,
#   'billed_amount': 4198.05,
#   'approved_amount': 4198.05,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-11-17'},
#  {'bill_id': 265,
#   'visit_id': 265,
#   'billed_amount': 34196.78,
#   'approved_amount': 22835.28,
#   'claim_status': 'Pending',
#   'payment_days': 17.0,
#   'billing_date': '2025-11-22'},
#  {'bill_id': 266,
#   'visit_id': 266,
#   'billed_amount': 23652.4,
#   'approved_amount': 23652.4,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-11-16'},
#  {'bill_id': 267,
#   'visit_id': 267,
#   'billed_amount': 24974.95,
#   'approved_amount': 24974.95,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-12-01'},
#  {'bill_id': 268,
#   'visit_id': 268,
#   'billed_amount': 26693.97,
#   'approved_amount': 19018.5,
#   'claim_status': 'Pending',
#   'payment_days': 19.0,
#   'billing_date': '2025-02-11'},
#  {'bill_id': 269,
#   'visit_id': 269,
#   'billed_amount': 11471.92,
#   'approved_amount': 9590.15,
#   'claim_status': 'Pending',
#   'payment_days': 13.0,
# ...
#  {'bill_id': 912,
#   'visit_id': 912,
#   'billed_amount': 30785.51,
#   'approved_amount': 30785.51,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-10-19'},
#  {'bill_id': 913,
#   'visit_id': 913,
#   'billed_amount': 17413.46,
#   'approved_amount': 17413.46,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-08-17'},
#  {'bill_id': 914,
#   'visit_id': 914,
#   'billed_amount': 27606.71,
#   'approved_amount': 27606.71,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-09'},
#  {'bill_id': 915,
#   'visit_id': 915,
#   'billed_amount': 13168.74,
#   'approved_amount': 6603.24,
#   'claim_status': 'Pending',
#   'payment_days': 9.0,
#   'billing_date': '2025-12-01'},
#  {'bill_id': 916,
#   'visit_id': 916,
#   'billed_amount': 36033.75,
#   'approved_amount': 24195.96,
#   'claim_status': 'Pending',
#   'payment_days': 3.0,
#   'billing_date': '2026-01-15'},
#  {'bill_id': 917,
#   'visit_id': 917,
#   'billed_amount': 18751.41,
#   'approved_amount': 18751.41,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-09-30'},
#  {'bill_id': 918,
#   'visit_id': 918,
#   'billed_amount': 2188.83,
#   'approved_amount': 2188.83,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-09-21'},
#  {'bill_id': 919,
#   'visit_id': 919,
#   'billed_amount': 20834.47,
#   'approved_amount': 20834.47,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-12-16'},
#  {'bill_id': 920,
#   'visit_id': 920,
#   'billed_amount': 54848.35,
#   'approved_amount': 54848.35,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-04-11'},
#  {'bill_id': 921,
#   'visit_id': 921,
#   'billed_amount': 14860.64,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 9.0,
#   'billing_date': '2025-03-04'},
#  {'bill_id': 922,
#   'visit_id': 922,
#   'billed_amount': 31035.44,
#   'approved_amount': 31035.44,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-05-21'},
#  {'bill_id': 923,
#   'visit_id': 923,
#   'billed_amount': 38745.55,
#   'approved_amount': 38745.55,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-09-02'},
#  {'bill_id': 924,
#   'visit_id': 924,
#   'billed_amount': 19695.38,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': 17.0,
#   'billing_date': '2025-07-30'},
#  {'bill_id': 925,
#   'visit_id': 925,
#   'billed_amount': 14279.58,
#   'approved_amount': 10726.11,
#   'claim_status': 'Pending',
#   'payment_days': 21.0,
#   'billing_date': '2025-05-18'},
#  {'bill_id': 926,
#   'visit_id': 926,
#   'billed_amount': 17612.2,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-07-27'},
#  {'bill_id': 927,
#   'visit_id': 927,
#   'billed_amount': 17473.84,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2025-06-20'},
#  {'bill_id': 928,
#   'visit_id': 928,
#   'billed_amount': 29373.0,
#   'approved_amount': 29373.0,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-08-08'},
#  {'bill_id': 929,
#   'visit_id': 929,
#   'billed_amount': 500.0,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-01-27'},
#  {'bill_id': 930,
#   'visit_id': 930,
#   'billed_amount': 14185.89,
#   'approved_amount': 14185.89,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-03-04'},
#  {'bill_id': 931,
#   'visit_id': 931,
#   'billed_amount': 30618.37,
#   'approved_amount': 15802.37,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-11-11'},
#  {'bill_id': 932,
#   'visit_id': 932,
#   'billed_amount': 23384.53,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 18.0,
#   'billing_date': '2025-11-09'},
#  {'bill_id': 933,
#   'visit_id': 933,
#   'billed_amount': 19677.56,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 24.0,
#   'billing_date': '2025-01-31'},
#  {'bill_id': 934,
#   'visit_id': 934,
#   'billed_amount': 21812.51,
#   'approved_amount': 21812.51,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-03-19'},
#  {'bill_id': 935,
#   'visit_id': 935,
#   'billed_amount': 24255.94,
#   'approved_amount': 24255.94,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-05-27'},
#  {'bill_id': 936,
#   'visit_id': 936,
#   'billed_amount': 7846.57,
#   'approved_amount': 7846.57,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-02-14'},
#  {'bill_id': 937,
#   'visit_id': 937,
#   'billed_amount': 16599.66,
#   'approved_amount': 13276.72,
#   'claim_status': 'Pending',
#   'payment_days': 12.0,
#   'billing_date': '2025-12-03'},
#  {'bill_id': 938,
#   'visit_id': 938,
#   'billed_amount': 5093.4,
#   'approved_amount': 5093.4,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-03'},
#  {'bill_id': 939,
#   'visit_id': 939,
#   'billed_amount': 10037.93,
#   'approved_amount': 10037.93,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-10-05'},
#  {'bill_id': 940,
#   'visit_id': 940,
#   'billed_amount': 16799.79,
#   'approved_amount': 16799.79,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-12-12'},
#  {'bill_id': 941,
#   'visit_id': 941,
#   'billed_amount': 12670.81,
#   'approved_amount': 10946.04,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-03-06'},
#  {'bill_id': 942,
#   'visit_id': 942,
#   'billed_amount': 18530.61,
#   'approved_amount': 14614.47,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-10-04'},
#  {'bill_id': 943,
#   'visit_id': 943,
#   'billed_amount': 3439.47,
#   'approved_amount': 2427.29,
#   'claim_status': 'Pending',
#   'payment_days': 23.0,
#   'billing_date': '2025-06-09'},
#  {'bill_id': 944,
#   'visit_id': 944,
#   'billed_amount': 31700.24,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 20.0,
#   'billing_date': '2025-04-15'},
#  {'bill_id': 945,
#   'visit_id': 945,
#   'billed_amount': 36402.4,
#   'approved_amount': nan,
#   'claim_status': 'Rejected',
#   'payment_days': 13.0,
#   'billing_date': '2025-06-29'},
#  {'bill_id': 946,
#   'visit_id': 946,
#   'billed_amount': 21542.17,
#   'approved_amount': 21542.17,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-02-28'},
#  {'bill_id': 947,
#   'visit_id': 947,
#   'billed_amount': 32694.37,
#   'approved_amount': 32694.37,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-03-30'},
#  {'bill_id': 948,
#   'visit_id': 948,
#   'billed_amount': 24006.27,
#   'approved_amount': 24006.27,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-03-13'},
#  {'bill_id': 949,
#   'visit_id': 949,
#   'billed_amount': 34565.86,
#   'approved_amount': 20289.85,
#   'claim_status': 'Pending',
#   'payment_days': 25.0,
#   'billing_date': '2025-06-12'},
#  {'bill_id': 950,
#   'visit_id': 950,
#   'billed_amount': 14355.83,
#   'approved_amount': 14355.83,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-07-29'},
#  {'bill_id': 951,
#   'visit_id': 951,
#   'billed_amount': 15812.9,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 16.0,
#   'billing_date': '2025-11-10'},
#  {'bill_id': 952,
#   'visit_id': 952,
#   'billed_amount': 18835.54,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-07-01'},
#  {'bill_id': 953,
#   'visit_id': 953,
#   'billed_amount': 42453.2,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-12-15'},
#  {'bill_id': 954,
#   'visit_id': 954,
#   'billed_amount': 18004.79,
#   'approved_amount': 13637.42,
#   'claim_status': 'Pending',
#   'payment_days': 13.0,
#   'billing_date': '2025-09-12'},
#  {'bill_id': 955,
#   'visit_id': 955,
#   'billed_amount': 15096.81,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 6.0,
#   'billing_date': '2025-10-10'},
#  {'bill_id': 956,
#   'visit_id': 956,
#   'billed_amount': 3406.02,
#   'approved_amount': 3406.02,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-06-19'},
#  {'bill_id': 957,
#   'visit_id': 957,
#   'billed_amount': 13933.85,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-26'},
#  {'bill_id': 958,
#   'visit_id': 958,
#   'billed_amount': 32345.71,
#   'approved_amount': 32345.71,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-12-28'},
#  {'bill_id': 959,
#   'visit_id': 959,
#   'billed_amount': 7880.24,
#   'approved_amount': 7880.24,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-10-06'},
#  {'bill_id': 960,
#   'visit_id': 960,
#   'billed_amount': 16944.77,
#   'approved_amount': 14526.09,
#   'claim_status': 'Pending',
#   'payment_days': 12.0,
#   'billing_date': '2025-06-06'},
#  {'bill_id': 961,
#   'visit_id': 961,
#   'billed_amount': 24284.67,
#   'approved_amount': 24284.67,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-17'},
#  {'bill_id': 962,
#   'visit_id': 962,
#   'billed_amount': 42477.35,
#   'approved_amount': 42477.35,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2026-01-10'},
#  {'bill_id': 963,
#   'visit_id': 963,
#   'billed_amount': 32218.38,
#   'approved_amount': 32218.38,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-09-22'},
#  {'bill_id': 964,
#   'visit_id': 964,
#   'billed_amount': 13091.97,
#   'approved_amount': 9587.37,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-11-15'},
#  {'bill_id': 965,
#   'visit_id': 965,
#   'billed_amount': 33404.36,
#   'approved_amount': 22019.74,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-16'},
#  {'bill_id': 966,
#   'visit_id': 966,
#   'billed_amount': 20137.89,
#   'approved_amount': 20137.89,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-25'},
#  {'bill_id': 967,
#   'visit_id': 967,
#   'billed_amount': 19371.04,
#   'approved_amount': 13930.08,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-05-20'},
#  {'bill_id': 968,
#   'visit_id': 968,
#   'billed_amount': 13538.33,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-04-07'},
#  {'bill_id': 969,
#   'visit_id': 969,
#   'billed_amount': 11256.01,
#   'approved_amount': 8555.12,
#   'claim_status': 'Pending',
#   'payment_days': 11.0,
#   'billing_date': '2025-09-23'},
#  {'bill_id': 970,
#   'visit_id': 970,
#   'billed_amount': 34594.39,
#   'approved_amount': 17423.74,
#   'claim_status': 'Pending',
#   'payment_days': 9.0,
#   'billing_date': '2025-03-27'},
#  {'bill_id': 971,
#   'visit_id': 971,
#   'billed_amount': 38213.56,
#   'approved_amount': 38213.56,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-12-09'},
#  {'bill_id': 972,
#   'visit_id': 972,
#   'billed_amount': 5001.82,
#   'approved_amount': 5001.82,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-03-05'},
#  {'bill_id': 973,
#   'visit_id': 973,
#   'billed_amount': 1893.15,
#   'approved_amount': 1893.15,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-05-06'},
#  {'bill_id': 974,
#   'visit_id': 974,
#   'billed_amount': 25947.37,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 20.0,
#   'billing_date': '2025-05-24'},
#  {'bill_id': 975,
#   'visit_id': 975,
#   'billed_amount': 24702.09,
#   'approved_amount': 24702.09,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-03-06'},
#  {'bill_id': 976,
#   'visit_id': 976,
#   'billed_amount': 25129.56,
#   'approved_amount': 25129.56,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-03-07'},
#  {'bill_id': 977,
#   'visit_id': 977,
#   'billed_amount': 23755.91,
#   'approved_amount': 13848.51,
#   'claim_status': 'Pending',
#   'payment_days': 24.0,
#   'billing_date': '2025-02-15'},
#  {'bill_id': 978,
#   'visit_id': 978,
#   'billed_amount': 15569.27,
#   'approved_amount': 10153.37,
#   'claim_status': 'Pending',
#   'payment_days': 35.0,
#   'billing_date': '2025-09-17'},
#  {'bill_id': 979,
#   'visit_id': 979,
#   'billed_amount': 35646.83,
#   'approved_amount': 35646.83,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-01-30'},
#  {'bill_id': 980,
#   'visit_id': 980,
#   'billed_amount': 36082.1,
#   'approved_amount': 36082.1,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-01-22'},
#  {'bill_id': 981,
#   'visit_id': 981,
#   'billed_amount': 12818.5,
#   'approved_amount': 12818.5,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-04-30'},
#  {'bill_id': 982,
#   'visit_id': 982,
#   'billed_amount': 13501.29,
#   'approved_amount': 13501.29,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-09-04'},
#  {'bill_id': 983,
#   'visit_id': 983,
#   'billed_amount': 29980.74,
#   'approved_amount': 29980.74,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2026-01-03'},
#  {'bill_id': 984,
#   'visit_id': 984,
#   'billed_amount': 10910.21,
#   'approved_amount': 9138.63,
#   'claim_status': 'Pending',
#   'payment_days': 33.0,
#   'billing_date': '2025-05-26'},
#  {'bill_id': 985,
#   'visit_id': 985,
#   'billed_amount': 20598.03,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 5.0,
#   'billing_date': '2025-11-10'},
#  {'bill_id': 986,
#   'visit_id': 986,
#   'billed_amount': 33286.44,
#   'approved_amount': 33286.44,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-10'},
#  {'bill_id': 987,
#   'visit_id': 987,
#   'billed_amount': 43184.61,
#   'approved_amount': 32991.7,
#   'claim_status': 'Pending',
#   'payment_days': 11.0,
#   'billing_date': '2025-04-16'},
#  {'bill_id': 988,
#   'visit_id': 988,
#   'billed_amount': 11840.95,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-02-17'},
#  {'bill_id': 989,
#   'visit_id': 989,
#   'billed_amount': 37649.98,
#   'approved_amount': 32247.66,
#   'claim_status': 'Pending',
#   'payment_days': 22.0,
#   'billing_date': '2025-05-25'},
#  {'bill_id': 990,
#   'visit_id': 990,
#   'billed_amount': 16094.75,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-10-07'},
#  {'bill_id': 991,
#   'visit_id': 991,
#   'billed_amount': 8256.11,
#   'approved_amount': 8256.11,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-09-22'},
#  {'bill_id': 992,
#   'visit_id': 992,
#   'billed_amount': 51892.48,
#   'approved_amount': 45058.99,
#   'claim_status': 'Pending',
#   'payment_days': 6.0,
#   'billing_date': '2025-10-23'},
#  {'bill_id': 993,
#   'visit_id': 993,
#   'billed_amount': 45604.44,
#   'approved_amount': 45604.44,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-02-14'},
#  {'bill_id': 994,
#   'visit_id': 994,
#   'billed_amount': 54538.65,
#   'approved_amount': 54538.65,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-11-14'},
#  {'bill_id': 995,
#   'visit_id': 995,
#   'billed_amount': 43192.45,
#   'approved_amount': 43192.45,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-03-05'},
#  {'bill_id': 996,
#   'visit_id': 996,
#   'billed_amount': 22594.1,
#   'approved_amount': 19779.22,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-12-19'},
#  {'bill_id': 997,
#   'visit_id': 997,
#   'billed_amount': 24548.7,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': nan,
#   'billing_date': '2026-01-11'},
#  {'bill_id': 998,
#   'visit_id': 998,
#   'billed_amount': 29932.9,
#   'approved_amount': 19380.0,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-03-23'},
#  {'bill_id': 999,
#   'visit_id': 999,
#   'billed_amount': 7898.22,
#   'approved_amount': 7898.22,
#   'claim_status': 'Paid',
#   'payment_days': 27.0,
#   'billing_date': '2026-01-04'},
#  {'bill_id': 1000,
#   'visit_id': 1000,
#   'billed_amount': 49350.69,
#   'approved_amount': 49350.69,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-08-22'},
#  ...]

# %%
len(billing_data)
# Out:
# 25000

# %%
visits_data= visits.to_dict(orient="records")
visits_data
# Out:
# [{'visit_id': 1,
#   'patient_id': 756,
#   'visit_date': '2025-10-18',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 3.48,
#   'risk_score': 'Low',
#   'doctor_id': 169},
#  {'visit_id': 2,
#   'patient_id': 4102,
#   'visit_date': '2025-04-06',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.31,
#   'risk_score': 'High',
#   'doctor_id': 148},
#  {'visit_id': 3,
#   'patient_id': 2964,
#   'visit_date': '2025-07-13',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 34.36,
#   'risk_score': 'Low',
#   'doctor_id': 153},
#  {'visit_id': 4,
#   'patient_id': 4496,
#   'visit_date': '2025-11-19',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 37.89,
#   'risk_score': 'High',
#   'doctor_id': 119},
#  {'visit_id': 5,
#   'patient_id': 1930,
#   'visit_date': '2025-03-29',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.78,
#   'risk_score': 'Medium',
#   'doctor_id': 118},
#  {'visit_id': 6,
#   'patient_id': 1803,
#   'visit_date': '2025-12-20',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.7,
#   'risk_score': 'High',
#   'doctor_id': 157},
#  {'visit_id': 7,
#   'patient_id': 4118,
#   'visit_date': '2025-11-12',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.4,
#   'risk_score': 'Low',
#   'doctor_id': 121},
#  {'visit_id': 8,
#   'patient_id': 1868,
#   'visit_date': '2025-09-18',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 26.86,
#   'risk_score': 'High',
#   'doctor_id': 107},
#  {'visit_id': 9,
#   'patient_id': 295,
#   'visit_date': '2026-01-17',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.31,
#   'risk_score': 'Medium',
#   'doctor_id': 134},
#  {'visit_id': 10,
#   'patient_id': 4442,
#   'visit_date': '2025-12-07',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.22,
#   'risk_score': 'Low',
#   'doctor_id': 107},
#  {'visit_id': 11,
#   'patient_id': 4524,
#   'visit_date': '2025-06-12',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.21,
#   'risk_score': 'Medium',
#   'doctor_id': 174},
#  {'visit_id': 12,
#   'patient_id': 2646,
#   'visit_date': '2026-01-15',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.65,
#   'risk_score': 'Low',
#   'doctor_id': 180},
#  {'visit_id': 13,
#   'patient_id': 3647,
#   'visit_date': '2025-08-23',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 37.74,
#   'risk_score': 'Medium',
#   'doctor_id': 140},
#  {'visit_id': 14,
#   'patient_id': 1660,
#   'visit_date': '2025-11-19',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.13,
#   'risk_score': 'Low',
#   'doctor_id': 169},
#  {'visit_id': 15,
#   'patient_id': 4431,
#   'visit_date': '2025-12-05',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.39,
#   'risk_score': 'Low',
#   'doctor_id': 157},
#  {'visit_id': 16,
#   'patient_id': 1722,
#   'visit_date': '2025-09-13',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.92,
#   'risk_score': 'Medium',
#   'doctor_id': 145},
#  {'visit_id': 17,
#   'patient_id': 4778,
#   'visit_date': '2025-02-22',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.2,
#   'risk_score': 'Low',
#   'doctor_id': 177},
#  {'visit_id': 18,
#   'patient_id': 476,
#   'visit_date': '2025-11-01',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.8,
#   'risk_score': 'Low',
#   'doctor_id': 147},
#  {'visit_id': 19,
#   'patient_id': 4178,
#   'visit_date': '2025-11-27',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 29.28,
#   'risk_score': 'Medium',
#   'doctor_id': 149},
#  {'visit_id': 20,
#   'patient_id': 1374,
#   'visit_date': '2025-08-15',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.38,
#   'risk_score': 'Low',
#   'doctor_id': 164},
#  {'visit_id': 21,
#   'patient_id': 2160,
#   'visit_date': '2025-10-28',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.34,
#   'risk_score': 'High',
#   'doctor_id': 152},
#  {'visit_id': 22,
#   'patient_id': 1683,
#   'visit_date': '2025-10-15',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.27,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 23,
#   'patient_id': 3924,
#   'visit_date': '2025-08-12',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 4.94,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 24,
#   'patient_id': 4864,
#   'visit_date': '2025-08-12',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.15,
#   'risk_score': 'Low',
#   'doctor_id': 123},
#  {'visit_id': 25,
#   'patient_id': 939,
#   'visit_date': '2025-12-09',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 33.74,
#   'risk_score': 'Medium',
#   'doctor_id': 103},
#  {'visit_id': 26,
#   'patient_id': 2734,
#   'visit_date': '2025-03-06',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 30.39,
#   'risk_score': 'Medium',
#   'doctor_id': 112},
#  {'visit_id': 27,
#   'patient_id': 1268,
#   'visit_date': '2025-11-06',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 20.45,
#   'risk_score': 'Low',
#   'doctor_id': 166},
#  {'visit_id': 28,
#   'patient_id': 3171,
#   'visit_date': '2025-12-21',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.13,
#   'risk_score': 'Low',
#   'doctor_id': 198},
#  {'visit_id': 29,
#   'patient_id': 1097,
#   'visit_date': '2025-02-02',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.53,
#   'risk_score': 'Medium',
#   'doctor_id': 100},
#  {'visit_id': 30,
#   'patient_id': 3292,
#   'visit_date': '2025-08-06',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 6.6,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 31,
#   'patient_id': 971,
#   'visit_date': '2025-02-13',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 7.89,
#   'risk_score': 'Low',
#   'doctor_id': 116},
#  {'visit_id': 32,
#   'patient_id': 1798,
#   'visit_date': '2025-09-23',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.62,
#   'risk_score': 'Medium',
#   'doctor_id': 171},
#  {'visit_id': 33,
#   'patient_id': 1180,
#   'visit_date': '2025-08-06',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.16,
#   'risk_score': 'Low',
#   'doctor_id': 129},
#  {'visit_id': 34,
#   'patient_id': 1835,
#   'visit_date': '2025-06-09',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.34,
#   'risk_score': 'Medium',
#   'doctor_id': 184},
#  {'visit_id': 35,
#   'patient_id': 3578,
#   'visit_date': '2025-12-24',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.61,
#   'risk_score': 'Low',
#   'doctor_id': 158},
#  {'visit_id': 36,
#   'patient_id': 379,
#   'visit_date': '2025-05-24',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.1,
#   'risk_score': 'Low',
#   'doctor_id': 105},
#  {'visit_id': 37,
#   'patient_id': 3447,
#   'visit_date': '2025-09-28',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.31,
#   'risk_score': 'Low',
#   'doctor_id': 165},
#  {'visit_id': 38,
#   'patient_id': 3390,
#   'visit_date': '2025-10-12',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 24.92,
#   'risk_score': 'Low',
#   'doctor_id': 124},
#  {'visit_id': 39,
#   'patient_id': 2772,
#   'visit_date': '2025-07-20',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.82,
#   'risk_score': 'Low',
#   'doctor_id': 101},
#  {'visit_id': 40,
#   'patient_id': 3989,
#   'visit_date': '2025-09-03',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 0.92,
#   'risk_score': 'Low',
#   'doctor_id': 112},
#  {'visit_id': 41,
#   'patient_id': 1400,
#   'visit_date': '2025-12-22',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.26,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 42,
#   'patient_id': 2698,
#   'visit_date': '2025-07-13',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.23,
#   'risk_score': 'Medium',
#   'doctor_id': 187},
#  {'visit_id': 43,
#   'patient_id': 2608,
#   'visit_date': '2025-09-02',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.29,
#   'risk_score': 'Low',
#   'doctor_id': 145},
#  {'visit_id': 44,
#   'patient_id': 1041,
#   'visit_date': '2025-12-15',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 18.97,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 45,
#   'patient_id': 4944,
#   'visit_date': '2025-12-31',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.69,
#   'risk_score': 'Medium',
#   'doctor_id': 166},
#  {'visit_id': 46,
#   'patient_id': 2244,
#   'visit_date': '2026-01-18',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.06,
#   'risk_score': 'Low',
#   'doctor_id': 105},
#  {'visit_id': 47,
#   'patient_id': 2550,
#   'visit_date': '2025-07-27',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.65,
#   'risk_score': 'Low',
#   'doctor_id': 126},
#  {'visit_id': 48,
#   'patient_id': 858,
#   'visit_date': '2025-02-28',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.46,
#   'risk_score': 'Low',
#   'doctor_id': 139},
#  {'visit_id': 49,
#   'patient_id': 3960,
#   'visit_date': '2025-02-15',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 34.51,
#   'risk_score': 'High',
#   'doctor_id': 113},
#  {'visit_id': 50,
#   'patient_id': 1249,
#   'visit_date': '2025-05-16',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.98,
#   'risk_score': 'Medium',
#   'doctor_id': 106},
#  {'visit_id': 51,
#   'patient_id': 1626,
#   'visit_date': '2025-08-13',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.25,
#   'risk_score': 'Low',
#   'doctor_id': 114},
#  {'visit_id': 52,
#   'patient_id': 2657,
#   'visit_date': '2025-12-07',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 2.68,
#   'risk_score': 'Low',
#   'doctor_id': 177},
#  {'visit_id': 53,
#   'patient_id': 612,
#   'visit_date': '2025-02-08',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.48,
#   'risk_score': 'High',
#   'doctor_id': 156},
#  {'visit_id': 54,
#   'patient_id': 3690,
#   'visit_date': '2025-12-02',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 20.89,
#   'risk_score': 'Low',
#   'doctor_id': 106},
#  {'visit_id': 55,
#   'patient_id': 1165,
#   'visit_date': '2025-05-18',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.84,
#   'risk_score': 'Low',
#   'doctor_id': 199},
#  {'visit_id': 56,
#   'patient_id': 2188,
#   'visit_date': '2025-07-21',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 29.9,
#   'risk_score': 'High',
#   'doctor_id': 137},
#  {'visit_id': 57,
#   'patient_id': 2158,
#   'visit_date': '2025-08-18',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 31.1,
#   'risk_score': 'Low',
#   'doctor_id': 137},
#  {'visit_id': 58,
#   'patient_id': 203,
#   'visit_date': '2025-05-18',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.62,
#   'risk_score': 'High',
#   'doctor_id': 154},
#  {'visit_id': 59,
#   'patient_id': 2443,
#   'visit_date': '2025-01-31',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 3.05,
#   'risk_score': 'High',
#   'doctor_id': 127},
#  {'visit_id': 60,
#   'patient_id': 1104,
#   'visit_date': '2025-11-29',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.86,
#   'risk_score': 'Low',
#   'doctor_id': 127},
#  {'visit_id': 61,
#   'patient_id': 4085,
#   'visit_date': '2025-10-06',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.99,
#   'risk_score': 'Low',
#   'doctor_id': 115},
#  {'visit_id': 62,
#   'patient_id': 2909,
#   'visit_date': '2025-11-14',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.63,
#   'risk_score': 'Medium',
#   'doctor_id': 157},
#  {'visit_id': 63,
#   'patient_id': 1313,
#   'visit_date': '2025-11-23',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 59.25,
#   'risk_score': 'High',
#   'doctor_id': 118},
#  {'visit_id': 64,
#   'patient_id': 3598,
#   'visit_date': '2025-05-19',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.35,
#   'risk_score': 'High',
#   'doctor_id': 150},
#  {'visit_id': 65,
#   'patient_id': 4584,
#   'visit_date': '2025-05-06',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.63,
#   'risk_score': 'Medium',
#   'doctor_id': 117},
#  {'visit_id': 66,
#   'patient_id': 4628,
#   'visit_date': '2025-03-06',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 9.59,
#   'risk_score': 'High',
#   'doctor_id': 147},
#  {'visit_id': 67,
#   'patient_id': 2493,
#   'visit_date': '2025-12-14',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.36,
#   'risk_score': 'Medium',
#   'doctor_id': 129},
#  {'visit_id': 68,
#   'patient_id': 1435,
#   'visit_date': '2025-06-22',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.32,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 69,
#   'patient_id': 3055,
#   'visit_date': '2025-02-24',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 33.76,
#   'risk_score': 'Low',
#   'doctor_id': 180},
#  {'visit_id': 70,
#   'patient_id': 2084,
#   'visit_date': '2025-10-22',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 17.33,
#   'risk_score': 'Low',
#   'doctor_id': 155},
#  {'visit_id': 71,
#   'patient_id': 3188,
#   'visit_date': '2025-02-01',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.69,
#   'risk_score': 'Medium',
#   'doctor_id': 138},
#  {'visit_id': 72,
#   'patient_id': 2390,
#   'visit_date': '2025-08-04',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.09,
#   'risk_score': 'Medium',
#   'doctor_id': 132},
#  {'visit_id': 73,
#   'patient_id': 3185,
#   'visit_date': '2025-04-20',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.42,
#   'risk_score': 'High',
#   'doctor_id': 144},
#  {'visit_id': 74,
#   'patient_id': 4689,
#   'visit_date': '2025-07-21',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 37.13,
#   'risk_score': 'High',
#   'doctor_id': 183},
#  {'visit_id': 75,
#   'patient_id': 675,
#   'visit_date': '2025-12-07',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.32,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 76,
#   'patient_id': 4996,
#   'visit_date': '2025-03-19',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.6,
#   'risk_score': 'Medium',
#   'doctor_id': 156},
#  {'visit_id': 77,
#   'patient_id': 25,
#   'visit_date': '2025-07-11',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.9,
#   'risk_score': 'Low',
#   'doctor_id': 121},
#  {'visit_id': 78,
#   'patient_id': 631,
#   'visit_date': '2025-10-09',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 2.5,
#   'risk_score': 'High',
#   'doctor_id': 151},
#  {'visit_id': 79,
#   'patient_id': 4625,
#   'visit_date': '2025-10-29',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 65.76,
#   'risk_score': 'Medium',
#   'doctor_id': 136},
#  {'visit_id': 80,
#   'patient_id': 811,
#   'visit_date': '2025-05-16',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.67,
#   'risk_score': 'High',
#   'doctor_id': 185},
#  {'visit_id': 81,
#   'patient_id': 3929,
#   'visit_date': '2025-08-05',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.62,
#   'risk_score': 'Low',
#   'doctor_id': 190},
#  {'visit_id': 82,
#   'patient_id': 4840,
#   'visit_date': '2025-05-30',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.81,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 83,
#   'patient_id': 3989,
#   'visit_date': '2025-09-07',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.1,
#   'risk_score': 'Medium',
#   'doctor_id': 194},
#  {'visit_id': 84,
#   'patient_id': 1053,
#   'visit_date': '2025-11-18',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.68,
#   'risk_score': 'Medium',
#   'doctor_id': 168},
#  {'visit_id': 85,
#   'patient_id': 3319,
#   'visit_date': '2025-06-16',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.09,
#   'risk_score': 'Medium',
#   'doctor_id': 130},
#  {'visit_id': 86,
#   'patient_id': 1649,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.17,
#   'risk_score': 'Low',
#   'doctor_id': 181},
#  {'visit_id': 87,
#   'patient_id': 2850,
#   'visit_date': '2025-02-04',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.01,
#   'risk_score': 'Low',
#   'doctor_id': 182},
#  {'visit_id': 88,
#   'patient_id': 4794,
#   'visit_date': '2025-08-04',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.17,
#   'risk_score': 'Low',
#   'doctor_id': 114},
#  {'visit_id': 89,
#   'patient_id': 4570,
#   'visit_date': '2025-04-26',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.86,
#   'risk_score': 'Low',
#   'doctor_id': 157},
#  {'visit_id': 90,
#   'patient_id': 3766,
#   'visit_date': '2025-03-24',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.58,
#   'risk_score': 'High',
#   'doctor_id': 148},
#  {'visit_id': 91,
#   'patient_id': 3404,
#   'visit_date': '2025-08-19',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.87,
#   'risk_score': 'Medium',
#   'doctor_id': 100},
#  {'visit_id': 92,
#   'patient_id': 1144,
#   'visit_date': '2025-06-29',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 13.53,
#   'risk_score': 'Medium',
#   'doctor_id': 130},
#  {'visit_id': 93,
#   'patient_id': 2277,
#   'visit_date': '2025-04-19',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.81,
#   'risk_score': 'High',
#   'doctor_id': 116},
#  {'visit_id': 94,
#   'patient_id': 1095,
#   'visit_date': '2026-01-03',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.6,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 95,
#   'patient_id': 4821,
#   'visit_date': '2025-10-25',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.08,
#   'risk_score': 'High',
#   'doctor_id': 126},
#  {'visit_id': 96,
#   'patient_id': 3586,
#   'visit_date': '2025-08-24',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.94,
#   'risk_score': 'Medium',
#   'doctor_id': 153},
#  {'visit_id': 97,
#   'patient_id': 4000,
#   'visit_date': '2025-07-22',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 11.91,
#   'risk_score': 'Medium',
#   'doctor_id': 102},
#  {'visit_id': 98,
#   'patient_id': 769,
#   'visit_date': '2025-09-19',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.75,
#   'risk_score': 'Medium',
#   'doctor_id': 109},
#  {'visit_id': 99,
#   'patient_id': 2683,
#   'visit_date': '2025-04-06',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 39.81,
#   'risk_score': 'Low',
#   'doctor_id': 135},
#  {'visit_id': 100,
#   'patient_id': 3307,
#   'visit_date': '2025-03-22',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 51.54,
#   'risk_score': 'Low',
#   'doctor_id': 103},
#  {'visit_id': 101,
#   'patient_id': 1346,
#   'visit_date': '2025-05-08',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.73,
#   'risk_score': 'Medium',
#   'doctor_id': 108},
#  {'visit_id': 102,
#   'patient_id': 3752,
#   'visit_date': '2025-06-24',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.61,
#   'risk_score': 'Medium',
#   'doctor_id': 155},
#  {'visit_id': 103,
#   'patient_id': 2517,
#   'visit_date': '2025-04-01',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'High',
#   'doctor_id': 114},
#  {'visit_id': 104,
#   'patient_id': 4503,
#   'visit_date': '2025-08-04',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.05,
#   'risk_score': 'High',
#   'doctor_id': 196},
#  {'visit_id': 105,
#   'patient_id': 1051,
#   'visit_date': '2025-08-02',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.62,
#   'risk_score': 'Medium',
#   'doctor_id': 172},
#  {'visit_id': 106,
#   'patient_id': 4789,
#   'visit_date': '2025-07-21',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.99,
#   'risk_score': 'Low',
#   'doctor_id': 148},
#  {'visit_id': 107,
#   'patient_id': 2744,
#   'visit_date': '2025-07-21',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.89,
#   'risk_score': 'Low',
#   'doctor_id': 181},
#  {'visit_id': 108,
#   'patient_id': 1497,
#   'visit_date': '2025-09-25',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.73,
#   'risk_score': 'Medium',
#   'doctor_id': 148},
#  {'visit_id': 109,
#   'patient_id': 2153,
#   'visit_date': '2025-03-08',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.18,
#   'risk_score': 'Low',
#   'doctor_id': 105},
#  {'visit_id': 110,
#   'patient_id': 216,
#   'visit_date': '2025-05-10',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.0,
#   'risk_score': 'High',
#   'doctor_id': 100},
#  {'visit_id': 111,
#   'patient_id': 1466,
#   'visit_date': '2025-07-10',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.86,
#   'risk_score': 'Low',
#   'doctor_id': 193},
#  {'visit_id': 112,
#   'patient_id': 1707,
#   'visit_date': '2025-06-07',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.99,
#   'risk_score': 'Low',
#   'doctor_id': 132},
#  {'visit_id': 113,
#   'patient_id': 4501,
#   'visit_date': '2025-08-12',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.17,
#   'risk_score': 'Medium',
#   'doctor_id': 123},
#  {'visit_id': 114,
#   'patient_id': 4370,
#   'visit_date': '2025-10-21',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 9.18,
#   'risk_score': 'Medium',
#   'doctor_id': 100},
#  {'visit_id': 115,
#   'patient_id': 2464,
#   'visit_date': '2025-09-17',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.8,
#   'risk_score': 'Medium',
#   'doctor_id': 108},
#  {'visit_id': 116,
#   'patient_id': 2071,
#   'visit_date': '2025-07-23',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 2.21,
#   'risk_score': 'High',
#   'doctor_id': 193},
#  {'visit_id': 117,
#   'patient_id': 686,
#   'visit_date': '2025-07-30',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.64,
#   'risk_score': 'Low',
#   'doctor_id': 137},
#  {'visit_id': 118,
#   'patient_id': 4754,
#   'visit_date': '2025-05-01',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 37.15,
#   'risk_score': 'Medium',
#   'doctor_id': 111},
#  {'visit_id': 119,
#   'patient_id': 938,
#   'visit_date': '2025-06-02',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 1.84,
#   'risk_score': 'Low',
#   'doctor_id': 158},
#  {'visit_id': 120,
#   'patient_id': 4309,
#   'visit_date': '2025-10-11',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 44.21,
#   'risk_score': 'Low',
#   'doctor_id': 140},
#  {'visit_id': 121,
#   'patient_id': 1751,
#   'visit_date': '2025-02-21',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.92,
#   'risk_score': 'High',
#   'doctor_id': 101},
#  {'visit_id': 122,
#   'patient_id': 2372,
#   'visit_date': '2025-01-27',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 25.6,
#   'risk_score': 'Low',
#   'doctor_id': 136},
#  {'visit_id': 123,
#   'patient_id': 1998,
#   'visit_date': '2025-09-02',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 35.49,
#   'risk_score': 'Low',
#   'doctor_id': 155},
#  {'visit_id': 124,
#   'patient_id': 3481,
#   'visit_date': '2025-03-09',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.22,
#   'risk_score': 'High',
#   'doctor_id': 106},
#  {'visit_id': 125,
#   'patient_id': 4329,
#   'visit_date': '2025-07-30',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.73,
#   'risk_score': 'Low',
#   'doctor_id': 107},
#  {'visit_id': 126,
#   'patient_id': 819,
#   'visit_date': '2026-01-11',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.16,
#   'risk_score': 'High',
#   'doctor_id': 131},
#  {'visit_id': 127,
#   'patient_id': 703,
#   'visit_date': '2025-06-28',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.28,
#   'risk_score': 'High',
#   'doctor_id': 110},
#  {'visit_id': 128,
#   'patient_id': 2659,
#   'visit_date': '2025-03-08',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.01,
#   'risk_score': 'Low',
#   'doctor_id': 129},
#  {'visit_id': 129,
#   'patient_id': 3549,
#   'visit_date': '2025-09-23',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.57,
#   'risk_score': 'High',
#   'doctor_id': 121},
#  {'visit_id': 130,
#   'patient_id': 852,
#   'visit_date': '2025-01-27',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 8.09,
#   'risk_score': 'Low',
#   'doctor_id': 109},
#  {'visit_id': 131,
#   'patient_id': 4496,
#   'visit_date': '2025-09-10',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.13,
#   'risk_score': 'Medium',
#   'doctor_id': 178},
#  {'visit_id': 132,
#   'patient_id': 3321,
#   'visit_date': '2025-12-09',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 34.84,
#   'risk_score': 'Low',
#   'doctor_id': 154},
#  {'visit_id': 133,
#   'patient_id': 2468,
#   'visit_date': '2025-03-26',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.93,
#   'risk_score': 'Low',
#   'doctor_id': 106},
#  {'visit_id': 134,
#   'patient_id': 3331,
#   'visit_date': '2025-12-14',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 18.57,
#   'risk_score': 'High',
#   'doctor_id': 100},
#  {'visit_id': 135,
#   'patient_id': 1170,
#   'visit_date': '2025-08-27',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.98,
#   'risk_score': 'High',
#   'doctor_id': 125},
#  {'visit_id': 136,
#   'patient_id': 2003,
#   'visit_date': '2025-02-25',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Medium',
#   'doctor_id': 122},
#  {'visit_id': 137,
#   'patient_id': 1608,
#   'visit_date': '2025-01-26',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.2,
#   'risk_score': 'High',
#   'doctor_id': 106},
#  {'visit_id': 138,
#   'patient_id': 1513,
#   'visit_date': '2025-04-29',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.43,
#   'risk_score': 'Low',
#   'doctor_id': 164},
#  {'visit_id': 139,
#   'patient_id': 3537,
#   'visit_date': '2025-07-10',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 3.91,
#   'risk_score': 'Medium',
#   'doctor_id': 142},
#  {'visit_id': 140,
#   'patient_id': 155,
#   'visit_date': '2025-12-31',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 2.52,
#   'risk_score': 'Medium',
#   'doctor_id': 121},
#  {'visit_id': 141,
#   'patient_id': 2362,
#   'visit_date': '2025-03-09',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 38.5,
#   'risk_score': 'Low',
#   'doctor_id': 200},
#  {'visit_id': 142,
#   'patient_id': 1257,
#   'visit_date': '2025-02-02',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 42.34,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 143,
#   'patient_id': 301,
#   'visit_date': '2025-03-13',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.55,
#   'risk_score': 'Medium',
#   'doctor_id': 132},
#  {'visit_id': 144,
#   'patient_id': 2620,
#   'visit_date': '2025-11-17',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.47,
#   'risk_score': 'Low',
#   'doctor_id': 102},
#  {'visit_id': 145,
#   'patient_id': 782,
#   'visit_date': '2025-08-13',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.25,
#   'risk_score': 'Medium',
#   'doctor_id': 126},
#  {'visit_id': 146,
#   'patient_id': 4255,
#   'visit_date': '2025-04-02',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 36.79,
#   'risk_score': 'Low',
#   'doctor_id': 117},
#  {'visit_id': 147,
#   'patient_id': 2277,
#   'visit_date': '2025-02-08',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.61,
#   'risk_score': 'Low',
#   'doctor_id': 129},
#  {'visit_id': 148,
#   'patient_id': 4810,
#   'visit_date': '2025-03-27',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 29.32,
#   'risk_score': 'Medium',
#   'doctor_id': 122},
#  {'visit_id': 149,
#   'patient_id': 387,
#   'visit_date': '2025-07-29',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 2.82,
#   'risk_score': 'High',
#   'doctor_id': 183},
#  {'visit_id': 150,
#   'patient_id': 226,
#   'visit_date': '2025-03-09',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 8.08,
#   'risk_score': 'High',
#   'doctor_id': 178},
#  {'visit_id': 151,
#   'patient_id': 380,
#   'visit_date': '2025-02-27',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 1.69,
#   'risk_score': 'Low',
#   'doctor_id': 132},
#  {'visit_id': 152,
#   'patient_id': 4377,
#   'visit_date': '2025-06-26',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 2.82,
#   'risk_score': 'Low',
#   'doctor_id': 173},
#  {'visit_id': 153,
#   'patient_id': 828,
#   'visit_date': '2025-04-28',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 30.12,
#   'risk_score': 'Low',
#   'doctor_id': 122},
#  {'visit_id': 154,
#   'patient_id': 2979,
#   'visit_date': '2025-04-22',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 3.52,
#   'risk_score': 'High',
#   'doctor_id': 114},
#  {'visit_id': 155,
#   'patient_id': 1759,
#   'visit_date': '2025-04-11',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 2.95,
#   'risk_score': 'Low',
#   'doctor_id': 176},
#  {'visit_id': 156,
#   'patient_id': 2083,
#   'visit_date': '2025-07-10',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.83,
#   'risk_score': 'Low',
#   'doctor_id': 136},
#  {'visit_id': 157,
#   'patient_id': 2731,
#   'visit_date': '2025-03-25',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 21.55,
#   'risk_score': 'Medium',
#   'doctor_id': 123},
#  {'visit_id': 158,
#   'patient_id': 4101,
#   'visit_date': '2025-08-12',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 16.78,
#   'risk_score': 'High',
#   'doctor_id': 178},
#  {'visit_id': 159,
#   'patient_id': 3627,
#   'visit_date': '2025-08-27',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 6.86,
#   'risk_score': 'Medium',
#   'doctor_id': 133},
#  {'visit_id': 160,
#   'patient_id': 4782,
#   'visit_date': '2025-10-09',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 29.3,
#   'risk_score': 'Medium',
#   'doctor_id': 124},
#  {'visit_id': 161,
#   'patient_id': 2193,
#   'visit_date': '2025-04-19',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 47.15,
#   'risk_score': 'Medium',
#   'doctor_id': 193},
#  {'visit_id': 162,
#   'patient_id': 4779,
#   'visit_date': '2025-07-21',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 40.74,
#   'risk_score': 'Low',
#   'doctor_id': 196},
#  {'visit_id': 163,
#   'patient_id': 3718,
#   'visit_date': '2025-12-11',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.56,
#   'risk_score': 'High',
#   'doctor_id': 180},
#  {'visit_id': 164,
#   'patient_id': 1987,
#   'visit_date': '2025-06-10',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.16,
#   'risk_score': 'Medium',
#   'doctor_id': 170},
#  {'visit_id': 165,
#   'patient_id': 2954,
#   'visit_date': '2025-04-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.01,
#   'risk_score': 'Medium',
#   'doctor_id': 129},
#  {'visit_id': 166,
#   'patient_id': 2919,
#   'visit_date': '2025-08-15',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.06,
#   'risk_score': 'High',
#   'doctor_id': 188},
#  {'visit_id': 167,
#   'patient_id': 1455,
#   'visit_date': '2025-08-04',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.98,
#   'risk_score': 'Low',
#   'doctor_id': 142},
#  {'visit_id': 168,
#   'patient_id': 4610,
#   'visit_date': '2025-02-22',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.03,
#   'risk_score': 'Low',
#   'doctor_id': 197},
#  {'visit_id': 169,
#   'patient_id': 3196,
#   'visit_date': '2025-04-10',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.64,
#   'risk_score': 'Low',
#   'doctor_id': 181},
#  {'visit_id': 170,
#   'patient_id': 4186,
#   'visit_date': '2025-02-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.33,
#   'risk_score': 'Low',
#   'doctor_id': 153},
#  {'visit_id': 171,
#   'patient_id': 2459,
#   'visit_date': '2025-03-14',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.68,
#   'risk_score': 'Low',
#   'doctor_id': 200},
#  {'visit_id': 172,
#   'patient_id': 3027,
#   'visit_date': '2025-05-12',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 39.01,
#   'risk_score': 'Medium',
#   'doctor_id': 174},
#  {'visit_id': 173,
#   'patient_id': 3039,
#   'visit_date': '2025-04-11',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.0,
#   'risk_score': 'Medium',
#   'doctor_id': 199},
#  {'visit_id': 174,
#   'patient_id': 2219,
#   'visit_date': '2025-08-09',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.86,
#   'risk_score': 'Low',
#   'doctor_id': 140},
#  {'visit_id': 175,
#   'patient_id': 1912,
#   'visit_date': '2025-07-12',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 3.41,
#   'risk_score': 'Medium',
#   'doctor_id': 174},
#  {'visit_id': 176,
#   'patient_id': 3341,
#   'visit_date': '2025-03-26',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.86,
#   'risk_score': 'Low',
#   'doctor_id': 170},
#  {'visit_id': 177,
#   'patient_id': 2778,
#   'visit_date': '2025-05-27',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 43.8,
#   'risk_score': 'Medium',
#   'doctor_id': 125},
#  {'visit_id': 178,
#   'patient_id': 3181,
#   'visit_date': '2025-09-29',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 18.23,
#   'risk_score': 'Low',
#   'doctor_id': 138},
#  {'visit_id': 179,
#   'patient_id': 846,
#   'visit_date': '2025-07-12',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.35,
#   'risk_score': 'Low',
#   'doctor_id': 120},
#  {'visit_id': 180,
#   'patient_id': 3750,
#   'visit_date': '2025-12-16',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.23,
#   'risk_score': 'High',
#   'doctor_id': 125},
#  {'visit_id': 181,
#   'patient_id': 4482,
#   'visit_date': '2025-05-14',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.09,
#   'risk_score': 'Low',
#   'doctor_id': 127},
#  {'visit_id': 182,
#   'patient_id': 2348,
#   'visit_date': '2025-08-18',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 49.92,
#   'risk_score': 'Low',
#   'doctor_id': 164},
#  {'visit_id': 183,
#   'patient_id': 3516,
#   'visit_date': '2025-05-26',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 12.9,
#   'risk_score': 'Medium',
#   'doctor_id': 103},
#  {'visit_id': 184,
#   'patient_id': 3383,
#   'visit_date': '2025-03-12',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 6.36,
#   'risk_score': 'Low',
#   'doctor_id': 168},
#  {'visit_id': 185,
#   'patient_id': 1206,
#   'visit_date': '2025-06-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.99,
#   'risk_score': 'Medium',
#   'doctor_id': 175},
#  {'visit_id': 186,
#   'patient_id': 1937,
#   'visit_date': '2025-12-01',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 4.24,
#   'risk_score': 'Medium',
#   'doctor_id': 200},
#  {'visit_id': 187,
#   'patient_id': 633,
#   'visit_date': '2025-08-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.78,
#   'risk_score': 'Low',
#   'doctor_id': 128},
#  {'visit_id': 188,
#   'patient_id': 4097,
#   'visit_date': '2025-03-03',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.85,
#   'risk_score': 'Medium',
#   'doctor_id': 200},
#  {'visit_id': 189,
#   'patient_id': 4222,
#   'visit_date': '2025-12-21',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.87,
#   'risk_score': 'Low',
#   'doctor_id': 159},
#  {'visit_id': 190,
#   'patient_id': 725,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 50.22,
#   'risk_score': 'Medium',
#   'doctor_id': 163},
#  {'visit_id': 191,
#   'patient_id': 1706,
#   'visit_date': '2025-09-19',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.25,
#   'risk_score': 'Low',
#   'doctor_id': 107},
#  {'visit_id': 192,
#   'patient_id': 3863,
#   'visit_date': '2026-01-08',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.6,
#   'risk_score': 'Medium',
#   'doctor_id': 112},
#  {'visit_id': 193,
#   'patient_id': 2244,
#   'visit_date': '2025-10-21',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.66,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 194,
#   'patient_id': 4538,
#   'visit_date': '2026-01-19',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 26.62,
#   'risk_score': 'Medium',
#   'doctor_id': 117},
#  {'visit_id': 195,
#   'patient_id': 3168,
#   'visit_date': '2025-06-09',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.25,
#   'risk_score': 'Low',
#   'doctor_id': 115},
#  {'visit_id': 196,
#   'patient_id': 1080,
#   'visit_date': '2025-03-23',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.16,
#   'risk_score': 'Low',
#   'doctor_id': 200},
#  {'visit_id': 197,
#   'patient_id': 1610,
#   'visit_date': '2025-11-19',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 150},
#  {'visit_id': 198,
#   'patient_id': 1507,
#   'visit_date': '2025-07-04',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.16,
#   'risk_score': 'Low',
#   'doctor_id': 118},
#  {'visit_id': 199,
#   'patient_id': 4737,
#   'visit_date': '2025-12-10',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.5,
#   'risk_score': 'Low',
#   'doctor_id': 189},
#  {'visit_id': 200,
#   'patient_id': 2430,
#   'visit_date': '2025-07-15',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.98,
#   'risk_score': 'Low',
#   'doctor_id': 124},
#  {'visit_id': 201,
#   'patient_id': 4898,
#   'visit_date': '2025-03-16',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.15,
#   'risk_score': 'Low',
#   'doctor_id': 195},
#  {'visit_id': 202,
#   'patient_id': 4793,
#   'visit_date': '2025-11-17',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 40.68,
#   'risk_score': 'Low',
#   'doctor_id': 101},
#  {'visit_id': 203,
#   'patient_id': 1764,
#   'visit_date': '2025-08-10',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 29.01,
#   'risk_score': 'Medium',
#   'doctor_id': 164},
#  {'visit_id': 204,
#   'patient_id': 655,
#   'visit_date': '2025-12-27',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.08,
#   'risk_score': 'High',
#   'doctor_id': 182},
#  {'visit_id': 205,
#   'patient_id': 3389,
#   'visit_date': '2026-01-14',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.94,
#   'risk_score': 'Low',
#   'doctor_id': 137},
#  {'visit_id': 206,
#   'patient_id': 4647,
#   'visit_date': '2025-09-12',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 6.37,
#   'risk_score': 'Low',
#   'doctor_id': 152},
#  {'visit_id': 207,
#   'patient_id': 3699,
#   'visit_date': '2025-12-30',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 32.67,
#   'risk_score': 'High',
#   'doctor_id': 187},
#  {'visit_id': 208,
#   'patient_id': 4512,
#   'visit_date': '2025-05-14',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.89,
#   'risk_score': 'Low',
#   'doctor_id': 128},
#  {'visit_id': 209,
#   'patient_id': 4916,
#   'visit_date': '2025-03-17',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 36.66,
#   'risk_score': 'Low',
#   'doctor_id': 149},
#  {'visit_id': 210,
#   'patient_id': 881,
#   'visit_date': '2025-04-16',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 29.37,
#   'risk_score': 'Low',
#   'doctor_id': 103},
#  {'visit_id': 211,
#   'patient_id': 931,
#   'visit_date': '2025-08-13',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'High',
#   'doctor_id': 172},
#  {'visit_id': 212,
#   'patient_id': 4929,
#   'visit_date': '2025-06-08',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.36,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 213,
#   'patient_id': 667,
#   'visit_date': '2025-04-29',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 7.54,
#   'risk_score': 'Medium',
#   'doctor_id': 134},
#  {'visit_id': 214,
#   'patient_id': 2228,
#   'visit_date': '2025-05-10',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.51,
#   'risk_score': 'Low',
#   'doctor_id': 153},
#  {'visit_id': 215,
#   'patient_id': 3949,
#   'visit_date': '2025-12-22',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 22.12,
#   'risk_score': 'Medium',
#   'doctor_id': 135},
#  {'visit_id': 216,
#   'patient_id': 4371,
#   'visit_date': '2025-03-12',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.58,
#   'risk_score': 'High',
#   'doctor_id': 172},
#  {'visit_id': 217,
#   'patient_id': 4469,
#   'visit_date': '2026-01-08',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.9,
#   'risk_score': 'High',
#   'doctor_id': 193},
#  {'visit_id': 218,
#   'patient_id': 509,
#   'visit_date': '2025-02-25',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.86,
#   'risk_score': 'Low',
#   'doctor_id': 176},
#  {'visit_id': 219,
#   'patient_id': 1774,
#   'visit_date': '2025-02-08',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.17,
#   'risk_score': 'Low',
#   'doctor_id': 169},
#  {'visit_id': 220,
#   'patient_id': 747,
#   'visit_date': '2025-03-14',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.25,
#   'risk_score': 'Low',
#   'doctor_id': 136},
#  {'visit_id': 221,
#   'patient_id': 4738,
#   'visit_date': '2025-12-21',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 36.33,
#   'risk_score': 'Low',
#   'doctor_id': 184},
#  {'visit_id': 222,
#   'patient_id': 681,
#   'visit_date': '2025-02-01',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 41.24,
#   'risk_score': 'Medium',
#   'doctor_id': 183},
#  {'visit_id': 223,
#   'patient_id': 1324,
#   'visit_date': '2025-02-08',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.18,
#   'risk_score': 'Medium',
#   'doctor_id': 171},
#  {'visit_id': 224,
#   'patient_id': 3418,
#   'visit_date': '2025-08-21',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.44,
#   'risk_score': 'Medium',
#   'doctor_id': 169},
#  {'visit_id': 225,
#   'patient_id': 271,
#   'visit_date': '2025-02-26',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 18.19,
#   'risk_score': 'Medium',
#   'doctor_id': 105},
#  {'visit_id': 226,
#   'patient_id': 2019,
#   'visit_date': '2025-06-18',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.67,
#   'risk_score': 'Low',
#   'doctor_id': 198},
#  {'visit_id': 227,
#   'patient_id': 1644,
#   'visit_date': '2025-06-01',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.12,
#   'risk_score': 'Low',
#   'doctor_id': 142},
#  {'visit_id': 228,
#   'patient_id': 2477,
#   'visit_date': '2025-10-30',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 9.83,
#   'risk_score': 'Low',
#   'doctor_id': 107},
#  {'visit_id': 229,
#   'patient_id': 1717,
#   'visit_date': '2025-07-02',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.31,
#   'risk_score': 'Medium',
#   'doctor_id': 154},
#  {'visit_id': 230,
#   'patient_id': 503,
#   'visit_date': '2026-01-11',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.39,
#   'risk_score': 'High',
#   'doctor_id': 185},
#  {'visit_id': 231,
#   'patient_id': 788,
#   'visit_date': '2025-09-25',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 59.37,
#   'risk_score': 'High',
#   'doctor_id': 126},
#  {'visit_id': 232,
#   'patient_id': 4453,
#   'visit_date': '2025-08-03',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 29.58,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 233,
#   'patient_id': 3937,
#   'visit_date': '2025-03-11',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.46,
#   'risk_score': 'High',
#   'doctor_id': 163},
#  {'visit_id': 234,
#   'patient_id': 951,
#   'visit_date': '2025-05-04',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 11.25,
#   'risk_score': 'High',
#   'doctor_id': 112},
#  {'visit_id': 235,
#   'patient_id': 4776,
#   'visit_date': '2026-01-04',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.28,
#   'risk_score': 'Low',
#   'doctor_id': 117},
#  {'visit_id': 236,
#   'patient_id': 2486,
#   'visit_date': '2025-09-14',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.34,
#   'risk_score': 'High',
#   'doctor_id': 120},
#  {'visit_id': 237,
#   'patient_id': 4267,
#   'visit_date': '2025-10-31',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.04,
#   'risk_score': 'Medium',
#   'doctor_id': 137},
#  {'visit_id': 238,
#   'patient_id': 754,
#   'visit_date': '2025-03-22',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.8,
#   'risk_score': 'Low',
#   'doctor_id': 158},
#  {'visit_id': 239,
#   'patient_id': 2451,
#   'visit_date': '2025-07-01',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 24.09,
#   'risk_score': 'Low',
#   'doctor_id': 189},
#  {'visit_id': 240,
#   'patient_id': 616,
#   'visit_date': '2025-11-27',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.73,
#   'risk_score': 'Medium',
#   'doctor_id': 160},
#  {'visit_id': 241,
#   'patient_id': 4179,
#   'visit_date': '2025-07-27',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.05,
#   'risk_score': 'High',
#   'doctor_id': 137},
#  {'visit_id': 242,
#   'patient_id': 3512,
#   'visit_date': '2025-04-26',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 243,
#   'patient_id': 4540,
#   'visit_date': '2025-03-01',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 27.52,
#   'risk_score': 'Low',
#   'doctor_id': 163},
#  {'visit_id': 244,
#   'patient_id': 2472,
#   'visit_date': '2025-11-30',
# ...
#   'patient_id': 2380,
#   'visit_date': '2025-06-03',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.56,
#   'risk_score': 'Medium',
#   'doctor_id': 167},
#  {'visit_id': 921,
#   'patient_id': 2733,
#   'visit_date': '2025-12-21',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.53,
#   'risk_score': 'Low',
#   'doctor_id': 146},
#  {'visit_id': 922,
#   'patient_id': 2016,
#   'visit_date': '2025-07-14',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 0.5,
#   'risk_score': 'Low',
#   'doctor_id': 186},
#  {'visit_id': 923,
#   'patient_id': 1067,
#   'visit_date': '2025-08-18',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.55,
#   'risk_score': 'Low',
#   'doctor_id': 180},
#  {'visit_id': 924,
#   'patient_id': 111,
#   'visit_date': '2025-02-07',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.69,
#   'risk_score': 'High',
#   'doctor_id': 103},
#  {'visit_id': 925,
#   'patient_id': 4675,
#   'visit_date': '2025-03-01',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.6,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 926,
#   'patient_id': 2012,
#   'visit_date': '2025-06-26',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 7.73,
#   'risk_score': 'Low',
#   'doctor_id': 146},
#  {'visit_id': 927,
#   'patient_id': 3453,
#   'visit_date': '2025-02-28',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 49.23,
#   'risk_score': 'Medium',
#   'doctor_id': 188},
#  {'visit_id': 928,
#   'patient_id': 4898,
#   'visit_date': '2025-10-03',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 17.56,
#   'risk_score': 'Low',
#   'doctor_id': 194},
#  {'visit_id': 929,
#   'patient_id': 3270,
#   'visit_date': '2025-06-29',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.86,
#   'risk_score': 'Low',
#   'doctor_id': 170},
#  {'visit_id': 930,
#   'patient_id': 834,
#   'visit_date': '2026-01-04',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 0.56,
#   'risk_score': 'Medium',
#   'doctor_id': 127},
#  {'visit_id': 931,
#   'patient_id': 3669,
#   'visit_date': '2025-06-10',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.53,
#   'risk_score': 'Low',
#   'doctor_id': 109},
#  {'visit_id': 932,
#   'patient_id': 2556,
#   'visit_date': '2025-06-25',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.32,
#   'risk_score': 'Medium',
#   'doctor_id': 154},
#  {'visit_id': 933,
#   'patient_id': 762,
#   'visit_date': '2025-10-08',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.95,
#   'risk_score': 'Medium',
#   'doctor_id': 152},
#  {'visit_id': 934,
#   'patient_id': 4188,
#   'visit_date': '2025-09-26',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.4,
#   'risk_score': 'High',
#   'doctor_id': 135},
#  {'visit_id': 935,
#   'patient_id': 3782,
#   'visit_date': '2025-11-14',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.36,
#   'risk_score': 'High',
#   'doctor_id': 185},
#  {'visit_id': 936,
#   'patient_id': 3141,
#   'visit_date': '2025-10-27',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.03,
#   'risk_score': 'Low',
#   'doctor_id': 178},
#  {'visit_id': 937,
#   'patient_id': 130,
#   'visit_date': '2025-07-29',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 19.93,
#   'risk_score': 'Medium',
#   'doctor_id': 147},
#  {'visit_id': 938,
#   'patient_id': 3311,
#   'visit_date': '2025-07-14',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.73,
#   'risk_score': 'Low',
#   'doctor_id': 147},
#  {'visit_id': 939,
#   'patient_id': 138,
#   'visit_date': '2025-10-16',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 38.58,
#   'risk_score': 'Medium',
#   'doctor_id': 108},
#  {'visit_id': 940,
#   'patient_id': 2263,
#   'visit_date': '2025-04-14',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.45,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 941,
#   'patient_id': 1897,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.31,
#   'risk_score': 'Low',
#   'doctor_id': 173},
#  {'visit_id': 942,
#   'patient_id': 1524,
#   'visit_date': '2025-10-01',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.13,
#   'risk_score': 'Medium',
#   'doctor_id': 102},
#  {'visit_id': 943,
#   'patient_id': 2585,
#   'visit_date': '2025-06-11',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.49,
#   'risk_score': 'Low',
#   'doctor_id': 130},
#  {'visit_id': 944,
#   'patient_id': 4383,
#   'visit_date': '2025-08-24',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 38.24,
#   'risk_score': 'High',
#   'doctor_id': 108},
#  {'visit_id': 945,
#   'patient_id': 2076,
#   'visit_date': '2025-02-17',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 39.56,
#   'risk_score': 'Low',
#   'doctor_id': 127},
#  {'visit_id': 946,
#   'patient_id': 723,
#   'visit_date': '2025-10-19',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.5,
#   'risk_score': 'Low',
#   'doctor_id': 104},
#  {'visit_id': 947,
#   'patient_id': 2526,
#   'visit_date': '2025-09-25',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 14.94,
#   'risk_score': 'Medium',
#   'doctor_id': 131},
#  {'visit_id': 948,
#   'patient_id': 1747,
#   'visit_date': '2025-10-29',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 45.92,
#   'risk_score': 'High',
#   'doctor_id': 132},
#  {'visit_id': 949,
#   'patient_id': 3718,
#   'visit_date': '2025-10-03',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 5.47,
#   'risk_score': 'High',
#   'doctor_id': 133},
#  {'visit_id': 950,
#   'patient_id': 3730,
#   'visit_date': '2025-06-22',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 1.35,
#   'risk_score': 'Low',
#   'doctor_id': 100},
#  {'visit_id': 951,
#   'patient_id': 1540,
#   'visit_date': '2025-07-06',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.98,
#   'risk_score': 'Low',
#   'doctor_id': 136},
#  {'visit_id': 952,
#   'patient_id': 845,
#   'visit_date': '2025-01-28',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 54.04,
#   'risk_score': 'Low',
#   'doctor_id': 121},
#  {'visit_id': 953,
#   'patient_id': 1851,
#   'visit_date': '2025-10-05',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 6.4,
#   'risk_score': 'High',
#   'doctor_id': 128},
#  {'visit_id': 954,
#   'patient_id': 2928,
#   'visit_date': '2025-03-03',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 17.11,
#   'risk_score': 'Medium',
#   'doctor_id': 187},
#  {'visit_id': 955,
#   'patient_id': 3329,
#   'visit_date': '2025-08-19',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 2.37,
#   'risk_score': 'Low',
#   'doctor_id': 161},
#  {'visit_id': 956,
#   'patient_id': 2478,
#   'visit_date': '2025-03-09',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 22.84,
#   'risk_score': 'High',
#   'doctor_id': 126},
#  {'visit_id': 957,
#   'patient_id': 3003,
#   'visit_date': '2025-02-28',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.11,
#   'risk_score': 'High',
#   'doctor_id': 124},
#  {'visit_id': 958,
#   'patient_id': 71,
#   'visit_date': '2025-04-02',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.35,
#   'risk_score': 'Low',
#   'doctor_id': 147},
#  {'visit_id': 959,
#   'patient_id': 1603,
#   'visit_date': '2025-06-05',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.82,
#   'risk_score': 'Low',
#   'doctor_id': 168},
#  {'visit_id': 960,
#   'patient_id': 644,
#   'visit_date': '2025-07-17',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.85,
#   'risk_score': 'Low',
#   'doctor_id': 167},
#  {'visit_id': 961,
#   'patient_id': 4408,
#   'visit_date': '2025-07-25',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.87,
#   'risk_score': 'High',
#   'doctor_id': 188},
#  {'visit_id': 962,
#   'patient_id': 975,
#   'visit_date': '2025-09-27',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.36,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 963,
#   'patient_id': 2816,
#   'visit_date': '2025-12-04',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.08,
#   'risk_score': 'Medium',
#   'doctor_id': 173},
#  {'visit_id': 964,
#   'patient_id': 4281,
#   'visit_date': '2025-06-24',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 26.47,
#   'risk_score': 'Low',
#   'doctor_id': 109},
#  {'visit_id': 965,
#   'patient_id': 1400,
#   'visit_date': '2025-10-30',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.99,
#   'risk_score': 'Medium',
#   'doctor_id': 146},
#  {'visit_id': 966,
#   'patient_id': 4251,
#   'visit_date': '2025-03-17',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.1,
#   'risk_score': 'Medium',
#   'doctor_id': 144},
#  {'visit_id': 967,
#   'patient_id': 1457,
#   'visit_date': '2025-05-10',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.61,
#   'risk_score': 'Low',
#   'doctor_id': 112},
#  {'visit_id': 968,
#   'patient_id': 4814,
#   'visit_date': '2025-05-12',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 25.37,
#   'risk_score': 'High',
#   'doctor_id': 197},
#  {'visit_id': 969,
#   'patient_id': 4686,
#   'visit_date': '2025-03-07',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 9.47,
#   'risk_score': 'Low',
#   'doctor_id': 197},
#  {'visit_id': 970,
#   'patient_id': 337,
#   'visit_date': '2025-02-17',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 22.69,
#   'risk_score': 'Medium',
#   'doctor_id': 108},
#  {'visit_id': 971,
#   'patient_id': 2116,
#   'visit_date': '2025-08-05',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 36.76,
#   'risk_score': 'Low',
#   'doctor_id': 116},
#  {'visit_id': 972,
#   'patient_id': 4971,
#   'visit_date': '2025-04-18',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.48,
#   'risk_score': 'Low',
#   'doctor_id': 113},
#  {'visit_id': 973,
#   'patient_id': 4983,
#   'visit_date': '2025-07-28',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 12.53,
#   'risk_score': 'Medium',
#   'doctor_id': 195},
#  {'visit_id': 974,
#   'patient_id': 1984,
#   'visit_date': '2025-02-15',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 9.41,
#   'risk_score': 'Low',
#   'doctor_id': 113},
#  {'visit_id': 975,
#   'patient_id': 1421,
#   'visit_date': '2025-02-21',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 30.47,
#   'risk_score': 'Low',
#   'doctor_id': 119},
#  {'visit_id': 976,
#   'patient_id': 3869,
#   'visit_date': '2025-04-28',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 36.97,
#   'risk_score': 'Low',
#   'doctor_id': 111},
#  {'visit_id': 977,
#   'patient_id': 2423,
#   'visit_date': '2025-08-13',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.11,
#   'risk_score': 'Low',
#   'doctor_id': 131},
#  {'visit_id': 978,
#   'patient_id': 687,
#   'visit_date': '2025-07-09',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 4.09,
#   'risk_score': 'High',
#   'doctor_id': 146},
#  {'visit_id': 979,
#   'patient_id': 1604,
#   'visit_date': '2025-02-16',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 2.79,
#   'risk_score': 'Medium',
#   'doctor_id': 128},
#  {'visit_id': 980,
#   'patient_id': 320,
#   'visit_date': '2025-04-27',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.02,
#   'risk_score': 'Medium',
#   'doctor_id': 137},
#  {'visit_id': 981,
#   'patient_id': 85,
#   'visit_date': '2025-09-07',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.85,
#   'risk_score': 'Low',
#   'doctor_id': 111},
#  {'visit_id': 982,
#   'patient_id': 818,
#   'visit_date': '2025-02-13',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.14,
#   'risk_score': 'Low',
#   'doctor_id': 152},
#  {'visit_id': 983,
#   'patient_id': 2954,
#   'visit_date': '2025-11-30',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.91,
#   'risk_score': 'Low',
#   'doctor_id': 184},
#  {'visit_id': 984,
#   'patient_id': 2563,
#   'visit_date': '2025-07-02',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 32.87,
#   'risk_score': 'Medium',
#   'doctor_id': 194},
#  {'visit_id': 985,
#   'patient_id': 3541,
#   'visit_date': '2025-05-21',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.01,
#   'risk_score': 'Low',
#   'doctor_id': 141},
#  {'visit_id': 986,
#   'patient_id': 2487,
#   'visit_date': '2025-03-22',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 14.13,
#   'risk_score': 'Medium',
#   'doctor_id': 123},
#  {'visit_id': 987,
#   'patient_id': 4896,
#   'visit_date': '2025-11-18',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 43.96,
#   'risk_score': 'High',
#   'doctor_id': 152},
#  {'visit_id': 988,
#   'patient_id': 4899,
#   'visit_date': '2025-06-05',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.71,
#   'risk_score': 'Medium',
#   'doctor_id': 107},
#  {'visit_id': 989,
#   'patient_id': 3416,
#   'visit_date': '2025-06-26',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.88,
#   'risk_score': 'Low',
#   'doctor_id': 179},
#  {'visit_id': 990,
#   'patient_id': 844,
#   'visit_date': '2025-01-31',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 36.56,
#   'risk_score': 'Low',
#   'doctor_id': 188},
#  {'visit_id': 991,
#   'patient_id': 3133,
#   'visit_date': '2025-12-14',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.15,
#   'risk_score': 'Medium',
#   'doctor_id': 178},
#  {'visit_id': 992,
#   'patient_id': 765,
#   'visit_date': '2025-01-28',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 30.57,
#   'risk_score': 'Low',
#   'doctor_id': 193},
#  {'visit_id': 993,
#   'patient_id': 4313,
#   'visit_date': '2025-12-11',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.03,
#   'risk_score': 'Medium',
#   'doctor_id': 185},
#  {'visit_id': 994,
#   'patient_id': 2049,
#   'visit_date': '2025-03-29',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 16.52,
#   'risk_score': 'Medium',
#   'doctor_id': 151},
#  {'visit_id': 995,
#   'patient_id': 4388,
#   'visit_date': '2025-04-02',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.55,
#   'risk_score': 'Low',
#   'doctor_id': 116},
#  {'visit_id': 996,
#   'patient_id': 1245,
#   'visit_date': '2026-01-06',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.43,
#   'risk_score': 'Medium',
#   'doctor_id': 163},
#  {'visit_id': 997,
#   'patient_id': 2916,
#   'visit_date': '2025-12-12',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.7,
#   'risk_score': 'Medium',
#   'doctor_id': 183},
#  {'visit_id': 998,
#   'patient_id': 3122,
#   'visit_date': '2025-12-02',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.55,
#   'risk_score': 'High',
#   'doctor_id': 118},
#  {'visit_id': 999,
#   'patient_id': 250,
#   'visit_date': '2025-10-17',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.81,
#   'risk_score': 'Low',
#   'doctor_id': 134},
#  {'visit_id': 1000,
#   'patient_id': 4068,
#   'visit_date': '2025-11-09',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 15.03,
#   'risk_score': 'Medium',
#   'doctor_id': 195},
#  ...]

# %%
len(visits_data)
# Out:
# 25000

# %%
patient_data= patient.to_dict(orient="records")
patient_data
# Out:
# [{'patient_id': 1,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-14'},
#  {'patient_id': 2,
#   'age': 42,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-18'},
#  {'patient_id': 3,
#   'age': 56,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-11'},
#  {'patient_id': 4,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-18'},
#  {'patient_id': 5,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-23'},
#  {'patient_id': 6,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-11'},
#  {'patient_id': 7,
#   'age': 73,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-08'},
#  {'patient_id': 8,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-25'},
#  {'patient_id': 9,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-01'},
#  {'patient_id': 10,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-11'},
#  {'patient_id': 11,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-24'},
#  {'patient_id': 12,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-12'},
#  {'patient_id': 13,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-13'},
#  {'patient_id': 14,
#   'age': 10,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-14'},
#  {'patient_id': 15,
#   'age': 13,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-13'},
#  {'patient_id': 16,
#   'age': 34,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-05'},
#  {'patient_id': 17,
#   'age': 26,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-30'},
#  {'patient_id': 18,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-06'},
#  {'patient_id': 19,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-15'},
#  {'patient_id': 20,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-26'},
#  {'patient_id': 21,
#   'age': 71,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-24'},
#  {'patient_id': 22,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-13'},
#  {'patient_id': 23,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-21'},
#  {'patient_id': 24,
#   'age': 19,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-17'},
#  {'patient_id': 25,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-04'},
#  {'patient_id': 26,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-19'},
#  {'patient_id': 27,
#   'age': 24,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-03'},
#  {'patient_id': 28,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-13'},
#  {'patient_id': 29,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-23'},
#  {'patient_id': 30,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-29'},
#  {'patient_id': 31,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-18'},
#  {'patient_id': 32,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-25'},
#  {'patient_id': 33,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-23'},
#  {'patient_id': 34,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-17'},
#  {'patient_id': 35,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-12'},
#  {'patient_id': 36,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-26'},
#  {'patient_id': 37,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-17'},
#  {'patient_id': 38,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-25'},
#  {'patient_id': 39,
#   'age': 21,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-08'},
#  {'patient_id': 40,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-28'},
#  {'patient_id': 41,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-24'},
#  {'patient_id': 42,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-10'},
#  {'patient_id': 43,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-16'},
#  {'patient_id': 44,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-14'},
#  {'patient_id': 45,
#   'age': 18,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-27'},
#  {'patient_id': 46,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-11'},
#  {'patient_id': 47,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-28'},
#  {'patient_id': 48,
#   'age': 64,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-21'},
#  {'patient_id': 49,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-09'},
#  {'patient_id': 50,
#   'age': 13,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-21'},
#  {'patient_id': 51,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-24'},
#  {'patient_id': 52,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-11'},
#  {'patient_id': 53,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-18'},
#  {'patient_id': 54,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-18'},
#  {'patient_id': 55,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-31'},
#  {'patient_id': 56,
#   'age': 61,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-12'},
#  {'patient_id': 57,
#   'age': 29,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-22'},
#  {'patient_id': 58,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-22'},
#  {'patient_id': 59,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-11'},
#  {'patient_id': 60,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-04'},
#  {'patient_id': 61,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-28'},
#  {'patient_id': 62,
#   'age': 41,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-14'},
#  {'patient_id': 63,
#   'age': 25,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-27'},
#  {'patient_id': 64,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-04'},
#  {'patient_id': 65,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-13'},
#  {'patient_id': 66,
#   'age': 69,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-06'},
#  {'patient_id': 67,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-15'},
#  {'patient_id': 68,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-11'},
#  {'patient_id': 69,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-12'},
#  {'patient_id': 70,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-18'},
#  {'patient_id': 71,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-28'},
#  {'patient_id': 72,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-26'},
#  {'patient_id': 73,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-04'},
#  {'patient_id': 74,
#   'age': 73,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-02'},
#  {'patient_id': 75,
#   'age': 1,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-13'},
#  {'patient_id': 76,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-09'},
#  {'patient_id': 77,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-11'},
#  {'patient_id': 78,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-13'},
#  {'patient_id': 79,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-16'},
#  {'patient_id': 80,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-07'},
#  {'patient_id': 81,
#   'age': 41,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-14'},
#  {'patient_id': 82,
#   'age': 51,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-20'},
#  {'patient_id': 83,
#   'age': 71,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-16'},
#  {'patient_id': 84,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-26'},
#  {'patient_id': 85,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-11'},
#  {'patient_id': 86,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-28'},
#  {'patient_id': 87,
#   'age': 61,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-25'},
#  {'patient_id': 88,
#   'age': 50,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-27'},
#  {'patient_id': 89,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-30'},
#  {'patient_id': 90,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-01'},
#  {'patient_id': 91,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-27'},
#  {'patient_id': 92,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-28'},
#  {'patient_id': 93,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-31'},
#  {'patient_id': 94,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-23'},
#  {'patient_id': 95,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-20'},
#  {'patient_id': 96,
#   'age': 18,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-01'},
#  {'patient_id': 97,
#   'age': 50,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-10'},
#  {'patient_id': 98,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-30'},
#  {'patient_id': 99,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-15'},
#  {'patient_id': 100,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-14'},
#  {'patient_id': 101,
#   'age': 19,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-14'},
#  {'patient_id': 102,
#   'age': 37,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-11'},
#  {'patient_id': 103,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-12'},
#  {'patient_id': 104,
#   'age': 30,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-09'},
#  {'patient_id': 105,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-08'},
#  {'patient_id': 106,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-07'},
#  {'patient_id': 107,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-21'},
#  {'patient_id': 108,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-20'},
#  {'patient_id': 109,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-15'},
#  {'patient_id': 110,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-23'},
#  {'patient_id': 111,
#   'age': 10,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-22'},
#  {'patient_id': 112,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-31'},
#  {'patient_id': 113,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-28'},
#  {'patient_id': 114,
#   'age': 89,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-26'},
#  {'patient_id': 115,
#   'age': 41,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-15'},
#  {'patient_id': 116,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-14'},
#  {'patient_id': 117,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-09'},
#  {'patient_id': 118,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-23'},
#  {'patient_id': 119,
#   'age': 65,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-23'},
#  {'patient_id': 120,
#   'age': 58,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-19'},
#  {'patient_id': 121,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-01-30'},
#  {'patient_id': 122,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-28'},
#  {'patient_id': 123,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-13'},
#  {'patient_id': 124,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-13'},
#  {'patient_id': 125,
#   'age': 55,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-10'},
#  {'patient_id': 126,
#   'age': 84,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-19'},
#  {'patient_id': 127,
#   'age': 27,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-05'},
#  {'patient_id': 128,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-24'},
#  {'patient_id': 129,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-15'},
#  {'patient_id': 130,
#   'age': 35,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-30'},
#  {'patient_id': 131,
#   'age': 17,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-15'},
#  {'patient_id': 132,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-25'},
#  {'patient_id': 133,
#   'age': 25,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-14'},
#  {'patient_id': 134,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-05'},
#  {'patient_id': 135,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-01'},
#  {'patient_id': 136,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-11'},
#  {'patient_id': 137,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-27'},
#  {'patient_id': 138,
#   'age': 39,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-06'},
#  {'patient_id': 139,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-15'},
#  {'patient_id': 140,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-30'},
#  {'patient_id': 141,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-14'},
#  {'patient_id': 142,
#   'age': 68,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-18'},
#  {'patient_id': 143,
#   'age': 16,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-22'},
#  {'patient_id': 144,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-10'},
#  {'patient_id': 145,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-16'},
#  {'patient_id': 146,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-17'},
#  {'patient_id': 147,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-30'},
#  {'patient_id': 148,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-13'},
#  {'patient_id': 149,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-22'},
#  {'patient_id': 150,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-29'},
#  {'patient_id': 151,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-28'},
#  {'patient_id': 152,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-06'},
#  {'patient_id': 153,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-01'},
#  {'patient_id': 154,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-07'},
#  {'patient_id': 155,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-07'},
#  {'patient_id': 156,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-06'},
#  {'patient_id': 157,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-22'},
#  {'patient_id': 158,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-01-21'},
#  {'patient_id': 159,
#   'age': 23,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-05'},
#  {'patient_id': 160,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-25'},
#  {'patient_id': 161,
#   'age': 27,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-19'},
#  {'patient_id': 162,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-02'},
#  {'patient_id': 163,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-20'},
#  {'patient_id': 164,
#   'age': 30,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-07'},
#  {'patient_id': 165,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-03'},
#  {'patient_id': 166,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-29'},
#  {'patient_id': 167,
#   'age': 59,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 168,
#   'age': 79,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-11'},
#  {'patient_id': 169,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-11'},
#  {'patient_id': 170,
#   'age': 31,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 171,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-03'},
#  {'patient_id': 172,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-10'},
#  {'patient_id': 173,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-09'},
#  {'patient_id': 174,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-20'},
#  {'patient_id': 175,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-19'},
#  {'patient_id': 176,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-06'},
#  {'patient_id': 177,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-28'},
#  {'patient_id': 178,
#   'age': 71,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-23'},
#  {'patient_id': 179,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-28'},
#  {'patient_id': 180,
#   'age': 90,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-15'},
#  {'patient_id': 181,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-02'},
#  {'patient_id': 182,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-24'},
#  {'patient_id': 183,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-04'},
#  {'patient_id': 184,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-10'},
#  {'patient_id': 185,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-13'},
#  {'patient_id': 186,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-05'},
#  {'patient_id': 187,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-10'},
#  {'patient_id': 188,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-19'},
#  {'patient_id': 189,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-16'},
#  {'patient_id': 190,
#   'age': 17,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-07'},
#  {'patient_id': 191,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-02'},
#  {'patient_id': 192,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-03'},
#  {'patient_id': 193,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-17'},
#  {'patient_id': 194,
#   'age': 22,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-07'},
#  {'patient_id': 195,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-02'},
#  {'patient_id': 196,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 197,
#   'age': 29,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-15'},
#  {'patient_id': 198,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-17'},
#  {'patient_id': 199,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-04'},
#  {'patient_id': 200,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-17'},
#  {'patient_id': 201,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-01'},
#  {'patient_id': 202,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-12'},
#  {'patient_id': 203,
#   'age': 64,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-16'},
#  {'patient_id': 204,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-16'},
#  {'patient_id': 205,
#   'age': 20,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-10'},
#  {'patient_id': 206,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-15'},
#  {'patient_id': 207,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-13'},
#  {'patient_id': 208,
#   'age': 54,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-24'},
#  {'patient_id': 209,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-17'},
#  {'patient_id': 210,
#   'age': 90,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-02'},
#  {'patient_id': 211,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-27'},
#  {'patient_id': 212,
#   'age': 65,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 213,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-02'},
#  {'patient_id': 214,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-14'},
#  {'patient_id': 215,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-19'},
#  {'patient_id': 216,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-01'},
#  {'patient_id': 217,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-10'},
#  {'patient_id': 218,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-27'},
#  {'patient_id': 219,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-16'},
#  {'patient_id': 220,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-28'},
#  {'patient_id': 221,
#   'age': 86,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-13'},
#  {'patient_id': 222,
#   'age': 11,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-01'},
#  {'patient_id': 223,
#   'age': 57,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-20'},
#  {'patient_id': 224,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-09'},
#  {'patient_id': 225,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-20'},
#  {'patient_id': 226,
#   'age': 64,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-05'},
#  {'patient_id': 227,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-20'},
#  {'patient_id': 228,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-20'},
#  {'patient_id': 229,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-09'},
#  {'patient_id': 230,
#   'age': 57,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-14'},
#  {'patient_id': 231,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-24'},
#  {'patient_id': 232,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-07'},
#  {'patient_id': 233,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-04'},
#  {'patient_id': 234,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-17'},
#  {'patient_id': 235,
#   'age': 83,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-21'},
#  {'patient_id': 236,
#   'age': 56,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-15'},
#  {'patient_id': 237,
#   'age': 8,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-21'},
#  {'patient_id': 238,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-08'},
#  {'patient_id': 239,
#   'age': 33,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-11'},
#  {'patient_id': 240,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-26'},
#  {'patient_id': 241,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-02'},
#  {'patient_id': 242,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-25'},
#  {'patient_id': 243,
#   'age': 54,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-21'},
#  {'patient_id': 244,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-14'},
#  {'patient_id': 245,
#   'age': 23,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-08'},
#  {'patient_id': 246,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-12'},
#  {'patient_id': 247,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-26'},
#  {'patient_id': 248,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-08'},
#  {'patient_id': 249,
#   'age': 76,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-08'},
#  {'patient_id': 250,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-31'},
#  {'patient_id': 251,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-18'},
#  {'patient_id': 252,
#   'age': 61,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-16'},
#  {'patient_id': 253,
#   'age': 83,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-09'},
#  {'patient_id': 254,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-31'},
#  {'patient_id': 255,
#   'age': 17,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-27'},
#  {'patient_id': 256,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-22'},
#  {'patient_id': 257,
#   'age': 67,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-18'},
#  {'patient_id': 258,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-24'},
#  {'patient_id': 259,
#   'age': 52,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-18'},
#  {'patient_id': 260,
#   'age': 58,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-13'},
#  {'patient_id': 261,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-06'},
#  {'patient_id': 262,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-02'},
#  {'patient_id': 263,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-03'},
#  {'patient_id': 264,
#   'age': 26,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-08'},
#  {'patient_id': 265,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-28'},
#  {'patient_id': 266,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-12'},
#  {'patient_id': 267,
#   'age': 74,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-04'},
#  {'patient_id': 268,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-17'},
#  {'patient_id': 269,
#   'age': 37,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-28'},
#  {'patient_id': 270,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-03'},
#  {'patient_id': 271,
#   'age': 70,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-31'},
#  {'patient_id': 272,
#   'age': 19,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-10'},
#  {'patient_id': 273,
#   'age': 65,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-17'},
#  {'patient_id': 274,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-17'},
#  {'patient_id': 275,
#   'age': 27,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-31'},
#  {'patient_id': 276,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-15'},
#  {'patient_id': 277,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-13'},
#  {'patient_id': 278,
#   'age': 34,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-18'},
#  {'patient_id': 279,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-20'},
#  {'patient_id': 280,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-18'},
#  {'patient_id': 281,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-07'},
#  {'patient_id': 282,
#   'age': 56,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-07'},
#  {'patient_id': 283,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-17'},
#  {'patient_id': 284,
#   'age': 22,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-18'},
#  {'patient_id': 285,
#   'age': 83,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-13'},
#  {'patient_id': 286,
#   'age': 9,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-15'},
#  {'patient_id': 287,
#   'age': 42,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-13'},
# ...
#   'chronic_flag': 1,
#   'registration_date': '2025-05-17'},
#  {'patient_id': 906,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-25'},
#  {'patient_id': 907,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-03'},
#  {'patient_id': 908,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-26'},
#  {'patient_id': 909,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-13'},
#  {'patient_id': 910,
#   'age': 83,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-17'},
#  {'patient_id': 911,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-19'},
#  {'patient_id': 912,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-29'},
#  {'patient_id': 913,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-19'},
#  {'patient_id': 914,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-29'},
#  {'patient_id': 915,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-31'},
#  {'patient_id': 916,
#   'age': 50,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-13'},
#  {'patient_id': 917,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-12'},
#  {'patient_id': 918,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 919,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-21'},
#  {'patient_id': 920,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-27'},
#  {'patient_id': 921,
#   'age': 64,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-30'},
#  {'patient_id': 922,
#   'age': 26,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-13'},
#  {'patient_id': 923,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-22'},
#  {'patient_id': 924,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-30'},
#  {'patient_id': 925,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-22'},
#  {'patient_id': 926,
#   'age': 17,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-12'},
#  {'patient_id': 927,
#   'age': 34,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-16'},
#  {'patient_id': 928,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07'},
#  {'patient_id': 929,
#   'age': 73,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-10'},
#  {'patient_id': 930,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-14'},
#  {'patient_id': 931,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-06'},
#  {'patient_id': 932,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-13'},
#  {'patient_id': 933,
#   'age': 18,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-10'},
#  {'patient_id': 934,
#   'age': 5,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-12'},
#  {'patient_id': 935,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-23'},
#  {'patient_id': 936,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-10'},
#  {'patient_id': 937,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-19'},
#  {'patient_id': 938,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-27'},
#  {'patient_id': 939,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-27'},
#  {'patient_id': 940,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-11'},
#  {'patient_id': 941,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-02'},
#  {'patient_id': 942,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-05'},
#  {'patient_id': 943,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-09'},
#  {'patient_id': 944,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-30'},
#  {'patient_id': 945,
#   'age': 78,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-29'},
#  {'patient_id': 946,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-23'},
#  {'patient_id': 947,
#   'age': 17,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-16'},
#  {'patient_id': 948,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-09'},
#  {'patient_id': 949,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-30'},
#  {'patient_id': 950,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-13'},
#  {'patient_id': 951,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-25'},
#  {'patient_id': 952,
#   'age': 51,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-29'},
#  {'patient_id': 953,
#   'age': 22,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-25'},
#  {'patient_id': 954,
#   'age': 70,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-13'},
#  {'patient_id': 955,
#   'age': 43,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-10'},
#  {'patient_id': 956,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-31'},
#  {'patient_id': 957,
#   'age': 51,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-06'},
#  {'patient_id': 958,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-02'},
#  {'patient_id': 959,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-22'},
#  {'patient_id': 960,
#   'age': 53,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-11'},
#  {'patient_id': 961,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-20'},
#  {'patient_id': 962,
#   'age': 68,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-23'},
#  {'patient_id': 963,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-30'},
#  {'patient_id': 964,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-11'},
#  {'patient_id': 965,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-30'},
#  {'patient_id': 966,
#   'age': 70,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-03'},
#  {'patient_id': 967,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-13'},
#  {'patient_id': 968,
#   'age': 77,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-01'},
#  {'patient_id': 969,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-01'},
#  {'patient_id': 970,
#   'age': 19,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-07'},
#  {'patient_id': 971,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-15'},
#  {'patient_id': 972,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-24'},
#  {'patient_id': 973,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-15'},
#  {'patient_id': 974,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-19'},
#  {'patient_id': 975,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-14'},
#  {'patient_id': 976,
#   'age': 10,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-21'},
#  {'patient_id': 977,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-14'},
#  {'patient_id': 978,
#   'age': 1,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-16'},
#  {'patient_id': 979,
#   'age': 16,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-05'},
#  {'patient_id': 980,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-30'},
#  {'patient_id': 981,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-15'},
#  {'patient_id': 982,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-06'},
#  {'patient_id': 983,
#   'age': 27,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-02'},
#  {'patient_id': 984,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-14'},
#  {'patient_id': 985,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-20'},
#  {'patient_id': 986,
#   'age': 24,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-22'},
#  {'patient_id': 987,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-01-23'},
#  {'patient_id': 988,
#   'age': 60,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-10'},
#  {'patient_id': 989,
#   'age': 41,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-12'},
#  {'patient_id': 990,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-11'},
#  {'patient_id': 991,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-26'},
#  {'patient_id': 992,
#   'age': 8,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-17'},
#  {'patient_id': 993,
#   'age': 40,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-13'},
#  {'patient_id': 994,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-07'},
#  {'patient_id': 995,
#   'age': 26,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-13'},
#  {'patient_id': 996,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-24'},
#  {'patient_id': 997,
#   'age': 77,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-29'},
#  {'patient_id': 998,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-02'},
#  {'patient_id': 999,
#   'age': 34,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-02'},
#  {'patient_id': 1000,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-25'},
#  ...]

# %%
len(patient_data)
# Out:
# 5000

# %%
DB_NAME="hospital_miops"
COLLECTION_PATIENT="patient_data"
COLLECTION_VISITS="visits_data"
COLLECTION_BILLING="billing_data_data"
CONNECTION_URL="myurl"

# %%
import pymongo
import pandas as pd

# %%
client=pymongo.MongoClient(CONNECTION_URL)
db=client[DB_NAME]
patient_collection=db[COLLECTION_PATIENT]
visits_collection=db[COLLECTION_VISITS]
billing_collection=db[COLLECTION_BILLING]

patient_rec=patient_collection.insert_many(patient_data)
visits_rec=visits_collection.insert_many(visits_data)      
billing_rec=billing_collection.insert_many(billing_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       4 visits_collection=db[COLLECTION_VISITS]
#       5 billing_collection=db[COLLECTION_BILLING]
# ----> 7 patient_rec=patient_collection.insert_many(patient_data)
#       8 visits_rec=visits_collection.insert_many(visits_data)
#       9 billing_rec=billing_collection.insert_many(billing_data)
#
# NameError: name 'patient_data' is not defined

# %%
patient_df=pd.DataFrame(list(patient_collection.find()))
patient_df.head()
# Out:
#                         _id  patient_id  age gender       city  \
# 0  6a286bfbdb5bb3abac6f50b5           1   53      M  Hyderabad
# 1  6a286bfbdb5bb3abac6f50b6           2   42      M       Pune
# 2  6a286bfbdb5bb3abac6f50b7           3   56      F  Hyderabad
# 3  6a286bfbdb5bb3abac6f50b8           4   72      M    Chennai
# 4  6a286bfbdb5bb3abac6f50b9           5   40      F  Bangalore
#
#   insurance_provider  chronic_flag registration_date
# 0         SecureLife             0        2025-05-14
# 1         HealthPlus             0        2025-11-18
# 2         HealthPlus             0        2025-05-11
# 3         HealthPlus             0        2025-12-18
# 4            CareOne             1        2025-01-23

# %%
billing_df=pd.DataFrame(list(billing_collection.find()))
billing_df.head()
# Out:
#                         _id  bill_id  visit_id  billed_amount  \
# 0  6a286c11db5bb3abac6fc5e5        1         1       23577.37
# 1  6a286c11db5bb3abac6fc5e6        2         2       38178.81
# 2  6a286c11db5bb3abac6fc5e7        3         3        5038.97
# 3  6a286c11db5bb3abac6fc5e8        4         4       22813.34
# 4  6a286c11db5bb3abac6fc5e9        5         5       27106.95
#
#    approved_amount claim_status  payment_days billing_date
# 0             0.00     Rejected          16.0   2025-06-18
# 1         38178.81         Paid          18.0   2025-10-09
# 2          5038.97         Paid           NaN   2025-01-20
# 3         22813.34         Paid          16.0   2025-12-24
# 4         27106.95         Paid          14.0   2025-09-23

# %%
visits_df=pd.DataFrame(list(visits_collection.find()))
visits_df.head()
# Out:
#                         _id  visit_id  patient_id  visit_date   department  \
# 0  6a286c04db5bb3abac6f643d         1         756  2025-10-18   Cardiology
# 1  6a286c04db5bb3abac6f643e         2        4102  2025-04-06  Orthopedics
# 2  6a286c04db5bb3abac6f643f         3        2964  2025-07-13          ICU
# 3  6a286c04db5bb3abac6f6440         4        4496  2025-11-19   Cardiology
# 4  6a286c04db5bb3abac6f6441         5        1930  2025-03-29      General
#
#   visit_type  length_of_stay_hours risk_score  doctor_id
# 0         ER                  3.48        Low        169
# 1        OPD                 15.31       High        148
# 2         ER                 34.36        Low        153
# 3         ER                 37.89       High        119
# 4        ICU                 16.78     Medium        118

# %%
if"_id" in patient_df.columns:
    patient_df.drop("_id",axis=1,inplace=True)
if"_id" in billing_df.columns:
    billing_df.drop("_id",axis=1,inplace=True)
if"_id" in visits_df.columns:
    visits_df.drop("_id",axis=1,inplace=True)

# %%
visits_df.head()
# Out:
#    visit_id  patient_id  visit_date   department visit_type  \
# 0         1         756  2025-10-18   Cardiology         ER
# 1         2        4102  2025-04-06  Orthopedics        OPD
# 2         3        2964  2025-07-13          ICU         ER
# 3         4        4496  2025-11-19   Cardiology         ER
# 4         5        1930  2025-03-29      General        ICU
#
#    length_of_stay_hours risk_score  doctor_id
# 0                  3.48        Low        169
# 1                 15.31       High        148
# 2                 34.36        Low        153
# 3                 37.89       High        119
# 4                 16.78     Medium        118

# %%
# Create db folder, if it doesn't exits
import pandas as pd
import sqlite3
import os


os.makedirs("../db", exist_ok=True)

# Connect to sqlite and then create db
conn = sqlite3.connect("../db/hospital.db")
cursor = conn.cursor()
print("Database connected:", conn)
# Out:
# Database connected: <sqlite3.Connection object at 0x00000244AC8E3880>

# %%
billing = pd.read_csv("data/billing.csv")
visits = pd.read_csv("data/visits.csv")
patient = pd.read_csv("data/patients.csv")

print("patient shape :",patient.shape)
print("billing shape :",billing.shape)
print("visits shape :",visits.shape)
# write all three dataframes into sqlite tables
patient.to_sql("patients", conn, if_exists="replace", index=False)
visits.to_sql("visits", conn, if_exists="replace", index=False)
billing.to_sql("billing", conn, if_exists="replace", index=False)

print("All three tables loaded into hospital db")
# Out:
# patient shape : (5000, 7)
# billing shape : (25000, 7)
# visits shape : (25000, 8)
# All three tables loaded into hospital db

# %%
# Quick preview of tables
print("=== PATIENTS (first 3 rows) ===")
print(pd.read_sql("select * from patients limit 5", conn).to_string())

print("=== VISITS (first 3 rows) ===")
print(pd.read_sql("select * from visits limit 5", conn).to_string())

print("=== BILLING (first 3 rows) ===")
print(pd.read_sql("select * from billing limit 5", conn).to_string())
# Out:
# === PATIENTS (first 3 rows) ===
#    patient_id  age gender       city insurance_provider  chronic_flag registration_date
# 0           1   53      M  Hyderabad         SecureLife             0        2025-05-14
# 1           2   42      M       Pune         HealthPlus             0        2025-11-18
# 2           3   56      F  Hyderabad         HealthPlus             0        2025-05-11
# 3           4   72      M    Chennai         HealthPlus             0        2025-12-18
# 4           5   40      F  Bangalore            CareOne             1        2025-01-23
# === VISITS (first 3 rows) ===
#    visit_id  patient_id  visit_date   department visit_type  length_of_stay_hours risk_score  doctor_id
# 0         1         756  2025-10-18   Cardiology         ER                  3.48        Low        169
# 1         2        4102  2025-04-06  Orthopedics        OPD                 15.31       High        148
# 2         3        2964  2025-07-13          ICU         ER                 34.36        Low        153
# 3         4        4496  2025-11-19   Cardiology         ER                 37.89       High        119
# 4         5        1930  2025-03-29      General        ICU                 16.78     Medium        118
# === BILLING (first 3 rows) ===
#    bill_id  visit_id  billed_amount  approved_amount claim_status  payment_days billing_date
# 0        1         1       23577.37             0.00     Rejected          16.0   2025-06-18
# 1        2         2       38178.81         38178.81         Paid          18.0   2025-10-09
# 2        3         3        5038.97          5038.97         Paid           NaN   2025-01-20
# 3        4         4       22813.34         22813.34         Paid          16.0   2025-12-24
# 4        5         5       27106.95         27106.95         Paid          14.0   2025-09-23

# %% [markdown]
# ## Financial Analytics

# %%
#department workload analysis
query = """
SELECT department, COUNT(*) AS num_visits, 
ROUND(AVG(length_of_stay_hours),2) AS avg_stay_hours,
ROUND(MAX(length_of_stay_hours),2) AS max_stay_hours,
SUM(CASE
    WHEN risk_score = 'High'
    THEN 1
    ELSE 0
END) AS high_risk_count
FROM visits
GROUP BY department
order by num_visits DESC
"""
department_workload = pd.read_sql(query, conn)
print("Department Workload:")
print(department_workload.to_string(index=False))
# Out:
# Department Workload:
#  department  num_visits  avg_stay_hours  max_stay_hours  high_risk_count
#     General        4228           19.43           78.42              839
#          ER        4220           19.53           74.81              872
#   Neurology        4165           19.72           70.12              846
# Orthopedics        4164           19.66           71.60              842
#  Cardiology        4159           19.60           77.42              790
#         ICU        4064           19.36           72.47              845

# %%
#which doctor handled most critical patients
query = """
SELECT 
        doctor_id,
        COUNT(visit_id)                              AS total_visits,
        SUM(CASE WHEN risk_score = 'High' 
            THEN 1 ELSE 0 END)                       AS high_risk_cases,
        ROUND(
            100.0 * SUM(CASE WHEN risk_score = 'High' 
            THEN 1 ELSE 0 END) / COUNT(visit_id), 1) AS high_risk_pct
    FROM visits
    GROUP BY doctor_id
    ORDER BY high_risk_cases DESC
    LIMIT 10
"""
doctor_risk = pd.read_sql(query, conn)
print("Doctor Risk Analysis:")
print(doctor_risk.to_string(index=False))
# Out:
# Doctor Risk Analysis:
#  doctor_id  total_visits  high_risk_cases  high_risk_pct
#        174           264               71           26.9
#        198           252               69           27.4
#        169           279               68           24.4
#        177           266               67           25.2
#        135           261               65           24.9
#        105           250               65           26.0
#        188           285               64           22.5
#        180           290               64           22.1
#        131           266               62           23.3
#        178           245               61           24.9

# %%
#Patient Visit Patterns distribution
query = """
  SELECT 
        visit_frequency_bucket,
        COUNT(patient_id) AS num_patients
    FROM (
        SELECT 
            patient_id,
            COUNT(visit_id) AS visit_count,
            CASE 
                WHEN COUNT(visit_id) = 1     THEN '1 visit'
                WHEN COUNT(visit_id) BETWEEN 2 AND 3 THEN '2-3 visits'
                WHEN COUNT(visit_id) BETWEEN 4 AND 5 THEN '4-5 visits'
                ELSE '6+ visits'
            END AS visit_frequency_bucket
        FROM visits
        GROUP BY patient_id
    )
    GROUP BY visit_frequency_bucket
    ORDER BY num_patients DESC

"""
visit_patterns = pd.read_sql(query, conn)
print("Visit Patterns Analysis:")
print(visit_patterns.to_string(index=False))
# Out:
# Visit Patterns Analysis:
# visit_frequency_bucket  num_patients
#              6+ visits          1937
#             4-5 visits          1731
#             2-3 visits          1150
#                1 visit           149

# %%
# Risk Score Distribution
query = """
   SELECT 
        department,
        SUM(CASE WHEN risk_score = 'Low'    THEN 1 ELSE 0 END) AS low,
        SUM(CASE WHEN risk_score = 'Medium' THEN 1 ELSE 0 END) AS medium,
        SUM(CASE WHEN risk_score = 'High'   THEN 1 ELSE 0 END) AS high,
        COUNT(*) AS total
    FROM visits
    GROUP BY department
    ORDER BY high DESC

"""
risk_by_dept = pd.read_sql(query, conn)
print("Risk Score Distribution by Department:")
print(risk_by_dept.to_string(index=False))
# Out:
# Risk Score Distribution by Department:
#  department  low  medium  high  total
#          ER 2092    1256   872   4220
#   Neurology 2058    1261   846   4165
#         ICU 2037    1182   845   4064
# Orthopedics 2078    1244   842   4164
#     General 2123    1266   839   4228
#  Cardiology 2082    1287   790   4159

# %% [markdown]
# ## Financial Analytics

# %%
#  Revenue and claim outcomes by insurance provider
query = """
  SELECT 
        p.insurance_provider,
        COUNT(b.bill_id)                         AS total_claims,
        ROUND(SUM(b.billed_amount), 0)           AS total_billed,
        ROUND(AVG(b.billed_amount), 0)           AS avg_billed,
        ROUND(SUM(b.approved_amount), 0)         AS total_approved,
        SUM(CASE WHEN b.claim_status = 'Paid'     
            THEN 1 ELSE 0 END)                   AS paid,
        SUM(CASE WHEN b.claim_status = 'Pending'  
            THEN 1 ELSE 0 END)                   AS pending,
        SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END)                   AS rejected
    FROM billing b
    JOIN visits  v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    GROUP BY p.insurance_provider
    ORDER BY total_billed DESC

"""
insurance_billing = pd.read_sql(query, conn)
print("Risk Score Distribution by Department:")
print(insurance_billing.to_string(index=False))
# Out:
# Risk Score Distribution by Department:
# insurance_provider  total_claims  total_billed  avg_billed  total_approved  paid  pending  rejected
#          MediCareX          6532   134591163.0     20605.0     100135469.0  3875     1661       996
#            CareOne          6283   130707993.0     20803.0      96997758.0  3787     1562       934
#         HealthPlus          6220   130180741.0     20929.0      96251775.0  3680     1609       931
#         SecureLife          5965   126289040.0     21172.0      93770886.0  3598     1431       936

# %%
# Which insurance providers reject the most claims?
query = """
 SELECT 
        p.insurance_provider,
        COUNT(b.bill_id)                              AS total_claims,
        SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END)                        AS rejected_claims,
        ROUND(
            100.0 * SUM(CASE WHEN b.claim_status = 'Rejected' 
            THEN 1 ELSE 0 END) / COUNT(b.bill_id), 1) AS rejection_rate_pct
    FROM billing b
    JOIN visits   v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    GROUP BY p.insurance_provider
    ORDER BY rejection_rate_pct DESC

"""
rejection_analysis = pd.read_sql(query, conn)
print("Claim Rejection Analysis by Insurance Provider:")
print(rejection_analysis.to_string(index=False))
# Out:
# Claim Rejection Analysis by Insurance Provider:
# insurance_provider  total_claims  rejected_claims  rejection_rate_pct
#         SecureLife          5965              936                15.7
#          MediCareX          6532              996                15.2
#         HealthPlus          6220              931                15.0
#            CareOne          6283              934                14.9

# %%
#How much of what we bill actually gets approved
query = """
    SELECT 
        p.insurance_provider,
        ROUND(SUM(b.billed_amount), 0)                AS total_billed,
        ROUND(SUM(b.approved_amount), 0)              AS total_approved,
        ROUND(
            100.0 * SUM(b.approved_amount) / 
            SUM(b.billed_amount), 1)                  AS realization_rate_pct
    FROM billing b
    JOIN visits   v ON b.visit_id   = v.visit_id
    JOIN patients p ON v.patient_id = p.patient_id
    WHERE b.approved_amount IS NOT NULL
    GROUP BY p.insurance_provider
    ORDER BY realization_rate_pct DESC

"""
revenue_realization = pd.read_sql(query, conn)
print("Revenue Realization Analysis by Insurance Provider:")
print(revenue_realization.to_string(index=False))
# Out:
# Revenue Realization Analysis by Insurance Provider:
# insurance_provider  total_billed  total_approved  realization_rate_pct
#            CareOne   123701662.0      96997758.0                  78.4
#         HealthPlus   122873457.0      96251775.0                  78.3
#          MediCareX   128114983.0     100135469.0                  78.2
#         SecureLife   120079039.0      93770886.0                  78.1

# %% [markdown]
# ## Data Quality

# %%
# Missing Records Check
print("=== MISSING VALUES CHECK ===\n")

for table in ['patients', 'visits', 'billing']:
    df = pd.read_sql(f"SELECT * FROM {table}", conn)
    nulls = df.isnull().sum()
    nulls = nulls[nulls > 0]
    if len(nulls) > 0:
        print(f"{table}:")
        print(nulls.to_string())
        print()
    else:
        print(f"{table}: ✓ No missing values\n")
# Out:
# === MISSING VALUES CHECK ===
#
# patients: ✓ No missing values
#
# visits: ✓ No missing values
#
# billing:
# approved_amount    1318
# payment_days        790

# %%
# Duplicate Patients Check
duplicate_patients = pd.read_sql("""
    SELECT 
        patient_id,
        COUNT(*) AS occurrences
    FROM patients
    GROUP BY patient_id
    HAVING COUNT(*) > 1
""", conn)

if len(duplicate_patients) == 0:
    print("✓ No duplicate patient_ids found")
else:
    print(f"⚠ Found {len(duplicate_patients)} duplicate patient_ids")
    print(duplicate_patients)
# Out:
# ✓ No duplicate patient_ids found

# %%
# Orphan Records Check
# Visits without matching patients
orphan_visits = pd.read_sql("""
    SELECT COUNT(*) AS orphan_visits
    FROM visits v
    LEFT JOIN patients p ON v.patient_id = p.patient_id
    WHERE p.patient_id IS NULL
""", conn)

# Billing without matching visits
orphan_billing = pd.read_sql("""
    SELECT COUNT(*) AS orphan_billing
    FROM billing b
    LEFT JOIN visits v ON b.visit_id = v.visit_id
    WHERE v.visit_id IS NULL
""", conn)

print("Orphan visits  (no matching patient):", 
      orphan_visits['orphan_visits'][0])
print("Orphan billing (no matching visit)  :", 
      orphan_billing['orphan_billing'][0])
# Out:
# Orphan visits  (no matching patient): 0
# Orphan billing (no matching visit)  : 0

# %%
#Invalid LOS Check
invalid_los = pd.read_sql("""
    SELECT 
        COUNT(CASE WHEN length_of_stay_hours <= 0  THEN 1 END) AS zero_or_negative,
        COUNT(CASE WHEN length_of_stay_hours > 720 THEN 1 END) AS over_30_days,
        MIN(length_of_stay_hours)                              AS min_los,
        MAX(length_of_stay_hours)                             AS max_los,
        ROUND(AVG(length_of_stay_hours), 2)                   AS avg_los
    FROM visits
""", conn)

print("LOS Validation:")
print(invalid_los.to_string(index=False))
# Out:
# LOS Validation:
#  zero_or_negative  over_30_days  min_los  max_los  avg_los
#                 0             0      0.5    78.42    19.55

# %%
# Invalid Payment Days Check
invalid_payment = pd.read_sql("""
    SELECT 
        COUNT(CASE WHEN payment_days < 0   THEN 1 END) AS negative_days,
        COUNT(CASE WHEN payment_days > 365 THEN 1 END) AS over_1_year,
        COUNT(CASE WHEN payment_days IS NULL THEN 1 END) AS nulls,
        MIN(payment_days)                               AS min_days,
        MAX(payment_days)                               AS max_days
    FROM billing
""", conn)

print("Payment Days Validation:")
print(invalid_payment.to_string(index=False))
# Out:
# Payment Days Validation:
#  negative_days  over_1_year  nulls  min_days  max_days
#              0            0    790       1.0      55.0

# %%
# Join all three tables into one flat table for ML modeling.
# This is the single source of truth for Phase 2 EDA and Phase 3 Modeling.
model_table = pd.read_sql("""
    SELECT
        -- Patient features
        p.patient_id,
        p.age,
        p.gender,
        p.city,
        p.insurance_provider,
        p.chronic_flag,
        p.registration_date,

        -- Visit features
        v.visit_id,
        v.visit_date,
        v.department,
        v.visit_type,
        v.length_of_stay_hours,
        v.risk_score,
        v.doctor_id,

        -- Billing features
        b.bill_id,
        b.billed_amount,
        b.approved_amount,
        b.claim_status,
        b.payment_days,
        b.billing_date

    FROM visits v
    JOIN patients p ON v.patient_id = p.patient_id
    JOIN billing  b ON v.visit_id   = b.visit_id
    ORDER BY v.visit_date
""", conn)

print("model_table shape:", model_table.shape)
print("Columns:", model_table.columns.tolist())
model_table.head(3)
# Out:
# model_table shape: (25000, 20)
# Columns: ['patient_id', 'age', 'gender', 'city', 'insurance_provider', 'chronic_flag', 'registration_date', 'visit_id', 'visit_date', 'department', 'visit_type', 'length_of_stay_hours', 'risk_score', 'doctor_id', 'bill_id', 'billed_amount', 'approved_amount', 'claim_status', 'payment_days', 'billing_date']
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0        3993    9      M  Hyderabad         HealthPlus             1
# 1          76   59      M      Delhi         HealthPlus             0
# 2        3393   43      M  Hyderabad         HealthPlus             0
#
#   registration_date  visit_id  visit_date department visit_type  \
# 0        2025-10-18       684  2025-01-20    General        ICU
# 1        2025-07-09      1412  2025-01-20    General         ER
# 2        2025-07-10      1510  2025-01-20        ICU        ICU
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                  5.79        Low        137      684       36721.68
# 1                 34.80     Medium        109     1412        8365.47
# 2                 31.37     Medium        135     1510       16529.35
#
#    approved_amount claim_status  payment_days billing_date
# 0         36721.68         Paid          19.0   2025-08-15
# 1          4189.20      Pending          26.0   2025-11-14
# 2             0.00     Rejected           7.0   2025-04-24

# %%
# save the table
import os
os.makedirs("../outputs", exist_ok=True)
model_table.to_csv("../outputs/model_table.csv", index=False)
print(f"model_table.csv saved --> /outputs/model_table.csv")
print(f"Shape: {model_table.shape}")
print(f"Size: {os.path.getsize('../outputs/model_table.csv')/1024:.1f} KB")
# Out:
# model_table.csv saved --> /outputs/model_table.csv
# Shape: (25000, 20)
# Size: 3126.7 KB

# %%
model_table= pd.read_csv("../outputs/model_table.csv")
model_table.head()
# Out:
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0        3993    9      M  Hyderabad         HealthPlus             1
# 1          76   59      M      Delhi         HealthPlus             0
# 2        3393   43      M  Hyderabad         HealthPlus             0
# 3        1998   29      M  Bangalore          MediCareX             1
# 4        3500   38      M  Hyderabad            CareOne             1
#
#   registration_date  visit_id  visit_date   department visit_type  \
# 0        2025-10-18       684  2025-01-20      General        ICU
# 1        2025-07-09      1412  2025-01-20      General         ER
# 2        2025-07-10      1510  2025-01-20          ICU        ICU
# 3        2025-04-22      1549  2025-01-20   Cardiology         ER
# 4        2025-08-02      2275  2025-01-20  Orthopedics        ICU
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                  5.79        Low        137      684       36721.68
# 1                 34.80     Medium        109     1412        8365.47
# 2                 31.37     Medium        135     1510       16529.35
# 3                 20.88     Medium        179     1549       61827.63
# 4                  4.97        Low        107     2275        5860.51
#
#    approved_amount claim_status  payment_days billing_date
# 0         36721.68         Paid          19.0   2025-08-15
# 1          4189.20      Pending          26.0   2025-11-14
# 2             0.00     Rejected           7.0   2025-04-24
# 3         61827.63         Paid           1.0   2025-10-17
# 4          4897.65      Pending          28.0   2025-08-05

# %%
model_table_df= model_table.to_dict(orient="records")
model_table_df
# Out:
# [{'patient_id': 3993,
#   'age': 9,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-18',
#   'visit_id': 684,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 5.79,
#   'risk_score': 'Low',
#   'doctor_id': 137,
#   'bill_id': 684,
#   'billed_amount': 36721.68,
#   'approved_amount': 36721.68,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-08-15'},
#  {'patient_id': 76,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-09',
#   'visit_id': 1412,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 34.8,
#   'risk_score': 'Medium',
#   'doctor_id': 109,
#   'bill_id': 1412,
#   'billed_amount': 8365.47,
#   'approved_amount': 4189.2,
#   'claim_status': 'Pending',
#   'payment_days': 26.0,
#   'billing_date': '2025-11-14'},
#  {'patient_id': 3393,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-10',
#   'visit_id': 1510,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 31.37,
#   'risk_score': 'Medium',
#   'doctor_id': 135,
#   'bill_id': 1510,
#   'billed_amount': 16529.35,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 7.0,
#   'billing_date': '2025-04-24'},
#  {'patient_id': 1998,
#   'age': 29,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-22',
#   'visit_id': 1549,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.88,
#   'risk_score': 'Medium',
#   'doctor_id': 179,
#   'bill_id': 1549,
#   'billed_amount': 61827.63,
#   'approved_amount': 61827.63,
#   'claim_status': 'Paid',
#   'payment_days': 1.0,
#   'billing_date': '2025-10-17'},
#  {'patient_id': 3500,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-02',
#   'visit_id': 2275,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 4.97,
#   'risk_score': 'Low',
#   'doctor_id': 107,
#   'bill_id': 2275,
#   'billed_amount': 5860.51,
#   'approved_amount': 4897.65,
#   'claim_status': 'Pending',
#   'payment_days': 28.0,
#   'billing_date': '2025-08-05'},
#  {'patient_id': 3286,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-01-21',
#   'visit_id': 2287,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.13,
#   'risk_score': 'High',
#   'doctor_id': 165,
#   'bill_id': 2287,
#   'billed_amount': 18756.25,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-12-30'},
#  {'patient_id': 152,
#   'age': 51,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-06',
#   'visit_id': 3141,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.36,
#   'risk_score': 'Medium',
#   'doctor_id': 160,
#   'bill_id': 3141,
#   'billed_amount': 16289.04,
#   'approved_amount': 16289.04,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-11-29'},
#  {'patient_id': 532,
#   'age': 15,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-14',
#   'visit_id': 3704,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 2.04,
#   'risk_score': 'Medium',
#   'doctor_id': 190,
#   'bill_id': 3704,
#   'billed_amount': 31393.59,
#   'approved_amount': 31393.59,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-11-28'},
#  {'patient_id': 4451,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-13',
#   'visit_id': 3955,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.87,
#   'risk_score': 'Low',
#   'doctor_id': 166,
#   'bill_id': 3955,
#   'billed_amount': 27956.09,
#   'approved_amount': 23012.97,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-05-01'},
#  {'patient_id': 2826,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-08',
#   'visit_id': 4288,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 26.92,
#   'risk_score': 'Low',
#   'doctor_id': 162,
#   'bill_id': 4288,
#   'billed_amount': 15857.69,
#   'approved_amount': 12440.45,
#   'claim_status': 'Pending',
#   'payment_days': 21.0,
#   'billing_date': '2025-09-10'},
#  {'patient_id': 128,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-24',
#   'visit_id': 4866,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.72,
#   'risk_score': 'Low',
#   'doctor_id': 126,
#   'bill_id': 4866,
#   'billed_amount': 3483.79,
#   'approved_amount': 3483.79,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-09-28'},
#  {'patient_id': 3393,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-10',
#   'visit_id': 4949,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.9,
#   'risk_score': 'Medium',
#   'doctor_id': 177,
#   'bill_id': 4949,
#   'billed_amount': 18254.46,
#   'approved_amount': 18254.46,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 2072,
#   'age': 67,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-06',
#   'visit_id': 5095,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.26,
#   'risk_score': 'Low',
#   'doctor_id': 145,
#   'bill_id': 5095,
#   'billed_amount': 16683.54,
#   'approved_amount': 16683.54,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-02-11'},
#  {'patient_id': 586,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-25',
#   'visit_id': 5128,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 18.74,
#   'risk_score': 'High',
#   'doctor_id': 146,
#   'bill_id': 5128,
#   'billed_amount': 21522.01,
#   'approved_amount': 21522.01,
#   'claim_status': 'Paid',
#   'payment_days': 26.0,
#   'billing_date': '2025-05-03'},
#  {'patient_id': 665,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-24',
#   'visit_id': 5204,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.06,
#   'risk_score': 'Low',
#   'doctor_id': 183,
#   'bill_id': 5204,
#   'billed_amount': 28610.16,
#   'approved_amount': 15749.91,
#   'claim_status': 'Pending',
#   'payment_days': 9.0,
#   'billing_date': '2025-09-28'},
#  {'patient_id': 4599,
#   'age': 52,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-25',
#   'visit_id': 5557,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 23.92,
#   'risk_score': 'High',
#   'doctor_id': 156,
#   'bill_id': 5557,
#   'billed_amount': 25348.28,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-08-04'},
#  {'patient_id': 2027,
#   'age': 77,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-03',
#   'visit_id': 5914,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.51,
#   'risk_score': 'High',
#   'doctor_id': 124,
#   'bill_id': 5914,
#   'billed_amount': 28166.5,
#   'approved_amount': 22953.54,
#   'claim_status': 'Pending',
#   'payment_days': 5.0,
#   'billing_date': '2025-03-06'},
#  {'patient_id': 109,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-15',
#   'visit_id': 5959,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 35.18,
#   'risk_score': 'Low',
#   'doctor_id': 188,
#   'bill_id': 5959,
#   'billed_amount': 12399.88,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 19.0,
#   'billing_date': '2025-10-21'},
#  {'patient_id': 4068,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-27',
#   'visit_id': 6263,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.27,
#   'risk_score': 'High',
#   'doctor_id': 121,
#   'bill_id': 6263,
#   'billed_amount': 29260.99,
#   'approved_amount': 29260.99,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-08-10'},
#  {'patient_id': 4946,
#   'age': 63,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-12',
#   'visit_id': 6402,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 25.62,
#   'risk_score': 'Medium',
#   'doctor_id': 155,
#   'bill_id': 6402,
#   'billed_amount': 58503.2,
#   'approved_amount': 58503.2,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-09-26'},
#  {'patient_id': 3933,
#   'age': 60,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-29',
#   'visit_id': 6414,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.13,
#   'risk_score': 'Low',
#   'doctor_id': 168,
#   'bill_id': 6414,
#   'billed_amount': 33789.5,
#   'approved_amount': 33789.5,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-05-03'},
#  {'patient_id': 3411,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-03',
#   'visit_id': 6442,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 15.21,
#   'risk_score': 'Medium',
#   'doctor_id': 133,
#   'bill_id': 6442,
#   'billed_amount': 3267.59,
#   'approved_amount': 2016.13,
#   'claim_status': 'Pending',
#   'payment_days': 29.0,
#   'billing_date': '2025-06-17'},
#  {'patient_id': 495,
#   'age': 72,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-19',
#   'visit_id': 6506,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 13.42,
#   'risk_score': 'Low',
#   'doctor_id': 121,
#   'bill_id': 6506,
#   'billed_amount': 15048.62,
#   'approved_amount': 15048.62,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-09-20'},
#  {'patient_id': 3068,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-06',
#   'visit_id': 6618,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.1,
#   'risk_score': 'Low',
#   'doctor_id': 144,
#   'bill_id': 6618,
#   'billed_amount': 37014.63,
#   'approved_amount': 37014.63,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2026-01-13'},
#  {'patient_id': 2673,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-24',
#   'visit_id': 6783,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.8,
#   'risk_score': 'Medium',
#   'doctor_id': 113,
#   'bill_id': 6783,
#   'billed_amount': 22955.11,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 16.0,
#   'billing_date': '2025-04-19'},
#  {'patient_id': 4808,
#   'age': 56,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-24',
#   'visit_id': 7033,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.91,
#   'risk_score': 'Low',
#   'doctor_id': 141,
#   'bill_id': 7033,
#   'billed_amount': 28009.75,
#   'approved_amount': 28009.75,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-10-17'},
#  {'patient_id': 1264,
#   'age': 28,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-14',
#   'visit_id': 7308,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 44.32,
#   'risk_score': 'Medium',
#   'doctor_id': 178,
#   'bill_id': 7308,
#   'billed_amount': 3369.28,
#   'approved_amount': 3369.28,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-12-28'},
#  {'patient_id': 3919,
#   'age': 62,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-04',
#   'visit_id': 7471,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 11.46,
#   'risk_score': 'Low',
#   'doctor_id': 181,
#   'bill_id': 7471,
#   'billed_amount': 7980.21,
#   'approved_amount': 7980.21,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-12-24'},
#  {'patient_id': 93,
#   'age': 32,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-31',
#   'visit_id': 7472,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 35.83,
#   'risk_score': 'Medium',
#   'doctor_id': 182,
#   'bill_id': 7472,
#   'billed_amount': 28415.72,
#   'approved_amount': 28415.72,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-10-26'},
#  {'patient_id': 1079,
#   'age': 72,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-09',
#   'visit_id': 8790,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 1.07,
#   'risk_score': 'Medium',
#   'doctor_id': 122,
#   'bill_id': 8790,
#   'billed_amount': 7348.37,
#   'approved_amount': 4877.41,
#   'claim_status': 'Pending',
#   'payment_days': 16.0,
#   'billing_date': '2025-06-25'},
#  {'patient_id': 2294,
#   'age': 30,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-17',
#   'visit_id': 9687,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.75,
#   'risk_score': 'High',
#   'doctor_id': 118,
#   'bill_id': 9687,
#   'billed_amount': 19760.98,
#   'approved_amount': 19760.98,
#   'claim_status': 'Paid',
#   'payment_days': 2.0,
#   'billing_date': '2025-08-06'},
#  {'patient_id': 4887,
#   'age': 31,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-01',
#   'visit_id': 9727,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 3.47,
#   'risk_score': 'Low',
#   'doctor_id': 160,
#   'bill_id': 9727,
#   'billed_amount': 15948.64,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 2.0,
#   'billing_date': '2025-12-21'},
#  {'patient_id': 3854,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-25',
#   'visit_id': 10392,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.37,
#   'risk_score': 'Medium',
#   'doctor_id': 170,
#   'bill_id': 10392,
#   'billed_amount': 21477.41,
#   'approved_amount': 21477.41,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-06-02'},
#  {'patient_id': 737,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-10',
#   'visit_id': 10517,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.4,
#   'risk_score': 'Low',
#   'doctor_id': 171,
#   'bill_id': 10517,
#   'billed_amount': 18237.68,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 29.0,
#   'billing_date': '2025-08-08'},
#  {'patient_id': 90,
#   'age': 54,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2026-01-01',
#   'visit_id': 10582,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.48,
#   'risk_score': 'Low',
#   'doctor_id': 165,
#   'bill_id': 10582,
#   'billed_amount': 20042.27,
#   'approved_amount': 20042.27,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-04-21'},
#  {'patient_id': 2046,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-21',
#   'visit_id': 12232,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 38.42,
#   'risk_score': 'High',
#   'doctor_id': 115,
#   'bill_id': 12232,
#   'billed_amount': 19729.38,
#   'approved_amount': 19729.38,
#   'claim_status': 'Paid',
#   'payment_days': 4.0,
#   'billing_date': '2025-04-26'},
#  {'patient_id': 1266,
#   'age': 19,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-15',
#   'visit_id': 12551,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 36.39,
#   'risk_score': 'High',
#   'doctor_id': 158,
#   'bill_id': 12551,
#   'billed_amount': 6774.33,
#   'approved_amount': 6774.33,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-02-25'},
#  {'patient_id': 2744,
#   'age': 55,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-10',
#   'visit_id': 13142,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 2.2,
#   'risk_score': 'Medium',
#   'doctor_id': 159,
#   'bill_id': 13142,
#   'billed_amount': 23394.16,
#   'approved_amount': 13061.8,
#   'claim_status': 'Pending',
#   'payment_days': 4.0,
#   'billing_date': '2025-04-05'},
#  {'patient_id': 2071,
#   'age': 62,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-26',
#   'visit_id': 13251,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 24.71,
#   'risk_score': 'Low',
#   'doctor_id': 135,
#   'bill_id': 13251,
#   'billed_amount': 6907.14,
#   'approved_amount': 6907.14,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-05-11'},
#  {'patient_id': 2433,
#   'age': 44,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-12',
#   'visit_id': 13472,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 15.59,
#   'risk_score': 'Medium',
#   'doctor_id': 136,
#   'bill_id': 13472,
#   'billed_amount': 18385.76,
#   'approved_amount': 18385.76,
#   'claim_status': 'Paid',
#   'payment_days': 18.0,
#   'billing_date': '2025-07-22'},
#  {'patient_id': 1390,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-09',
#   'visit_id': 13590,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.19,
#   'risk_score': 'Low',
#   'doctor_id': 132,
#   'bill_id': 13590,
#   'billed_amount': 12534.18,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-12-28'},
#  {'patient_id': 3354,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-24',
#   'visit_id': 13844,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.36,
#   'risk_score': 'Low',
#   'doctor_id': 162,
#   'bill_id': 13844,
#   'billed_amount': 8496.78,
#   'approved_amount': 6137.37,
#   'claim_status': 'Pending',
#   'payment_days': 15.0,
#   'billing_date': '2025-10-07'},
#  {'patient_id': 2501,
#   'age': 55,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-19',
#   'visit_id': 13906,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 20.88,
#   'risk_score': 'Low',
#   'doctor_id': 104,
#   'bill_id': 13906,
#   'billed_amount': 5594.65,
#   'approved_amount': 5594.65,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-17'},
#  {'patient_id': 2085,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-29',
#   'visit_id': 14089,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.06,
#   'risk_score': 'Low',
#   'doctor_id': 121,
#   'bill_id': 14089,
#   'billed_amount': 12365.56,
#   'approved_amount': 12365.56,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-07-01'},
#  {'patient_id': 3757,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-04',
#   'visit_id': 14471,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 48.12,
#   'risk_score': 'Medium',
#   'doctor_id': 193,
#   'bill_id': 14471,
#   'billed_amount': 35791.14,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-09-28'},
#  {'patient_id': 3472,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-14',
#   'visit_id': 14589,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 28.83,
#   'risk_score': 'Low',
#   'doctor_id': 102,
#   'bill_id': 14589,
#   'billed_amount': 32715.8,
#   'approved_amount': 32715.8,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-27'},
#  {'patient_id': 3734,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-24',
#   'visit_id': 15397,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 17.36,
#   'risk_score': 'Low',
#   'doctor_id': 166,
#   'bill_id': 15397,
#   'billed_amount': 15867.7,
#   'approved_amount': 9990.43,
#   'claim_status': 'Pending',
#   'payment_days': 23.0,
#   'billing_date': '2025-04-16'},
#  {'patient_id': 2526,
#   'age': 53,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-12',
#   'visit_id': 15857,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 16.4,
#   'risk_score': 'High',
#   'doctor_id': 104,
#   'bill_id': 15857,
#   'billed_amount': 30743.59,
#   'approved_amount': 27231.2,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2025-02-14'},
#  {'patient_id': 3205,
#   'age': 27,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-28',
#   'visit_id': 15867,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 31.27,
#   'risk_score': 'High',
#   'doctor_id': 114,
#   'bill_id': 15867,
#   'billed_amount': 45066.28,
#   'approved_amount': 29819.51,
#   'claim_status': 'Pending',
#   'payment_days': 12.0,
#   'billing_date': '2025-06-30'},
#  {'patient_id': 2400,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-08',
#   'visit_id': 16565,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.94,
#   'risk_score': 'High',
#   'doctor_id': 116,
#   'bill_id': 16565,
#   'billed_amount': 8821.75,
#   'approved_amount': 8821.75,
#   'claim_status': 'Paid',
#   'payment_days': 5.0,
#   'billing_date': '2025-07-16'},
#  {'patient_id': 656,
#   'age': 46,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-05',
#   'visit_id': 16677,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.15,
#   'risk_score': 'Low',
#   'doctor_id': 156,
#   'bill_id': 16677,
#   'billed_amount': 15041.79,
#   'approved_amount': 11023.65,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-05-29'},
#  {'patient_id': 629,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-11',
#   'visit_id': 16881,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.46,
#   'risk_score': 'Low',
#   'doctor_id': 145,
#   'bill_id': 16881,
#   'billed_amount': 15317.82,
#   'approved_amount': 8099.25,
#   'claim_status': 'Pending',
#   'payment_days': 14.0,
#   'billing_date': '2025-04-25'},
#  {'patient_id': 2500,
#   'age': 51,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-01',
#   'visit_id': 18179,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 24.03,
#   'risk_score': 'Low',
#   'doctor_id': 150,
#   'bill_id': 18179,
#   'billed_amount': 34796.68,
#   'approved_amount': 34796.68,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-02-12'},
#  {'patient_id': 654,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-02',
#   'visit_id': 18353,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 10.25,
#   'risk_score': 'Low',
#   'doctor_id': 106,
#   'bill_id': 18353,
#   'billed_amount': 10932.55,
#   'approved_amount': 10932.55,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-09-19'},
#  {'patient_id': 4573,
#   'age': 59,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-16',
#   'visit_id': 18435,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 28.25,
#   'risk_score': 'Low',
#   'doctor_id': 114,
#   'bill_id': 18435,
#   'billed_amount': 32625.98,
#   'approved_amount': 32625.98,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-06-28'},
#  {'patient_id': 4397,
#   'age': 28,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-04',
#   'visit_id': 18759,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.88,
#   'risk_score': 'Low',
#   'doctor_id': 103,
#   'bill_id': 18759,
#   'billed_amount': 6273.46,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-02-12'},
#  {'patient_id': 2440,
#   'age': 16,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-13',
#   'visit_id': 19088,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.01,
#   'risk_score': 'Low',
#   'doctor_id': 175,
#   'bill_id': 19088,
#   'billed_amount': 8397.82,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-12-27'},
#  {'patient_id': 1829,
#   'age': 43,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-15',
#   'visit_id': 19260,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 8.04,
#   'risk_score': 'Low',
#   'doctor_id': 116,
#   'bill_id': 19260,
#   'billed_amount': 23377.53,
#   'approved_amount': 16939.77,
#   'claim_status': 'Pending',
#   'payment_days': 24.0,
#   'billing_date': '2025-09-16'},
#  {'patient_id': 493,
#   'age': 46,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-07',
#   'visit_id': 19504,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 18.44,
#   'risk_score': 'Low',
#   'doctor_id': 144,
#   'bill_id': 19504,
#   'billed_amount': 20313.48,
#   'approved_amount': 20313.48,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-05-06'},
#  {'patient_id': 4248,
#   'age': 84,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-24',
#   'visit_id': 19632,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 5.07,
#   'risk_score': 'Medium',
#   'doctor_id': 161,
#   'bill_id': 19632,
#   'billed_amount': 1094.19,
#   'approved_amount': 1094.19,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-09-02'},
#  {'patient_id': 247,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-26',
#   'visit_id': 19702,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 1.0,
#   'risk_score': 'Medium',
#   'doctor_id': 155,
#   'bill_id': 19702,
#   'billed_amount': 42934.71,
#   'approved_amount': 42934.71,
#   'claim_status': 'Paid',
#   'payment_days': 15.0,
#   'billing_date': '2025-01-26'},
#  {'patient_id': 1969,
#   'age': 41,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-04',
#   'visit_id': 19815,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.12,
#   'risk_score': 'Low',
#   'doctor_id': 195,
#   'bill_id': 19815,
#   'billed_amount': 43479.21,
#   'approved_amount': 43479.21,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-09-12'},
#  {'patient_id': 3486,
#   'age': 35,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-14',
#   'visit_id': 21401,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 33.11,
#   'risk_score': 'Medium',
#   'doctor_id': 121,
#   'bill_id': 21401,
#   'billed_amount': 6898.51,
#   'approved_amount': 6898.51,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-09-18'},
#  {'patient_id': 1721,
#   'age': 54,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-01',
#   'visit_id': 21420,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 2.36,
#   'risk_score': 'High',
#   'doctor_id': 149,
#   'bill_id': 21420,
#   'billed_amount': 29425.75,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 1.0,
#   'billing_date': '2025-04-28'},
#  {'patient_id': 1549,
#   'age': 58,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-13',
#   'visit_id': 21687,
#   'visit_date': '2025-01-20',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.49,
#   'risk_score': 'Medium',
#   'doctor_id': 145,
#   'bill_id': 21687,
#   'billed_amount': 25607.61,
#   'approved_amount': 16108.89,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-04-23'},
#  {'patient_id': 582,
#   'age': 37,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-12-21',
#   'visit_id': 22772,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 1.97,
#   'risk_score': 'High',
#   'doctor_id': 174,
#   'bill_id': 22772,
#   'billed_amount': 8118.8,
#   'approved_amount': 8118.8,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-06-04'},
#  {'patient_id': 1431,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-30',
#   'visit_id': 23174,
#   'visit_date': '2025-01-20',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.69,
#   'risk_score': 'Low',
#   'doctor_id': 141,
#   'bill_id': 23174,
#   'billed_amount': 8450.19,
#   'approved_amount': 8450.19,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-04-12'},
#  {'patient_id': 2065,
#   'age': 49,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-09',
#   'visit_id': 23479,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 17.04,
#   'risk_score': 'Low',
#   'doctor_id': 144,
#   'bill_id': 23479,
#   'billed_amount': 24893.47,
#   'approved_amount': 18464.22,
#   'claim_status': 'Pending',
#   'payment_days': nan,
#   'billing_date': '2025-06-13'},
#  {'patient_id': 1176,
#   'age': 39,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-13',
#   'visit_id': 23661,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.38,
#   'risk_score': 'Low',
#   'doctor_id': 102,
#   'bill_id': 23661,
#   'billed_amount': 21488.7,
#   'approved_amount': 13295.43,
#   'claim_status': 'Pending',
#   'payment_days': 16.0,
#   'billing_date': '2025-12-19'},
#  {'patient_id': 2493,
#   'age': 36,
#   'gender': 'M',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-02',
#   'visit_id': 23705,
#   'visit_date': '2025-01-20',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.46,
#   'risk_score': 'High',
#   'doctor_id': 180,
#   'bill_id': 23705,
#   'billed_amount': 4965.1,
#   'approved_amount': 4965.1,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-07-27'},
#  {'patient_id': 2547,
#   'age': 20,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-29',
#   'visit_id': 24044,
#   'visit_date': '2025-01-20',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 23.03,
#   'risk_score': 'High',
#   'doctor_id': 156,
#   'bill_id': 24044,
#   'billed_amount': 36849.95,
#   'approved_amount': 29725.78,
#   'claim_status': 'Pending',
#   'payment_days': 17.0,
#   'billing_date': '2025-09-15'},
#  {'patient_id': 1110,
#   'age': 79,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-09',
#   'visit_id': 24503,
#   'visit_date': '2025-01-20',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 26.03,
#   'risk_score': 'High',
#   'doctor_id': 106,
#   'bill_id': 24503,
#   'billed_amount': 20345.98,
#   'approved_amount': 20345.98,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-17'},
#  {'patient_id': 3602,
#   'age': 32,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-06',
#   'visit_id': 24727,
#   'visit_date': '2025-01-20',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 6.76,
#   'risk_score': 'Medium',
#   'doctor_id': 191,
#   'bill_id': 24727,
#   'billed_amount': 18526.25,
#   'approved_amount': 18526.25,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-08-29'},
#  {'patient_id': 507,
#   'age': 34,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-01',
#   'visit_id': 347,
#   'visit_date': '2025-01-21',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 22.97,
#   'risk_score': 'Low',
#   'doctor_id': 102,
#   'bill_id': 347,
#   'billed_amount': 35174.18,
#   'approved_amount': 35174.18,
#   'claim_status': 'Paid',
#   'payment_days': 9.0,
#   'billing_date': '2025-12-06'},
#  {'patient_id': 3752,
#   'age': 50,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-03',
#   'visit_id': 543,
#   'visit_date': '2025-01-21',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.58,
#   'risk_score': 'High',
#   'doctor_id': 128,
#   'bill_id': 543,
#   'billed_amount': 52894.6,
#   'approved_amount': 52894.6,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-12-26'},
#  {'patient_id': 1897,
#   'age': 40,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-12',
#   'visit_id': 941,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.31,
#   'risk_score': 'Low',
#   'doctor_id': 173,
#   'bill_id': 941,
#   'billed_amount': 12670.81,
#   'approved_amount': 10946.04,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-03-06'},
#  {'patient_id': 3058,
#   'age': 48,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-21',
#   'visit_id': 1191,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 31.38,
#   'risk_score': 'High',
#   'doctor_id': 183,
#   'bill_id': 1191,
#   'billed_amount': 24042.9,
#   'approved_amount': 24042.9,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-06-08'},
#  {'patient_id': 4744,
#   'age': 52,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-07',
#   'visit_id': 2734,
#   'visit_date': '2025-01-21',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 32.79,
#   'risk_score': 'Low',
#   'doctor_id': 109,
#   'bill_id': 2734,
#   'billed_amount': 10260.78,
#   'approved_amount': 10260.78,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-10-10'},
#  {'patient_id': 434,
#   'age': 57,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2026-01-03',
#   'visit_id': 2754,
#   'visit_date': '2025-01-21',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 8.49,
#   'risk_score': 'Low',
#   'doctor_id': 136,
#   'bill_id': 2754,
#   'billed_amount': 500.0,
#   'approved_amount': 500.0,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-11'},
#  {'patient_id': 1333,
#   'age': 41,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-14',
#   'visit_id': 2859,
#   'visit_date': '2025-01-21',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 27.25,
#   'risk_score': 'Medium',
#   'doctor_id': 129,
#   'bill_id': 2859,
#   'billed_amount': 28509.91,
#   'approved_amount': 28509.91,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-10-25'},
#  {'patient_id': 2609,
#   'age': 61,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-25',
#   'visit_id': 3542,
#   'visit_date': '2025-01-21',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.27,
#   'risk_score': 'High',
#   'doctor_id': 124,
#   'bill_id': 3542,
#   'billed_amount': 13691.97,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 28.0,
#   'billing_date': '2025-03-30'},
#  {'patient_id': 3288,
#   'age': 41,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-19',
#   'visit_id': 4027,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 34.5,
#   'risk_score': 'Medium',
#   'doctor_id': 160,
#   'bill_id': 4027,
#   'billed_amount': 24054.63,
#   'approved_amount': 24054.63,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-07-06'},
#  {'patient_id': 777,
#   'age': 31,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-01-26',
#   'visit_id': 4085,
#   'visit_date': '2025-01-21',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 27.13,
#   'risk_score': 'Low',
#   'doctor_id': 167,
#   'bill_id': 4085,
#   'billed_amount': 18956.99,
#   'approved_amount': 18956.99,
#   'claim_status': 'Paid',
#   'payment_days': 22.0,
#   'billing_date': '2025-01-27'},
#  {'patient_id': 3416,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-23',
#   'visit_id': 4436,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 46.86,
#   'risk_score': 'Medium',
#   'doctor_id': 136,
#   'bill_id': 4436,
#   'billed_amount': 7682.42,
#   'approved_amount': 7682.42,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-05-14'},
#  {'patient_id': 2214,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-29',
#   'visit_id': 4438,
#   'visit_date': '2025-01-21',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 35.36,
#   'risk_score': 'Medium',
#   'doctor_id': 188,
#   'bill_id': 4438,
#   'billed_amount': 34939.59,
#   'approved_amount': 18359.91,
#   'claim_status': 'Pending',
#   'payment_days': 11.0,
#   'billing_date': '2025-03-15'},
#  {'patient_id': 1337,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-03',
#   'visit_id': 5265,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 17.88,
#   'risk_score': 'Low',
#   'doctor_id': 106,
#   'bill_id': 5265,
#   'billed_amount': 15829.98,
#   'approved_amount': 15829.98,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-03-28'},
#  {'patient_id': 752,
#   'age': 20,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-06-30',
#   'visit_id': 5347,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 32.61,
#   'risk_score': 'Low',
#   'doctor_id': 136,
#   'bill_id': 5347,
#   'billed_amount': 8200.16,
#   'approved_amount': 8200.16,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-05-24'},
#  {'patient_id': 1878,
#   'age': 41,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-11-10',
#   'visit_id': 5524,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 13.57,
#   'risk_score': 'Low',
#   'doctor_id': 200,
#   'bill_id': 5524,
#   'billed_amount': 27435.61,
#   'approved_amount': 27435.61,
#   'claim_status': 'Paid',
#   'payment_days': 10.0,
#   'billing_date': '2025-03-12'},
#  {'patient_id': 889,
#   'age': 55,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-08',
#   'visit_id': 5583,
#   'visit_date': '2025-01-21',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 26.11,
#   'risk_score': 'Low',
#   'doctor_id': 192,
#   'bill_id': 5583,
#   'billed_amount': 31278.9,
#   'approved_amount': 25785.33,
#   'claim_status': 'Pending',
#   'payment_days': 23.0,
#   'billing_date': '2025-03-27'},
#  {'patient_id': 3116,
#   'age': 49,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-02',
#   'visit_id': 6036,
#   'visit_date': '2025-01-21',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 25.09,
#   'risk_score': 'High',
#   'doctor_id': 149,
#   'bill_id': 6036,
#   'billed_amount': 30706.5,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 12.0,
#   'billing_date': '2025-05-21'},
#  {'patient_id': 4298,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-31',
#   'visit_id': 6064,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 37.79,
#   'risk_score': 'Medium',
#   'doctor_id': 194,
#   'bill_id': 6064,
#   'billed_amount': 18155.38,
#   'approved_amount': 18155.38,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-03-13'},
#  {'patient_id': 3817,
#   'age': 38,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-28',
#   'visit_id': 6964,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 21.56,
#   'risk_score': 'Low',
#   'doctor_id': 148,
#   'bill_id': 6964,
#   'billed_amount': 18942.61,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-04-09'},
#  {'patient_id': 4891,
#   'age': 30,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-09-03',
#   'visit_id': 8911,
#   'visit_date': '2025-01-21',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 12.02,
#   'risk_score': 'Low',
#   'doctor_id': 110,
#   'bill_id': 8911,
#   'billed_amount': 15779.29,
#   'approved_amount': 15779.29,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2025-09-07'},
#  {'patient_id': 1257,
#   'age': 75,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-07',
#   'visit_id': 8955,
#   'visit_date': '2025-01-21',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.23,
#   'risk_score': 'Medium',
#   'doctor_id': 134,
#   'bill_id': 8955,
#   'billed_amount': 31490.48,
#   'approved_amount': 31490.48,
#   'claim_status': 'Paid',
#   'payment_days': 7.0,
#   'billing_date': '2025-11-15'},
#  {'patient_id': 2812,
#   'age': 33,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-07-03',
#   'visit_id': 9411,
#   'visit_date': '2025-01-21',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 30.65,
#   'risk_score': 'Low',
#   'doctor_id': 177,
#   'bill_id': 9411,
#   'billed_amount': 43540.2,
#   'approved_amount': 43540.2,
#   'claim_status': 'Paid',
# ...
#   'visit_type': 'ER',
#   'length_of_stay_hours': 8.24,
#   'risk_score': 'Low',
#   'doctor_id': 190,
#   'bill_id': 20487,
#   'billed_amount': 32895.84,
#   'approved_amount': 18527.42,
#   'claim_status': 'Pending',
#   'payment_days': 1.0,
#   'billing_date': '2026-01-08'},
#  {'patient_id': 3048,
#   'age': 38,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 1,
#   'registration_date': '2025-02-11',
#   'visit_id': 20799,
#   'visit_date': '2025-02-02',
#   'department': 'General',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 32.89,
#   'risk_score': 'Medium',
#   'doctor_id': 172,
#   'bill_id': 20799,
#   'billed_amount': 19081.39,
#   'approved_amount': 19081.39,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-04-08'},
#  {'patient_id': 3090,
#   'age': 47,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-03-24',
#   'visit_id': 21873,
#   'visit_date': '2025-02-02',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 9.16,
#   'risk_score': 'Medium',
#   'doctor_id': 160,
#   'bill_id': 21873,
#   'billed_amount': 8164.65,
#   'approved_amount': 8164.65,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-02-04'},
#  {'patient_id': 2507,
#   'age': 90,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-02',
#   'visit_id': 21913,
#   'visit_date': '2025-02-02',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.28,
#   'risk_score': 'Low',
#   'doctor_id': 187,
#   'bill_id': 21913,
#   'billed_amount': 43165.16,
#   'approved_amount': 43165.16,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-09-03'},
#  {'patient_id': 1203,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-11',
#   'visit_id': 22487,
#   'visit_date': '2025-02-02',
#   'department': 'ICU',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 31.64,
#   'risk_score': 'Low',
#   'doctor_id': 184,
#   'bill_id': 22487,
#   'billed_amount': 23028.86,
#   'approved_amount': 23028.86,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-12-22'},
#  {'patient_id': 794,
#   'age': 22,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-04-06',
#   'visit_id': 22493,
#   'visit_date': '2025-02-02',
#   'department': 'ICU',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.95,
#   'risk_score': 'Medium',
#   'doctor_id': 117,
#   'bill_id': 22493,
#   'billed_amount': 77324.14,
#   'approved_amount': 77324.14,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-11-30'},
#  {'patient_id': 4856,
#   'age': 87,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-16',
#   'visit_id': 22557,
#   'visit_date': '2025-02-02',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 22.59,
#   'risk_score': 'High',
#   'doctor_id': 107,
#   'bill_id': 22557,
#   'billed_amount': 19084.99,
#   'approved_amount': 13596.35,
#   'claim_status': 'Pending',
#   'payment_days': 14.0,
#   'billing_date': '2025-05-10'},
#  {'patient_id': 3760,
#   'age': 44,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-05-30',
#   'visit_id': 22912,
#   'visit_date': '2025-02-02',
#   'department': 'Orthopedics',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 47.66,
#   'risk_score': 'Medium',
#   'doctor_id': 190,
#   'bill_id': 22912,
#   'billed_amount': 26008.66,
#   'approved_amount': 26008.66,
#   'claim_status': 'Paid',
#   'payment_days': 17.0,
#   'billing_date': '2025-01-28'},
#  {'patient_id': 1563,
#   'age': 1,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-21',
#   'visit_id': 23198,
#   'visit_date': '2025-02-02',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.66,
#   'risk_score': 'Low',
#   'doctor_id': 199,
#   'bill_id': 23198,
#   'billed_amount': 33583.22,
#   'approved_amount': 33583.22,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-05-22'},
#  {'patient_id': 3734,
#   'age': 47,
#   'gender': 'M',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-08-24',
#   'visit_id': 23873,
#   'visit_date': '2025-02-02',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 23.83,
#   'risk_score': 'Medium',
#   'doctor_id': 163,
#   'bill_id': 23873,
#   'billed_amount': 17706.75,
#   'approved_amount': 9549.55,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-07-05'},
#  {'patient_id': 1649,
#   'age': 66,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-22',
#   'visit_id': 86,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 18.17,
#   'risk_score': 'Low',
#   'doctor_id': 181,
#   'bill_id': 86,
#   'billed_amount': 30899.47,
#   'approved_amount': 30899.47,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-12-24'},
#  {'patient_id': 725,
#   'age': 48,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-23',
#   'visit_id': 190,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 50.22,
#   'risk_score': 'Medium',
#   'doctor_id': 163,
#   'bill_id': 190,
#   'billed_amount': 11221.04,
#   'approved_amount': nan,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-06-05'},
#  {'patient_id': 329,
#   'age': 56,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'MediCareX',
#   'chronic_flag': 0,
#   'registration_date': '2025-02-21',
#   'visit_id': 377,
#   'visit_date': '2025-02-03',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.26,
#   'risk_score': 'Low',
#   'doctor_id': 158,
#   'bill_id': 377,
#   'billed_amount': 34427.09,
#   'approved_amount': 34427.09,
#   'claim_status': 'Paid',
#   'payment_days': 14.0,
#   'billing_date': '2025-06-12'},
#  {'patient_id': 2629,
#   'age': 37,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-09',
#   'visit_id': 458,
#   'visit_date': '2025-02-03',
#   'department': 'Orthopedics',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 41.3,
#   'risk_score': 'Medium',
#   'doctor_id': 126,
#   'bill_id': 458,
#   'billed_amount': 500.0,
#   'approved_amount': 349.56,
#   'claim_status': 'Pending',
#   'payment_days': 18.0,
#   'billing_date': '2025-02-01'},
#  {'patient_id': 3476,
#   'age': 21,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-12',
#   'visit_id': 648,
#   'visit_date': '2025-02-03',
#   'department': 'ICU',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 32.54,
#   'risk_score': 'Low',
#   'doctor_id': 167,
#   'bill_id': 648,
#   'billed_amount': 25577.8,
#   'approved_amount': 0.0,
#   'claim_status': 'Rejected',
#   'payment_days': 22.0,
#   'billing_date': '2025-12-11'},
#  {'patient_id': 4526,
#   'age': 65,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-09-22',
#   'visit_id': 1013,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 20.68,
#   'risk_score': 'Low',
#   'doctor_id': 133,
#   'bill_id': 1013,
#   'billed_amount': 8665.53,
#   'approved_amount': 4699.54,
#   'claim_status': 'Pending',
#   'payment_days': 7.0,
#   'billing_date': '2025-09-24'},
#  {'patient_id': 1830,
#   'age': 45,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-10-04',
#   'visit_id': 1596,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 47.26,
#   'risk_score': 'Medium',
#   'doctor_id': 152,
#   'bill_id': 1596,
#   'billed_amount': 26605.27,
#   'approved_amount': nan,
#   'claim_status': 'Pending',
#   'payment_days': 25.0,
#   'billing_date': '2025-03-14'},
#  {'patient_id': 4525,
#   'age': 66,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-06-21',
#   'visit_id': 1669,
#   'visit_date': '2025-02-03',
#   'department': 'Cardiology',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 19.19,
#   'risk_score': 'Medium',
#   'doctor_id': 193,
#   'bill_id': 1669,
#   'billed_amount': 13311.98,
#   'approved_amount': 13311.98,
#   'claim_status': 'Paid',
#   'payment_days': 6.0,
#   'billing_date': '2025-08-23'},
#  {'patient_id': 3103,
#   'age': 74,
#   'gender': 'F',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-03-07',
#   'visit_id': 1935,
#   'visit_date': '2025-02-03',
#   'department': 'ER',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.07,
#   'risk_score': 'Low',
#   'doctor_id': 119,
#   'bill_id': 1935,
#   'billed_amount': 6293.27,
#   'approved_amount': 6293.27,
#   'claim_status': 'Paid',
#   'payment_days': nan,
#   'billing_date': '2025-08-10'},
#  {'patient_id': 3586,
#   'age': 21,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-12',
#   'visit_id': 1962,
#   'visit_date': '2025-02-03',
#   'department': 'Cardiology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 40.02,
#   'risk_score': 'High',
#   'doctor_id': 154,
#   'bill_id': 1962,
#   'billed_amount': 11229.84,
#   'approved_amount': 11229.84,
#   'claim_status': 'Paid',
#   'payment_days': 20.0,
#   'billing_date': '2025-08-31'},
#  {'patient_id': 3474,
#   'age': 25,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 1,
#   'registration_date': '2025-10-20',
#   'visit_id': 2088,
#   'visit_date': '2025-02-03',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 21.71,
#   'risk_score': 'Medium',
#   'doctor_id': 100,
#   'bill_id': 2088,
#   'billed_amount': 40345.87,
#   'approved_amount': 40345.87,
#   'claim_status': 'Paid',
#   'payment_days': 3.0,
#   'billing_date': '2025-06-07'},
#  {'patient_id': 3829,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-29',
#   'visit_id': 2415,
#   'visit_date': '2025-02-03',
#   'department': 'Cardiology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 31.22,
#   'risk_score': 'High',
#   'doctor_id': 196,
#   'bill_id': 2415,
#   'billed_amount': 25260.14,
#   'approved_amount': 25260.14,
#   'claim_status': 'Paid',
#   'payment_days': 19.0,
#   'billing_date': '2025-08-10'},
#  {'patient_id': 2267,
#   'age': 12,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-04-11',
#   'visit_id': 2517,
#   'visit_date': '2025-02-03',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 11.74,
#   'risk_score': 'Medium',
#   'doctor_id': 158,
#   'bill_id': 2517,
#   'billed_amount': 12213.75,
#   'approved_amount': 8311.04,
#   'claim_status': 'Pending',
#   'payment_days': 3.0,
#   'billing_date': '2025-04-27'},
#  {'patient_id': 3829,
#   'age': 66,
#   'gender': 'M',
#   'city': 'Chennai',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-29',
#   'visit_id': 2540,
#   'visit_date': '2025-02-03',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.28,
#   'risk_score': 'Low',
#   'doctor_id': 167,
#   'bill_id': 2540,
#   'billed_amount': 34691.0,
#   'approved_amount': 34691.0,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-06-28'},
#  {'patient_id': 2425,
#   'age': 17,
#   'gender': 'M',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-03',
#   'visit_id': 3051,
#   'visit_date': '2025-02-03',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 20.8,
#   'risk_score': 'Low',
#   'doctor_id': 126,
#   'bill_id': 3051,
#   'billed_amount': 17276.23,
#   'approved_amount': 17276.23,
#   'claim_status': 'Paid',
#   'payment_days': 12.0,
#   'billing_date': '2025-07-17'},
#  {'patient_id': 2808,
#   'age': 30,
#   'gender': 'F',
#   'city': 'Pune',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-25',
#   'visit_id': 3447,
#   'visit_date': '2025-02-03',
#   'department': 'General',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 34.84,
#   'risk_score': 'High',
#   'doctor_id': 140,
#   'bill_id': 3447,
#   'billed_amount': 32925.97,
#   'approved_amount': 32925.97,
#   'claim_status': 'Paid',
#   'payment_days': 8.0,
#   'billing_date': '2025-05-11'},
#  {'patient_id': 2756,
#   'age': 36,
#   'gender': 'F',
#   'city': 'Mumbai',
#   'insurance_provider': 'CareOne',
#   'chronic_flag': 0,
#   'registration_date': '2025-08-03',
#   'visit_id': 3631,
#   'visit_date': '2025-02-03',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 3.1,
#   'risk_score': 'Medium',
#   'doctor_id': 118,
#   'bill_id': 3631,
#   'billed_amount': 31915.13,
#   'approved_amount': 31915.13,
#   'claim_status': 'Paid',
#   'payment_days': 13.0,
#   'billing_date': '2025-03-11'},
#  {'patient_id': 1146,
#   'age': 45,
#   'gender': 'F',
#   'city': 'Chennai',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-11-11',
#   'visit_id': 3758,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'ICU',
#   'length_of_stay_hours': 38.53,
#   'risk_score': 'Medium',
#   'doctor_id': 191,
#   'bill_id': 3758,
#   'billed_amount': 35159.32,
#   'approved_amount': 35159.32,
#   'claim_status': 'Paid',
#   'payment_days': 11.0,
#   'billing_date': '2025-06-03'},
#  {'patient_id': 1841,
#   'age': 42,
#   'gender': 'F',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 1,
#   'registration_date': '2025-07-08',
#   'visit_id': 3866,
#   'visit_date': '2025-02-03',
#   'department': 'Neurology',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 14.81,
#   'risk_score': 'Medium',
#   'doctor_id': 164,
#   'bill_id': 3866,
#   'billed_amount': 39067.89,
#   'approved_amount': 22973.89,
#   'claim_status': 'Pending',
#   'payment_days': 2.0,
#   'billing_date': '2025-11-04'},
#  {'patient_id': 4789,
#   'age': 7,
#   'gender': 'M',
#   'city': 'Delhi',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-01-22',
#   'visit_id': 3941,
#   'visit_date': '2025-02-03',
#   'department': 'Orthopedics',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 10.31,
#   'risk_score': 'High',
#   'doctor_id': 171,
#   'bill_id': 3941,
#   'billed_amount': 9684.39,
#   'approved_amount': 8501.04,
#   'claim_status': 'Pending',
#   'payment_days': 10.0,
#   'billing_date': '2025-05-25'},
#  {'patient_id': 3399,
#   'age': 85,
#   'gender': 'F',
#   'city': 'Hyderabad',
#   'insurance_provider': 'SecureLife',
#   'chronic_flag': 0,
#   'registration_date': '2025-05-18',
#   'visit_id': 4859,
#   'visit_date': '2025-02-03',
#   'department': 'General',
#   'visit_type': 'OPD',
#   'length_of_stay_hours': 1.87,
#   'risk_score': 'Medium',
#   'doctor_id': 100,
#   'bill_id': 4859,
#   'billed_amount': 38466.95,
#   'approved_amount': 38466.95,
#   'claim_status': 'Paid',
#   'payment_days': 21.0,
#   'billing_date': '2026-01-07'},
#  {'patient_id': 55,
#   'age': 63,
#   'gender': 'M',
#   'city': 'Bangalore',
#   'insurance_provider': 'HealthPlus',
#   'chronic_flag': 0,
#   'registration_date': '2025-12-31',
#   'visit_id': 5602,
#   'visit_date': '2025-02-03',
#   'department': 'ER',
#   'visit_type': 'ER',
#   'length_of_stay_hours': 10.03,
#   'risk_score': 'Low',
#   'doctor_id': 148,
#   'bill_id': 5602,
#   'billed_amount': 11273.98,
#   'approved_amount': 11273.98,
#   'claim_status': 'Paid',
#   'payment_days': 16.0,
#   'billing_date': '2025-08-27'},
#  ...]

# %%
import pymongo
import pandas as pd
DB_NAME="hospital_miops"
COLLECTION_MODEL_TABLE="model_table_df"
CONNECTION_URL="my_url"

client=pymongo.MongoClient(CONNECTION_URL)
db=client[DB_NAME]
model_table_collection=db[COLLECTION_MODEL_TABLE]


model_table=model_table_collection.insert_many(model_table_df)

# %%
model_table_df=pd.DataFrame(list(model_table_collection.find()))
model_table_df.head()
# Out:
#                         _id  patient_id  age gender       city  \
# 0  6a32926c02c411335d6fa49e        3993    9      M  Hyderabad
# 1  6a32926c02c411335d6fa49f          76   59      M      Delhi
# 2  6a32926c02c411335d6fa4a0        3393   43      M  Hyderabad
# 3  6a32926c02c411335d6fa4a1        1998   29      M  Bangalore
# 4  6a32926c02c411335d6fa4a2        3500   38      M  Hyderabad
#
#   insurance_provider  chronic_flag registration_date  visit_id  visit_date  \
# 0         HealthPlus             1        2025-10-18       684  2025-01-20
# 1         HealthPlus             0        2025-07-09      1412  2025-01-20
# 2         HealthPlus             0        2025-07-10      1510  2025-01-20
# 3          MediCareX             1        2025-04-22      1549  2025-01-20
# 4            CareOne             1        2025-08-02      2275  2025-01-20
#
#    ... visit_type length_of_stay_hours  risk_score doctor_id  bill_id  \
# 0  ...        ICU                 5.79         Low       137      684
# 1  ...         ER                34.80      Medium       109     1412
# 2  ...        ICU                31.37      Medium       135     1510
# 3  ...         ER                20.88      Medium       179     1549
# 4  ...        ICU                 4.97         Low       107     2275
#
#    billed_amount  approved_amount  claim_status payment_days  billing_date
# 0       36721.68         36721.68          Paid         19.0    2025-08-15
# 1        8365.47          4189.20       Pending         26.0    2025-11-14
# 2       16529.35             0.00      Rejected          7.0    2025-04-24
# 3       61827.63         61827.63          Paid          1.0    2025-10-17
# 4        5860.51          4897.65       Pending         28.0    2025-08-05
#
# [5 rows x 21 columns]

# %%
if"_id" in model_table_df.columns:
    model_table_df.drop("_id",axis=1,inplace=True)
    
model_table_df.head()
# Out:
#    patient_id  age gender       city insurance_provider  chronic_flag  \
# 0        3993    9      M  Hyderabad         HealthPlus             1
# 1          76   59      M      Delhi         HealthPlus             0
# 2        3393   43      M  Hyderabad         HealthPlus             0
# 3        1998   29      M  Bangalore          MediCareX             1
# 4        3500   38      M  Hyderabad            CareOne             1
#
#   registration_date  visit_id  visit_date   department visit_type  \
# 0        2025-10-18       684  2025-01-20      General        ICU
# 1        2025-07-09      1412  2025-01-20      General         ER
# 2        2025-07-10      1510  2025-01-20          ICU        ICU
# 3        2025-04-22      1549  2025-01-20   Cardiology         ER
# 4        2025-08-02      2275  2025-01-20  Orthopedics        ICU
#
#    length_of_stay_hours risk_score  doctor_id  bill_id  billed_amount  \
# 0                  5.79        Low        137      684       36721.68
# 1                 34.80     Medium        109     1412        8365.47
# 2                 31.37     Medium        135     1510       16529.35
# 3                 20.88     Medium        179     1549       61827.63
# 4                  4.97        Low        107     2275        5860.51
#
#    approved_amount claim_status  payment_days billing_date
# 0         36721.68         Paid          19.0   2025-08-15
# 1          4189.20      Pending          26.0   2025-11-14
# 2             0.00     Rejected           7.0   2025-04-24
# 3         61827.63         Paid           1.0   2025-10-17
# 4          4897.65      Pending          28.0   2025-08-05

# %%
conn.close()
print("Database connection closed successfully")
# Out:
# Database connection closed successfully
